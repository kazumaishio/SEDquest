# %% [markdown]
# # 1day SEDs
# # Make an ecsv file which contains SEDs of all periods with significant number of data points
# Taking
# `/home/kazuma/Workspace/AGN_data/0XX_SOURCENAME_1d/MJD/1days/lightcurve_STARTMET_ENDMET/4fgl_jXXXXXXXXXX_sed.fits`

# %%
import os

# # 3C454.3 Number of significant SEDs: 871
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/051_3C454_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'


################ NO HIGH PERIOD ##################
# # Mrk421 = 4fgl_j1104.4+3812
# source_name='Mrk421'
# source_name_4fgl='4fgl_j1104.4+3812'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/032_Mrk421_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # BLLac = 4fgl_j2202.7+4216 Number of significant SEDs: 332
# source_name='BLLac'
# source_name_4fgl='4fgl_j2202.7+4216'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/053_BLLac_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'

# # # CTA102 = 4fgl_j2232.6+1143s Number of significant SEDs: 361
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/054_CTA102_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'

# # 3C279 = 4fgl_j1256.1-0547 Number of significant SEDs: 258
# source_name='3C279'
# source_name_4fgl='4fgl_j1256.1-0547'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/055_3C279_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'

################ NO HIGH PERIOD ##################
# # S50716+71 = 4fgl_j0721.9+7120
# source_name='S50716+71'
# source_name_4fgl='4fgl_j0721.9+7120'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/036_S50716+71_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# # PKS1424-41 = 4fgl_j1427.9-4206 Number of significant SEDs: 370
# source_name='PKS1424-41'
# source_name_4fgl='4fgl_j1427.9-4206'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/057_PKS1424-41_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'


################ NO HIGH PERIOD ##################
# # PKS0426-380 = 4fgl_j0428.6-3756
# source_name='PKS0426-380'
# source_name_4fgl='4fgl_j0428.6-3756'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/038_PKS0426-380_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


################ NO HIGH PERIOD ##################
# # PKS0537-441 = 4fgl_j0538.8-4405
# source_name='PKS0537-441'
# source_name_4fgl='4fgl_j0538.8-4405'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/039_PKS0537-441_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


################ NO HIGH PERIOD ##################
# # PKS2155-304 = 4fgl_j2158.8-3013
# source_name='PKS2155-304'
# source_name_4fgl='4fgl_j2158.8-3013'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/040_PKS2155-304_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


################ NO HIGH PERIOD ##################
# # PKS0454-234 = 4fgl_j0457.0-2324
# source_name='PKS0454-234'
# source_name_4fgl='4fgl_j0457.0-2324'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/041_PKS0454-234_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# # PKS1510-089 = 4fgl_j1512.8-0906 Number of significant SEDs: 263
source_name='PKS1510-089'
source_name_4fgl='4fgl_j1512.8-0906'
input_directory_parent='/home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d'
sed_filename=f'{source_name_4fgl}_sed.fits'
outfilename=f'{source_name}_allsed_1d_min11.ecsv'


# # PKS1502+106 = 4fgl_j1504.4+1029
# source_name='PKS1502+106'
# source_name_4fgl='4fgl_j1504.4+1029'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/043_PKS1502+106_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'



# # Ton599 = 4fgl_j1159.5+2914
# source_name='Ton599'
# source_name_4fgl='4fgl_j1159.5+2914'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/044_Ton599_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # -> PKS0346-27 = 4fgl_j0348.6-2749
# source_name='PKS0346-27'
# # source_name_4fgl='4fgl_j0348.5-2749'
# source_name_4fgl='4fgl_j0348.6-2749'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/045_PKS0346-27_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # 4C+01.02 = 4fgl_j0108.6+0134
# source_name='4C+01.02'
# source_name_4fgl='4fgl_j0108.6+0134'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/046_4C+01.02_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # 4C+55.17 = 4fgl_j0957.6+5523
# source_name='4C+55.17'
# source_name_4fgl='4fgl_j0957.6+5523'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/047_4C+55.17_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# # 4C+21.35 = 4fgl_j1224.9+2122
# source_name='4C+21.35'
# source_name_4fgl='4fgl_j1224.9+2122'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/048_4C+21.35_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # PKS1830-211 = 4fgl_j1833.6-2103
# source_name='PKS1830-211'
# source_name_4fgl='4fgl_j1833.6-2103'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/049_PKS1830-211_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# # PKS0208-512 = 4fgl_j0210.7-5101
# source_name='PKS0208-512'
# source_name_4fgl='4fgl_j0210.7-5101'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/050_PKS0208-512_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# %% [markdown]
# To exit GNU nano and save your merge message:
#
# 1. Press `Ctrl + O` (the letter O) to write/save the file.
# 2. Press `Enter` to confirm the filename.
# 3. Press `Ctrl + X` to exit nano.
#
# Your merge message will be saved and nano will close.

# %% [markdown]
# To synchronize your local branch with `origin/main`, follow these steps:
#
# 1. Make sure you are on the branch you want to update (e.g., `main`):

# %%
git checkout main

# %% [markdown]
# 2. Fetch the latest changes from the remote repository:

# %%
git fetch origin

# %% [markdown]
# 3. Merge the changes from `origin/main` into your local branch:

# %%
git merge origin/main

# %% [markdown]
# If you want your local branch to exactly match `origin/main` and discard local changes, you can use:

# %%
git reset --hard origin/main

# %% [markdown]
# Let me know if you want to synchronize a different branch or need help resolving merge conflicts.

# %%
####################################################################
# for Inline animations in Jupyter
# https://stackoverflow.com/questions/43445103/inline-animations-in-jupyter
####################################################################
# Enable interactive plot
# %matplotlib notebook

import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import os

####################################################################
# Functions
####################################################################
##################################
# 
##################################
def met_to_mjd(met) :
    mjd = 51910. + 7.4287e-4 + met/86400.
    return mjd
# print(mjd_start, mjd_end)
# print(met_to_mjd(mjd_start), met_to_mjd(mjd_end))

# %%
##################################
# Get Fermi SED
##################################

from astropy.table import Table, vstack
table_allSEDs=Table()
n_significant_sed=0

##################################
# Get subdirectories within time scope
ana_subdirectories=os.listdir(input_directory_parent)
print(len(ana_subdirectories))
# print(ana_subdirectories[0])

for ana_subdirectory in ana_subdirectories:
    print(ana_subdirectory)
    input_directory = os.path.join(input_directory_parent, ana_subdirectory,'1days')
    directories = os.listdir(input_directory)
    print(len(directories))
    for directoryname in directories:
        elements=directoryname.split('_')

        sed_path=os.path.join(input_directory_parent,ana_subdirectory,'1days',directoryname,sed_filename )
        try : 
            sed_tab= Table.read(sed_path)
            # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
            # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
        except:
            print('not found: ', sed_path)    
        if sed_tab is None:
            continue
        timebin_start=float(elements[1])
        timebin_end  =float(elements[2])
        # print(elements[1],elements[2]
        default_eref=sed_tab['e_ref']
        default_flux=np.ones(len(default_eref))*1e-4
        default_asymmerr=[np.ones(len(default_eref))*1e-5,np.ones(len(default_eref))*1e-5]

        default_errdiff=np.ones(len(default_eref))
        default_ts=np.ones(len(default_eref))*0.1
        high_significance_mask = (sed_tab['ts']>=9)
        low_significance_mask = (sed_tab['ts']<9)
        sed_tab['ShowUL']=low_significance_mask
        sed_tab_significant=sed_tab[high_significance_mask]
        sed_tab_nosignificant=sed_tab[low_significance_mask]
        print(len(sed_tab['e_ref']),len(sed_tab_significant['e_ref']))
        if len(sed_tab_significant['e_ref'])>=11:
            n_significant_sed+=1
            sed_tab_significant['tstart']=[met_to_mjd(timebin_start)]*len(sed_tab_significant['e_ref'])
            sed_tab_significant['tend']=[met_to_mjd(timebin_end)]*len(sed_tab_significant['e_ref'])
            table_allSEDs=vstack([table_allSEDs, sed_tab_significant])

        # print(len(sed_tab_nosignificant['e_ref']),len(sed_tab_nosignificant['e2dnde_ul']))
        # print(sed_tab_nosignificant['e_ref'],sed_tab_nosignificant['e2dnde_ul'])

table_allSEDs.write(outfilename)
# Out:
# 60
# 58609.7
# 14
# 30 5
# 30 6
# 30 8
# 30 10
# 30 7
# 30 4
# 30 4
# 30 2
# 30 6
# 30 3
# 30 9
# 30 9
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 5
# 57097.7
# 14
# 30 12
# 30 5
# 30 8
# 30 5
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57097.7/1days/lightcurve_447871615_447958015/4fgl_j1512.8-0906_sed.fits
# 30 0
# 30 17
# 30 10
# 30 14
# 30 3
# 30 13
# 30 2
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57097.7/1days/lightcurve_447698815_447785215/4fgl_j1512.8-0906_sed.fits
# 30 11
# 54969.7
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 14
# 30 7
# 30 10
# 30 9
# 30 14
# 30 10
# 30 6
# 30 12
# 30 7
# 30 8
# 30 15
# 30 9
# 30 9
# 30 9
# 30 7
# 58595.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58595.7/1days/lightcurve_577039615_577126015/4fgl_j1512.8-0906_sed.fits
# 30 7
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58595.7/1days/lightcurve_577385215_577471615/4fgl_j1512.8-0906_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58595.7/1days/lightcurve_577817215_577903615/4fgl_j1512.8-0906_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58595.7/1days/lightcurve_577471615_577558015/4fgl_j1512.8-0906_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58595.7/1days/lightcurve_578162815_578249215/4fgl_j1512.8-0906_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58595.7/1days/lightcurve_577644415_577730815/4fgl_j1512.8-0906_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58595.7/1days/lightcurve_577298815_577385215/4fgl_j1512.8-0906_sed.fits
# 30 1
# 30 1
# 30 6
# 30 3
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58595.7/1days/lightcurve_577558015_577644415/4fgl_j1512.8-0906_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58595.7/1days/lightcurve_577903615_577990015/4fgl_j1512.8-0906_sed.fits
# 30 1
# 57223.7
# 14
# 30 12
# 30 15
# 30 6
# 30 2
# 30 11
# 30 4
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 1
# 30 13
# 30 3
# 30 12
# 30 13
# 30 11
# 30 8
# 30 11
# 55879.7
# 14
# 30 11
# 30 13
# 30 8
# 30 3
# 30 17
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 8
# 30 9
# 30 11
# 30 10
# 30 13
# 30 11
# 30 10
# 30 14
# 56593.7
# 14
# 30 11
# 30 14
# 30 16
# 30 2
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# 30 9
# 30 1
# 30 11
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/56593.7/1days/lightcurve_404066815_404153215/4fgl_j1512.8-0906_sed.fits
# 30 8
# 30 1
# 30 16
# 30 11
# 30 10
# 57195.7
# 14
# 30 3
# 30 4
# 30 7
# 30 4
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 4
# 30 7
# 30 7
# 30 12
# 30 12
# 30 11
# 30 3
# 30 6
# 30 8
# 54843.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54843.7/1days/lightcurve_252953215_253039615/4fgl_j1512.8-0906_sed.fits
# 30 8
# 30 13
# 30 5
# 30 14
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 13
# 30 11
# 30 14
# 30 13
# 30 10
# 30 16
# 30 7
# 30 10
# 55011.7
# 14
# 30 9
# 30 9
# 30 8
# 30 10
# 30 4
# 30 3
# 30 12
# 30 7
# 30 12
# 30 8
# 30 10
# 30 11
# 30 8
# 30 11
# 55963.7
# 14
# 30 13
# 30 7
# 30 9
# 30 13
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 8
# 30 14
# 30 7
# 30 11
# 30 11
# 30 10
# 30 11
# 30 13
# 30 13
# 55949.7
# 14
# 30 1
# 30 6
# 30 4
# 30 4
# 30 2
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55949.7/1days/lightcurve_348598015_348684415/4fgl_j1512.8-0906_sed.fits
# 30 11
# 30 0
# 30 5
# 30 4
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55949.7/1days/lightcurve_348770815_348857215/4fgl_j1512.8-0906_sed.fits
# 30 7
# 30 11
# 30 5
# 57643.7
# 14
# 30 12
# 30 11
# 30 9
# 30 10
# 30 11
# 30 6
# 30 6
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 13
# 30 8
# 30 11
# 30 10
# 30 12
# 55795.7
# 14
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55795.7/1days/lightcurve_335897215_335983615/4fgl_j1512.8-0906_sed.fits
# 30 10
# 30 1
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55795.7/1days/lightcurve_336156415_336242815/4fgl_j1512.8-0906_sed.fits
# 30 3
# 30 5
# 30 8
# 30 2
# 30 2
# 30 1
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55795.7/1days/lightcurve_335638015_335724415/4fgl_j1512.8-0906_sed.fits
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55795.7/1days/lightcurve_336070015_336156415/4fgl_j1512.8-0906_sed.fits
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55795.7/1days/lightcurve_336242815_336329215/4fgl_j1512.8-0906_sed.fits
# 30 7
# 56551.7
# 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 4
# 30 4
# 30 14
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/56551.7/1days/lightcurve_400697215_400783615/4fgl_j1512.8-0906_sed.fits
# 30 5
# 30 10
# 30 5
# 30 11
# 30 6
# 30 11
# 30 11
# 30 9
# 30 2
# 30 5
# 56005.7
# 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 1
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/56005.7/1days/lightcurve_354127615_354214015/4fgl_j1512.8-0906_sed.fits
# 30 10
# 30 3
# 30 13
# 30 10
# 30 11
# 30 9
# 30 8
# 30 5
# 30 14
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/56005.7/1days/lightcurve_354386815_354473215/4fgl_j1512.8-0906_sed.fits
# 30 14
# 30 14
# 30 1
# 56957.7
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 14
# 30 4
# 30 14
# 30 9
# 30 3
# 30 3
# 30 3
# 30 7
# 30 2
# 30 6
# 30 12
# 30 16
# 30 1
# 30 4
# 30 11
# 55193.7
# 14
# 30 9
# 30 10
# 30 10
# 30 7
# 30 6
# 30 9
# 30 12
# 30 13
# 30 10
# 30 5
# 30 7
# 30 15
# 30 6
# 30 6
# 54955.7
# 14
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 10
# 30 15
# 30 12
# 30 12
# 30 11
# 30 10
# 30 9
# 30 10
# 30 5
# 30 10
# 30 10
# 30 13
# 55767.7
# 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55767.7/1days/lightcurve_332700415_332786815/4fgl_j1512.8-0906_sed.fits
# 30 14
# 30 3
# 30 3
# 30 5
# 30 3
# 30 10
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55767.7/1days/lightcurve_333650815_333737215/4fgl_j1512.8-0906_sed.fits
# 30 4
# 30 6
# 30 3
# 30 15
# 30 3
# 30 1
# 55991.7
# 14
# 30 15
# 30 13
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55991.7/1days/lightcurve_353004415_353090815/4fgl_j1512.8-0906_sed.fits
# 30 15
# 30 11
# 30 5
# 30 13
# 30 14
# 30 14
# 30 13
# 30 15
# 30 16
# 30 16
# 57125.7
# 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 3
# 30 9
# 30 12
# 30 11
# 30 9
# 30 10
# 30 6
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57125.7/1days/lightcurve_450118015_450204415/4fgl_j1512.8-0906_sed.fits
# 30 10
# 30 12
# 30 10
# 30 10
# 30 12
# 30 10
# 54997.7
# 14
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 7
# 30 10
# 30 2
# 30 6
# 30 7
# 30 12
# 30 10
# 30 7
# 30 5
# 30 11
# 30 9
# 30 5
# 55977.7
# 14
# 30 11
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 3
# 30 15
# 30 14
# 30 14
# 30 10
# 30 14
# 30 13
# 30 9
# 30 10
# 30 12
# 30 12
# 57237.7
# 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 0
# 30 11
# 30 11
# 30 3
# 30 18
# 30 3
# 30 0
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57237.7/1days/lightcurve_460140415_460226815/4fgl_j1512.8-0906_sed.fits
# 30 6
# 30 2
# 30 0
# 30 5
# 30 1
# 30 6
# 58623.7m
# 14
# 30 10
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58623.7m/1days/lightcurve_580322815_580409215/4fgl_j1512.8-0906_sed.fits
# 30 0
# 30 10
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58623.7m/1days/lightcurve_580582015_580666913/4fgl_j1512.8-0906_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58623.7m/1days/lightcurve_580495615_580582015/4fgl_j1512.8-0906_sed.fits
# 30 2
# 30 5
# 30 4
# 30 1
# 30 1
# 30 1
# 54983.7
# 14
# 30 10
# 30 8
# 30 11
# 30 12
# 30 7
# 30 12
# 30 9
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 7
# 30 9
# 30 8
# 30 6
# 30 9
# 30 12
# 57657.7
# 14
# 30 7
# 30 4
# 30 7
# 30 8
# 30 5
# 30 10
# 30 4
# 30 10
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57657.7/1days/lightcurve_496428415_496514815/4fgl_j1512.8-0906_sed.fits
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57657.7/1days/lightcurve_496342015_496428415/4fgl_j1512.8-0906_sed.fits
# 30 4
# 30 9
# 30 2
# 56873.7
# 14
# 30 9
# 30 7
# 30 11
# 30 5
# 30 8
# 30 5
# 30 5
# 30 13
# 30 4
# 30 6
# 30 7
# 30 13
# 30 7
# 30 13
# 56831.7
# 14
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/56831.7/1days/lightcurve_424975615_425062015/4fgl_j1512.8-0906_sed.fits
# 30 4
# 30 7
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/56831.7/1days/lightcurve_424716415_424802815/4fgl_j1512.8-0906_sed.fits
# 30 4
# 30 7
# 30 2
# 30 5
# 30 2
# 30 6
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/56831.7/1days/lightcurve_425494015_425580415/4fgl_j1512.8-0906_sed.fits
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/56831.7/1days/lightcurve_424630015_424716415/4fgl_j1512.8-0906_sed.fits
# 30 10
# 30 12
# 54927.7
# 14
# 30 9
# 30 9
# 30 8
# 30 7
# 30 10
# 30 9
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 14
# 30 14
# 30 5
# 30 10
# 30 7
# 30 3
# 30 10
# 57209.7
# 14
# 30 6
# 30 6
# 30 8
# 30 10
# 30 7
# 30 7
# 30 12
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 7
# 30 3
# 30 9
# 30 10
# 30 10
# 30 13
# 57167.7
# 14
# 30 2
# 30 4
# 30 11
# 30 13
# 30 12
# 30 12
# 30 17
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# 30 15
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57167.7/1days/lightcurve_454524415_454610815/4fgl_j1512.8-0906_sed.fits
# 30 15
# 30 13
# 30 16
# 30 10
# 57629.7
# 14
# 30 1
# 30 7
# 30 0
# 30 13
# 30 9
# 30 7
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 8
# 30 12
# 30 9
# 30 3
# 30 5
# 30 6
# 30 9
# 55739.7
# 14
# 30 13
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55739.7/1days/lightcurve_330540415_330626815/4fgl_j1512.8-0906_sed.fits
# 30 1
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55739.7/1days/lightcurve_330281215_330367615/4fgl_j1512.8-0906_sed.fits
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 4
# 30 0
# 30 13
# 30 13
# 30 9
# 30 9
# 30 10
# 30 16
# 30 2
# 55865.7
# 14
# 30 17
# 30 8
# 30 12
# 30 9
# 30 5
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/55865.7/1days/lightcurve_341167615_341254015/4fgl_j1512.8-0906_sed.fits
# 30 14
# 30 14
# 30 5
# 30 4
# 30 1
# 30 3
# 30 2
# 30 16
# 55851.7
# 14
# 30 5
# 30 15
# 30 18
# 30 5
# 30 13
# 30 9
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 3
# 30 6
# 30 11
# 30 10
# 30 13
# 30 15
# 30 15
# 58511.7
# 14
# 30 11
# 30 3
# 30 3
# 30 3
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58511.7/1days/lightcurve_569954815_570041215/4fgl_j1512.8-0906_sed.fits
# 30 4
# 30 3
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 3
# 30 13
# 30 6
# 30 0
# 30 2
# 30 4
# 30 5
# 57153.7
# 14
# 30 16
# 30 10
# 30 13
# 30 5
# 30 15
# 30 8
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 6
# 30 3
# 30 7
# 30 7
# 30 11
# 30 12
# 30 18
# 56537.7
# 14
# 30 4
# 30 3
# 30 4
# 30 6
# 30 7
# 30 11
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 6
# 30 10
# 30 1
# 30 7
# 30 7
# 30 10
# 30 7
# 58231.7
# 14
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58231.7/1days/lightcurve_546626815_546713215/4fgl_j1512.8-0906_sed.fits
# 30 8
# 30 0
# 30 5
# 30 4
# 30 5
# 30 0
# 30 8
# 30 10
# 30 10
# 30 5
# 30 7
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58231.7/1days/lightcurve_546454015_546540415/4fgl_j1512.8-0906_sed.fits
# 30 8
# 56565.7
# 14
# 30 15
# 30 2
# 30 6
# 30 13
# 30 7
# 30 11
# 30 10
# 30 7
# 30 9
# 30 10
# 30 10
# 30 9
# 30 5
# 30 1
# 56579.7
# 14
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 8
# 30 10
# 30 8
# 30 11
# 30 9
# 30 10
# 30 7
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/56579.7/1days/lightcurve_403980415_404066815/4fgl_j1512.8-0906_sed.fits
# 30 10
# 30 8
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/56579.7/1days/lightcurve_403807615_403894015/4fgl_j1512.8-0906_sed.fits
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/56579.7/1days/lightcurve_403894015_403980415/4fgl_j1512.8-0906_sed.fits
# 30 8
# 57251.7
# 14
# 30 15
# 30 10
# 30 15
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57251.7/1days/lightcurve_461868415_461954815/4fgl_j1512.8-0906_sed.fits
# 30 15
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# 30 9
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57251.7/1days/lightcurve_462041215_462127035/4fgl_j1512.8-0906_sed.fits
# 30 5
# 30 3
# 30 19
# 30 4
# 30 3
# 30 2
# 54913.7
# 14
# 30 14
# 30 11
# 30 15
# 30 13
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# 30 12
# 30 14
# 30 11
# 30 16
# 30 13
# 30 16
# 30 11
# 30 14
# 57139.7
# 14
# 30 6
# 30 7
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57139.7/1days/lightcurve_452105215_452191615/4fgl_j1512.8-0906_sed.fits
# 30 8
# 30 9
# 30 12
# 30 2
# 30 1
# 30 0
# 30 4
# 30 4
# 30 3
# 30 10
# 58525.7
# 14
# 30 7
# 30 6
# 30 12
# 30 7
# 30 12
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 3
# 30 16
# 30 11
# 30 7
# 30 11
# 30 9
# 30 10
# 58581.7
# 14
# 30 2
# 30 11
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58581.7/1days/lightcurve_576953215_577038854/4fgl_j1512.8-0906_sed.fits
# 30 11
# 30 4
# 30 6
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 5
# 30 1
# 30 8
# 30 12
# 30 10
# 30 2
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58581.7/1days/lightcurve_576262015_576348415/4fgl_j1512.8-0906_sed.fits
# 30 11
# 54857.7
# 14
# 30 9
# 30 1
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54857.7/1days/lightcurve_254681215_254767615/4fgl_j1512.8-0906_sed.fits
# 30 4
# 30 8
# 30 5
# 30 12
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54857.7/1days/lightcurve_255199615_255286015/4fgl_j1512.8-0906_sed.fits
# 30 6
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 4
# 30 9
# 30 10
# 30 11
# 54717.7
# 14
# 30 5
# 30 6
# 30 12
# 30 1
# 30 8
# 30 8
# 30 6
# 30 5
# 30 4
# 30 10
# 30 10
# 30 7
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 58413.7
# 14
# 30 0
# 30 3
# 30 2
# 30 1
# 30 3
# 30 4
# 30 5
# 30 1
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58413.7/1days/lightcurve_561314815_561401215/4fgl_j1512.8-0906_sed.fits
# 30 2
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58413.7/1days/lightcurve_562265215_562351615/4fgl_j1512.8-0906_sed.fits
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/58413.7/1days/lightcurve_561401215_561487615/4fgl_j1512.8-0906_sed.fits
# 30 7
# 30 2
# 57181.7
# 14
# 30 2
# 30 8
# 30 3
# 30 1
# 30 1
# 30 5
# 30 5
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57181.7/1days/lightcurve_455734015_455820415/4fgl_j1512.8-0906_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57181.7/1days/lightcurve_455906815_455993215/4fgl_j1512.8-0906_sed.fits
# 30 1
# 30 4
# 30 8
# 30 5
# 57111.7
# 14
# 30 13
# 30 11
# 30 14
# 30 18
# 30 15
# 30 3
# 30 5
# 30 17
# 30 18
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 11
# 30 16
# 30 14
# 30 13
# 54941.7
# 14
# 30 12
# 30 6
# 30 13
# 30 1
# 30 11
# 30 3
# 30 10
# 30 3
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 7
# 30 12
# 30 2
# 30 4
# 30 9
# 30 6
# 54899.7
# 14
# 30 10
# 30 13
# 30 3
# 30 11
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54899.7/1days/lightcurve_257878015_257964415/4fgl_j1512.8-0906_sed.fits
# 30 2
# 30 16
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54899.7/1days/lightcurve_258569215_258655615/4fgl_j1512.8-0906_sed.fits
# 30 16
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54899.7/1days/lightcurve_257791615_257878015/4fgl_j1512.8-0906_sed.fits
# 30 16
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54899.7/1days/lightcurve_258742015_258828415/4fgl_j1512.8-0906_sed.fits
# 30 16
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54899.7/1days/lightcurve_258482815_258569215/4fgl_j1512.8-0906_sed.fits
# 30 16
# 30 1
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54899.7/1days/lightcurve_258655615_258742015/4fgl_j1512.8-0906_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54899.7/1days/lightcurve_257964415_258050815/4fgl_j1512.8-0906_sed.fits
# 30 1
# 55179.7
# 14
# 30 11
# 30 1
# 30 7
# 30 7
# 30 6
# 30 13
# 30 3
# 30 8
# 30 10
# 30 10
# 30 8
# 30 6
# 30 5
# 30 12
# 54731.7
# 14
# 30 6
# 30 4
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54731.7/1days/lightcurve_244226815_244313215/4fgl_j1512.8-0906_sed.fits
# 30 4
# 30 11
# 30 2
# 30 11
# 30 3
# 30 10
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54731.7/1days/lightcurve_244313215_244399615/4fgl_j1512.8-0906_sed.fits
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/54731.7/1days/lightcurve_244140415_244226815/4fgl_j1512.8-0906_sed.fits
# 30 6
# 30 1
# 30 2
# 30 1
# 55207.7
# 14
# 30 12
# 30 10
# 30 10
# 30 9
# 30 8
# 30 7
# 30 1
# 30 7
# 30 4
# 30 8
# 30 11
# 30 8
# 30 9
# 30 5
# 55025.7
# 14
# 30 12
# 30 12
# 30 8
# 30 9
# 30 0
# 30 10
# 30 10
# 30 10
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 10
# 30 11
# 30 8
# 30 7
# 57279.7
# 14
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57279.7/1days/lightcurve_463855615_463942015/4fgl_j1512.8-0906_sed.fits
# 30 4
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57279.7/1days/lightcurve_464460415_464545991/4fgl_j1512.8-0906_sed.fits
# 30 3
# 30 6
# 30 1
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d/57279.7/1days/lightcurve_464374015_464460415/4fgl_j1512.8-0906_sed.fits
# 30 8
# 30 2
# 30 6
# 30 1
# 30 5
# 30 5
# 30 4
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]

# %%
print('Number of significant SEDs:',n_significant_sed)
# Out:
# Number of significant SEDs: 263

# %%
print(table_allSEDs.colnames)
# Out:
# ['e_min', 'e_ref', 'e_max', 'ref_dnde_e_min', 'ref_dnde_e_max', 'ref_dnde', 'ref_flux', 'ref_eflux', 'ref_npred', 'dnde', 'dnde_err', 'dnde_errp', 'dnde_errn', 'dnde_ul', 'e2dnde', 'e2dnde_err', 'e2dnde_errp', 'e2dnde_errn', 'e2dnde_ul', 'norm', 'norm_err', 'norm_errp', 'norm_errn', 'norm_ul', 'ts', 'loglike', 'norm_scan', 'dloglike_scan', 'ShowUL', 'tstart', 'tend']

# %%
table_allSEDs
# Out:
# <Table length=3415>
#       e_min              e_ref        ...       tstart              tend
#        MeV                MeV         ...
#      float64            float64       ...      float64            float64
# ------------------ ------------------ ... ------------------ ------------------
# 132.83117061068992   153.091119887046 ... 58605.699990555186 58606.699990555186
#  176.4411988580621 203.35272664697808 ... 58605.699990555186 58606.699990555186
# 234.36890988269914  270.1158072739371 ... 58605.699990555186 58606.699990555186
#  311.3149665447022  358.7979888064861 ... 58605.699990555186 58606.699990555186
# 413.52331434760555  476.5900816815941 ... 58605.699990555186 58606.699990555186
#  549.2752115212968  633.0528961793416 ... 58605.699990555186 58606.699990555186
#  729.6086933380817  840.8915725798939 ... 58605.699990555186 58606.699990555186
#  969.1477682383326 1116.9661194245136 ... 58605.699990555186 58606.699990555186
# 1709.9759409858673 1970.7884119509856 ... 58605.699990555186 58606.699990555186
#                ...                ... ...                ...                ...
#  176.4411988580621 203.35272664697808 ... 55031.699990555186 55032.699990555186
# 234.36890988269914  270.1158072739371 ... 55031.699990555186 55032.699990555186
#  311.3149665447022  358.7979888064861 ... 55031.699990555186 55032.699990555186
# 413.52331434760555  476.5900816815941 ... 55031.699990555186 55032.699990555186
#  549.2752115212968  633.0528961793416 ... 55031.699990555186 55032.699990555186
#  729.6086933380817  840.8915725798939 ... 55031.699990555186 55032.699990555186
#  969.1477682383326 1116.9661194245136 ... 55031.699990555186 55032.699990555186
# 1287.3303254983532 1483.6791717563765 ... 55031.699990555186 55032.699990555186
# 1709.9759409858673 1970.7884119509856 ... 55031.699990555186 55032.699990555186
# 4007.6519721450045  4618.915317184078 ... 55031.699990555186 55032.699990555186

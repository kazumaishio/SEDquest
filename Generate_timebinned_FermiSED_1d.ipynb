# %% [markdown]
# # 1day SEDs
# # Make an ecsv file which contains SEDs of all periods with significant number of data points
# Taking
# `/home/kazuma/Workspace/AGN_data/0XX_SOURCENAME_1d/MJD/1days/lightcurve_STARTMET_ENDMET/4fgl_jXXXXXXXXXX_sed.fits`

# %%
import os

# # 3C454.3 Number of significant SEDs: 871
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/051_3C454_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'


# # Mrk421 = 4fgl_j1104.4+3812
# source_name='Mrk421'
# source_name_4fgl='4fgl_j1104.4+3812'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/032_Mrk421_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # BLLac = 4fgl_j2202.7+4216 Number of significant SEDs: 332
# source_name='BLLac'
# source_name_4fgl='4fgl_j2202.7+4216'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/053_BLLac_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'

# # CTA102 = 4fgl_j2232.6+1143s Number of significant SEDs: 361
source_name='CTA102'
source_name_4fgl='4fgl_j2232.6+1143'
input_directory_parent='/home/kazuma/Workspace/AGN_data/054_CTA102_1d'
sed_filename=f'{source_name_4fgl}_sed.fits'
outfilename=f'{source_name}_allsed_1d_min11.ecsv'

# # 3C279 = 4fgl_j1256.1-0547
# source_name='3C279'
# source_name_4fgl='4fgl_j1256.1-0547'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/035_3C279_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# # S50716+71 = 4fgl_j0721.9+7120
# source_name='S50716+71'
# source_name_4fgl='4fgl_j0721.9+7120'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/036_S50716+71_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# # PKS1424-41 = 4fgl_j1427.9-4206
# source_name='PKS1424-41'
# source_name_4fgl='4fgl_j1427.9-4206'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/037_PKS1424-41_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # PKS0426-380 = 4fgl_j0428.6-3756
# source_name='PKS0426-380'
# source_name_4fgl='4fgl_j0428.6-3756'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/038_PKS0426-380_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # PKS0537-441 = 4fgl_j0538.8-4405
# source_name='PKS0537-441'
# source_name_4fgl='4fgl_j0538.8-4405'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/039_PKS0537-441_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # PKS2155-304 = 4fgl_j2158.8-3013
# source_name='PKS2155-304'
# source_name_4fgl='4fgl_j2158.8-3013'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/040_PKS2155-304_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # PKS0454-234 = 4fgl_j0457.0-2324
# source_name='PKS0454-234'
# source_name_4fgl='4fgl_j0457.0-2324'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/041_PKS0454-234_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# # PKS1510-089 = 4fgl_j1512.8-0906
# # Number of significant SEDs: 40
# source_name='PKS1510-089'
# source_name_4fgl='4fgl_j1512.8-0906'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/042_PKS1510-089_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # PKS1502+106 = 4fgl_j1504.4+1029
# source_name='PKS1502+106'
# source_name_4fgl='4fgl_j1504.4+1029'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/043_PKS1502+106_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'



# # Ton599 = 4fgl_j1159.5+2914
# source_name='Ton599'
# source_name_4fgl='4fgl_j1159.5+2914'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/044_Ton599_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # -> PKS0346-27 = 4fgl_j0348.6-2749
# source_name='PKS0346-27'
# # source_name_4fgl='4fgl_j0348.5-2749'
# source_name_4fgl='4fgl_j0348.6-2749'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/045_PKS0346-27_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # 4C+01.02 = 4fgl_j0108.6+0134
# source_name='4C+01.02'
# source_name_4fgl='4fgl_j0108.6+0134'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/046_4C+01.02_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # 4C+55.17 = 4fgl_j0957.6+5523
# source_name='4C+55.17'
# source_name_4fgl='4fgl_j0957.6+5523'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/047_4C+55.17_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# # 4C+21.35 = 4fgl_j1224.9+2122
# source_name='4C+21.35'
# source_name_4fgl='4fgl_j1224.9+2122'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/048_4C+21.35_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # PKS1830-211 = 4fgl_j1833.6-2103
# source_name='PKS1830-211'
# source_name_4fgl='4fgl_j1833.6-2103'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/049_PKS1830-211_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# # PKS0208-512 = 4fgl_j0210.7-5101
# source_name='PKS0208-512'
# source_name_4fgl='4fgl_j0210.7-5101'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/050_PKS0208-512_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# %% [markdown]
# To exit GNU nano and save your merge message:
#
# 1. Press `Ctrl + O` (the letter O) to write/save the file.
# 2. Press `Enter` to confirm the filename.
# 3. Press `Ctrl + X` to exit nano.
#
# Your merge message will be saved and nano will close.

# %% [markdown]
# To synchronize your local branch with `origin/main`, follow these steps:
#
# 1. Make sure you are on the branch you want to update (e.g., `main`):

# %%
git checkout main

# %% [markdown]
# 2. Fetch the latest changes from the remote repository:

# %%
git fetch origin

# %% [markdown]
# 3. Merge the changes from `origin/main` into your local branch:

# %%
git merge origin/main

# %% [markdown]
# If you want your local branch to exactly match `origin/main` and discard local changes, you can use:

# %%
git reset --hard origin/main

# %% [markdown]
# Let me know if you want to synchronize a different branch or need help resolving merge conflicts.

# %%
####################################################################
# for Inline animations in Jupyter
# https://stackoverflow.com/questions/43445103/inline-animations-in-jupyter
####################################################################
# Enable interactive plot
# %matplotlib notebook

import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import os

####################################################################
# Functions
####################################################################
##################################
# 
##################################
def met_to_mjd(met) :
    mjd = 51910. + 7.4287e-4 + met/86400.
    return mjd
# print(mjd_start, mjd_end)
# print(met_to_mjd(mjd_start), met_to_mjd(mjd_end))

# %%
##################################
# Get Fermi SED
##################################

from astropy.table import Table, vstack
table_allSEDs=Table()
n_significant_sed=0

##################################
# Get subdirectories within time scope
ana_subdirectories=os.listdir(input_directory_parent)
print(len(ana_subdirectories))
# print(ana_subdirectories[0])

for ana_subdirectory in ana_subdirectories:
    print(ana_subdirectory)
    input_directory = os.path.join(input_directory_parent, ana_subdirectory,'1days')
    directories = os.listdir(input_directory)
    print(len(directories))
    for directoryname in directories:
        elements=directoryname.split('_')

        sed_path=os.path.join(input_directory_parent,ana_subdirectory,'1days',directoryname,sed_filename )
        try : 
            sed_tab= Table.read(sed_path)
            # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
            # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
        except:
            print('not found: ', sed_path)    
        if sed_tab is None:
            continue
        timebin_start=float(elements[1])
        timebin_end  =float(elements[2])
        # print(elements[1],elements[2]
        default_eref=sed_tab['e_ref']
        default_flux=np.ones(len(default_eref))*1e-4
        default_asymmerr=[np.ones(len(default_eref))*1e-5,np.ones(len(default_eref))*1e-5]

        default_errdiff=np.ones(len(default_eref))
        default_ts=np.ones(len(default_eref))*0.1
        high_significance_mask = (sed_tab['ts']>=9)
        low_significance_mask = (sed_tab['ts']<9)
        sed_tab['ShowUL']=low_significance_mask
        sed_tab_significant=sed_tab[high_significance_mask]
        sed_tab_nosignificant=sed_tab[low_significance_mask]
        print(len(sed_tab['e_ref']),len(sed_tab_significant['e_ref']))
        if len(sed_tab_significant['e_ref'])>=11:
            n_significant_sed+=1
            sed_tab_significant['tstart']=[met_to_mjd(timebin_start)]*len(sed_tab_significant['e_ref'])
            sed_tab_significant['tend']=[met_to_mjd(timebin_end)]*len(sed_tab_significant['e_ref'])
            table_allSEDs=vstack([table_allSEDs, sed_tab_significant])

        # print(len(sed_tab_nosignificant['e_ref']),len(sed_tab_nosignificant['e2dnde_ul']))
        # print(sed_tab_nosignificant['e_ref'],sed_tab_nosignificant['e2dnde_ul'])

table_allSEDs.write(outfilename)
# Out:
# 64
# 57755.7
# 14
# 30 17
# 30 18
# 30 19
# 30 21
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 19
# 30 18
# 30 20
# 30 14
# 30 18
# 30 20
# 30 18
# 30 21
# 30 16
# 30 19
# 57461.7
# 14
# 30 3
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 6
# 30 11
# 30 11
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57461.7/1days/lightcurve_479407615_479494015/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 9
# 30 11
# 30 6
# 30 2
# 30 12
# 30 4
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57461.7/1days/lightcurve_479494015_479580415/4fgl_j2232.6+1143_sed.fits
# 30 13
# 56201.7
# 14
# 30 8
# 30 15
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 6
# 30 9
# 30 13
# 30 13
# 30 13
# 30 9
# 30 14
# 30 12
# 30 14
# 30 13
# 57503.7
# 14
# 30 6
# 30 7
# 30 5
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57503.7/1days/lightcurve_483382015_483468415/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57503.7/1days/lightcurve_483554815_483641215/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 7
# 30 7
# 30 4
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57503.7/1days/lightcurve_483209215_483295615/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57503.7/1days/lightcurve_482863615_482950015/4fgl_j2232.6+1143_sed.fits
# 30 3
# 57405.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57405.7/1days/lightcurve_474569215_474655615/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 9
# 30 6
# 30 7
# 30 5
# 30 15
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57405.7/1days/lightcurve_474223615_474310015/4fgl_j2232.6+1143_sed.fits
# 30 15
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57405.7/1days/lightcurve_474310015_474396415/4fgl_j2232.6+1143_sed.fits
# 30 15
# 30 8
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 6
# 30 11
# 30 14
# 57545.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57545.7/1days/lightcurve_486319615_486406015/4fgl_j2232.6+1143_sed.fits
# 30 14
# 30 6
# 30 13
# 30 15
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57545.7/1days/lightcurve_486406015_486492415/4fgl_j2232.6+1143_sed.fits
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 13
# 30 13
# 30 11
# 30 9
# 30 8
# 30 14
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57545.7/1days/lightcurve_486492415_486578815/4fgl_j2232.6+1143_sed.fits
# 30 12
# 57741.7
# 14
# 30 19
# 30 19
# 30 17
# 30 19
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 19
# 30 20
# 30 15
# 30 20
# 30 17
# 30 21
# 30 20
# 30 18
# 30 15
# 30 18
# 57293.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57293.7/1days/lightcurve_465583615_465670015/4fgl_j2232.6+1143_sed.fits
# 30 18
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57293.7/1days/lightcurve_465497215_465583615/4fgl_j2232.6+1143_sed.fits
# 30 18
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57293.7/1days/lightcurve_465324415_465410815/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 3
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57293.7/1days/lightcurve_465151615_465238015/4fgl_j2232.6+1143_sed.fits
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57293.7/1days/lightcurve_465065215_465151615/4fgl_j2232.6+1143_sed.fits
# 30 13
# 30 2
# 30 8
# 30 5
# 30 8
# 30 3
# 30 3
# 57825.7
# 14
# 30 6
# 30 11
# 30 11
# 30 8
# 30 7
# 30 7
# 30 7
# 30 3
# 30 7
# 30 9
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57825.7/1days/lightcurve_511289215_511375615/4fgl_j2232.6+1143_sed.fits
# 30 13
# 30 9
# 30 10
# 58161.7
# 14
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58161.7/1days/lightcurve_540233215_540319615/4fgl_j2232.6+1143_sed.fits
# 30 13
# 30 4
# 30 10
# 30 5
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58161.7/1days/lightcurve_540146815_540233215/4fgl_j2232.6+1143_sed.fits
# 30 11
# 30 7
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 8
# 30 5
# 30 5
# 30 8
# 30 5
# 57573.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57573.7/1days/lightcurve_489516415_489602815/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 8
# 30 8
# 30 4
# 30 7
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 13
# 30 6
# 30 6
# 30 9
# 30 9
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57573.7/1days/lightcurve_489862015_489948415/4fgl_j2232.6+1143_sed.fits
# 30 7
# 57867.7
# 14
# 30 6
# 30 9
# 30 19
# 30 13
# 30 7
# 30 9
# 30 14
# 30 9
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 5
# 30 20
# 30 15
# 30 8
# 57643.7
# 14
# 30 4
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57643.7/1days/lightcurve_495564415_495650815/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 6
# 30 5
# 30 8
# 30 11
# 30 9
# 30 7
# 30 5
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57643.7/1days/lightcurve_494959615_495046015/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 7
# 30 5
# 57685.7
# 14
# 30 14
# 30 6
# 30 14
# 30 7
# 30 2
# 30 3
# 30 8
# 30 9
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57685.7/1days/lightcurve_498674815_498761215/4fgl_j2232.6+1143_sed.fits
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57685.7/1days/lightcurve_498847615_498934015/4fgl_j2232.6+1143_sed.fits
# 30 6
# 30 5
# 30 3
# 30 12
# 57447.7
# 14
# 30 6
# 30 10
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 14
# 30 13
# 30 12
# 30 8
# 30 12
# 30 16
# 30 13
# 30 11
# 30 8
# 30 13
# 56957.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56957.7/1days/lightcurve_436380415_436466815/4fgl_j2232.6+1143_sed.fits
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56957.7/1days/lightcurve_435516415_435602815/4fgl_j2232.6+1143_sed.fits
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 8
# 30 0
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56957.7/1days/lightcurve_436553215_436639615/4fgl_j2232.6+1143_sed.fits
# 30 10
# 30 3
# 30 11
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56957.7/1days/lightcurve_436294015_436380415/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 7
# 30 9
# 30 7
# 30 4
# 57377.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57377.7/1days/lightcurve_472150015_472236415/4fgl_j2232.6+1143_sed.fits
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57377.7/1days/lightcurve_472582015_472668415/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 10
# 30 16
# 30 12
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57377.7/1days/lightcurve_471804415_471890815/4fgl_j2232.6+1143_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57377.7/1days/lightcurve_472495615_472582015/4fgl_j2232.6+1143_sed.fits
# 30 9
# 30 8
# 30 5
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57377.7/1days/lightcurve_471977215_472063615/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 8
# 58105.7
# 14
# 30 16
# 30 11
# 30 11
# 30 12
# 30 12
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 14
# 30 15
# 30 16
# 30 12
# 30 10
# 30 11
# 30 14
# 57713.7
# 14
# 30 12
# 30 18
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 12
# 30 9
# 30 12
# 30 13
# 30 4
# 30 16
# 30 13
# 30 9
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57713.7/1days/lightcurve_500834815_500921215/4fgl_j2232.6+1143_sed.fits
# 30 13
# 59953.7
# 14
# 30 10
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/59953.7/1days/lightcurve_694457215_694543615/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/59953.7/1days/lightcurve_695494015_695580090/4fgl_j2232.6+1143_sed.fits
# 30 11
# 30 9
# 30 11
# 30 6
# 30 9
# 30 9
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/59953.7/1days/lightcurve_695407615_695494015/4fgl_j2232.6+1143_sed.fits
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/59953.7/1days/lightcurve_694370815_694457215/4fgl_j2232.6+1143_sed.fits
# 30 7
# 30 8
# 57811.7
# 14
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 8
# 30 6
# 30 7
# 30 5
# 30 12
# 30 4
# 30 3
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57811.7/1days/lightcurve_509993215_510079615/4fgl_j2232.6+1143_sed.fits
# 30 12
# 30 9
# 30 11
# 30 11
# 58147.7
# 14
# 30 8
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 11
# 30 14
# 30 13
# 30 16
# 30 13
# 30 13
# 30 14
# 30 13
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 11
# 57923.7
# 14
# 30 6
# 30 9
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57923.7/1days/lightcurve_519583615_519670015/4fgl_j2232.6+1143_sed.fits
# 30 6
# 30 7
# 30 7
# 30 11
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57923.7/1days/lightcurve_519324415_519410815/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57923.7/1days/lightcurve_520015615_520102015/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 4
# 30 14
# 30 7
# 57797.7
# 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 15
# 30 13
# 30 15
# 30 15
# 30 19
# 30 20
# 30 14
# 30 17
# 30 11
# 30 17
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 17
# 30 19
# 57979.7
# 14
# 30 5
# 30 2
# 30 11
# 30 4
# 30 13
# 30 9
# 30 10
# 30 10
# 30 10
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57979.7/1days/lightcurve_524681215_524767615/4fgl_j2232.6+1143_sed.fits
# 30 9
# 30 6
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 7
# 30 7
# 57965.7
# 14
# 30 13
# 30 10
# 30 12
# 30 8
# 30 12
# 30 12
# 30 14
# 30 10
# 30 4
# 30 7
# 30 15
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 3
# 30 8
# 56397.7
# 14
# 30 8
# 30 15
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56397.7/1days/lightcurve_387910015_387996415/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 8
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56397.7/1days/lightcurve_388082815_388169215/4fgl_j2232.6+1143_sed.fits
# 30 7
# 30 0
# 30 15
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56397.7/1days/lightcurve_387564415_387650815/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56397.7/1days/lightcurve_387737215_387823615/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 2
# 57489.7
# 14
# 30 8
# 30 6
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57489.7/1days/lightcurve_481999615_482086015/4fgl_j2232.6+1143_sed.fits
# 30 9
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 7
# 30 10
# 30 9
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57489.7/1days/lightcurve_482518015_482604415/4fgl_j2232.6+1143_sed.fits
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57489.7/1days/lightcurve_482604415_482690815/4fgl_j2232.6+1143_sed.fits
# 30 10
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57489.7/1days/lightcurve_481654015_481740415/4fgl_j2232.6+1143_sed.fits
# 30 6
# 30 11
# 58021.7
# 14
# 30 6
# 30 7
# 30 9
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58021.7/1days/lightcurve_527878015_527964415/4fgl_j2232.6+1143_sed.fits
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58021.7/1days/lightcurve_527791615_527878015/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 5
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58021.7/1days/lightcurve_528569215_528655353/4fgl_j2232.6+1143_sed.fits
# 30 6
# 30 6
# 30 13
# 30 6
# 30 11
# 30 4
# 57671.7
# 14
# 30 11
# 30 8
# 30 1
# 30 8
# 30 5
# 30 3
# 30 0
# 30 6
# 30 4
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57671.7/1days/lightcurve_498070015_498156415/4fgl_j2232.6+1143_sed.fits
# 30 8
# 30 1
# 30 4
# 30 9
# 58035.7
# 14
# 30 6
# 30 8
# 30 10
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58035.7/1days/lightcurve_529174015_529260415/4fgl_j2232.6+1143_sed.fits
# 30 4
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58035.7/1days/lightcurve_529433215_529519615/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 6
# 30 0
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58035.7/1days/lightcurve_529001215_529087615/4fgl_j2232.6+1143_sed.fits
# 30 9
# 30 5
# 30 5
# 30 6
# 57699.7
# 14
# 30 3
# 30 8
# 30 6
# 30 6
# 30 7
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57699.7/1days/lightcurve_499884415_499970815/4fgl_j2232.6+1143_sed.fits
# 30 10
# 30 3
# 30 6
# 30 9
# 30 10
# 30 2
# 30 7
# 30 8
# 60681.7
# 14
# 30 6
# 30 2
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/60681.7/1days/lightcurve_757874815_757961215/4fgl_j2232.6+1143_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/60681.7/1days/lightcurve_757702015_757788415/4fgl_j2232.6+1143_sed.fits
# 30 9
# 30 8
# 30 13
# 30 13
# 30 12
# 30 4
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/60681.7/1days/lightcurve_757529215_757615615/4fgl_j2232.6+1143_sed.fits
# 30 8
# 30 12
# 30 0
# 57657.7
# 14
# 30 8
# 30 2
# 30 5
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 0
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57657.7/1days/lightcurve_497033215_497119615/4fgl_j2232.6+1143_sed.fits
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57657.7/1days/lightcurve_496082815_496169215/4fgl_j2232.6+1143_sed.fits
# 30 7
# 30 11
# 30 10
# 30 14
# 30 9
# 30 12
# 30 9
# 57055.7
# 14
# 30 4
# 30 8
# 30 9
# 30 5
# 30 5
# 30 10
# 30 8
# 30 8
# 30 6
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57055.7/1days/lightcurve_444070015_444156415/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 11
# 30 3
# 58049.7
# 14
# 30 6
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58049.7/1days/lightcurve_529865215_529951615/4fgl_j2232.6+1143_sed.fits
# 30 6
# 30 4
# 30 6
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58049.7/1days/lightcurve_530383615_530470015/4fgl_j2232.6+1143_sed.fits
# 30 7
# 30 4
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58049.7/1days/lightcurve_530124415_530210815/4fgl_j2232.6+1143_sed.fits
# 30 6
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58049.7/1days/lightcurve_530470015_530556415/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58049.7/1days/lightcurve_530902015_530988415/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 8
# 57615.7
# 14
# 30 10
# 30 3
# 30 7
# 30 3
# 30 9
# 30 9
# 30 3
# 30 6
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57615.7/1days/lightcurve_492626815_492713215/4fgl_j2232.6+1143_sed.fits
# 30 6
# 30 1
# 30 13
# 30 5
# 30 10
# 56243.7
# 14
# 30 12
# 30 6
# 30 10
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56243.7/1days/lightcurve_374604415_374690815/4fgl_j2232.6+1143_sed.fits
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56243.7/1days/lightcurve_374777215_374863615/4fgl_j2232.6+1143_sed.fits
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56243.7/1days/lightcurve_374345215_374431615/4fgl_j2232.6+1143_sed.fits
# 30 10
# 30 6
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56243.7/1days/lightcurve_374863615_374950015/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56243.7/1days/lightcurve_374172415_374258815/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 4
# 57951.7
# 14
# 30 11
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57951.7/1days/lightcurve_522521215_522607615/4fgl_j2232.6+1143_sed.fits
# 30 11
# 30 10
# 30 12
# 30 12
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57951.7/1days/lightcurve_522434815_522521215/4fgl_j2232.6+1143_sed.fits
# 30 8
# 30 11
# 30 13
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 6
# 30 9
# 58133.7
# 14
# 30 15
# 30 11
# 30 10
# 30 13
# 30 12
# 30 11
# 30 14
# 30 11
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 13
# 30 12
# 30 13
# 30 9
# 57419.7
# 14
# 30 13
# 30 7
# 30 7
# 30 13
# 30 14
# 30 12
# 30 10
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 15
# 30 10
# 30 15
# 30 9
# 30 14
# 56383.7
# 14
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56383.7/1days/lightcurve_386527615_386614015/4fgl_j2232.6+1143_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56383.7/1days/lightcurve_385922815_386009215/4fgl_j2232.6+1143_sed.fits
# 30 9
# 30 8
# 30 2
# 30 8
# 30 0
# 30 5
# 30 10
# 30 14
# 30 6
# 30 1
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 2
# 30 15
# 56187.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56187.7/1days/lightcurve_369161215_369247615/4fgl_j2232.6+1143_sed.fits
# 30 15
# 30 3
# 30 16
# 30 5
# 30 15
# 30 13
# 30 9
# 30 1
# 30 12
# 30 20
# 30 6
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56187.7/1days/lightcurve_369334015_369420415/4fgl_j2232.6+1143_sed.fits
# 30 0
# 57629.7
# 14
# 30 14
# 30 13
# 30 13
# 30 10
# 30 9
# 30 14
# 30 11
# 30 14
# 30 12
# 30 6
# 30 14
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 12
# 57909.7
# 14
# 30 8
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57909.7/1days/lightcurve_518633215_518719615/4fgl_j2232.6+1143_sed.fits
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57909.7/1days/lightcurve_518719615_518806015/4fgl_j2232.6+1143_sed.fits
# 30 6
# 30 11
# 30 7
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57909.7/1days/lightcurve_518806015_518892415/4fgl_j2232.6+1143_sed.fits
# 30 13
# 30 10
# 30 7
# 30 8
# 30 11
# 30 9
# 30 10
# 57727.7
# 14
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 19
# 30 14
# 30 17
# 30 18
# 30 14
# 30 16
# 30 15
# 30 16
# 30 14
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# 30 16
# 57839.7
# 14
# 30 12
# 30 10
# 30 11
# 30 9
# 30 13
# 30 10
# 30 15
# 30 12
# 30 16
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# ...
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# 30 14
# 30 13
# 30 12
# 30 13
# 30 16
# 59981.7
# 14
# 30 6
# 30 4
# 30 3
# 30 8
# 30 15
# 30 8
# 30 6
# 30 2
# 30 6
# 30 6
# 30 3
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/59981.7/1days/lightcurve_697308415_697394815/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 2
# 57895.7
# 14
# 30 16
# 30 4
# 30 10
# 30 16
# 30 10
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57895.7/1days/lightcurve_516905215_516991615/4fgl_j2232.6+1143_sed.fits
# 30 11
# 30 9
# 30 15
# 30 4
# 30 5
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57895.7/1days/lightcurve_517423615_517510015/4fgl_j2232.6+1143_sed.fits
# 30 10
# 30 11
# 57769.7
# 14
# 30 15
# 30 16
# 30 14
# 30 16
# 30 16
# 30 13
# 30 15
# 30 14
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# 30 19
# 30 16
# 30 15
# 30 16
# 56215.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56215.7/1days/lightcurve_371839615_371926015/4fgl_j2232.6+1143_sed.fits
# 30 16
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/56215.7/1days/lightcurve_372358015_372444415/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 7
# 30 7
# 30 9
# 30 10
# 30 10
# 30 5
# 30 5
# 30 4
# 30 7
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 8
# 30 4
# 57475.7
# 14
# 30 10
# 30 9
# 30 6
# 30 10
# 30 11
# 30 10
# 30 15
# 30 11
# 30 13
# 30 10
# 30 13
# 30 10
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 57881.7
# 14
# 30 10
# 30 15
# 30 18
# 30 8
# 30 11
# 30 12
# 30 10
# 30 17
# 30 14
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57881.7/1days/lightcurve_515609215_515695615/4fgl_j2232.6+1143_sed.fits
# 30 14
# 30 14
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 6
# 57937.7
# 14
# 30 6
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57937.7/1days/lightcurve_520620415_520706815/4fgl_j2232.6+1143_sed.fits
# 30 6
# 30 0
# 30 6
# 30 10
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57937.7/1days/lightcurve_520534015_520620415/4fgl_j2232.6+1143_sed.fits
# 30 6
# 30 10
# 30 10
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57937.7/1days/lightcurve_521225215_521311615/4fgl_j2232.6+1143_sed.fits
# 30 10
# 30 4
# 30 11
# 57531.7
# 14
# 30 10
# 30 7
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57531.7/1days/lightcurve_485455615_485542015/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 1
# 30 7
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 3
# 30 9
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57531.7/1days/lightcurve_485542015_485628415/4fgl_j2232.6+1143_sed.fits
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57531.7/1days/lightcurve_485282815_485369215/4fgl_j2232.6+1143_sed.fits
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57531.7/1days/lightcurve_485196415_485282815/4fgl_j2232.6+1143_sed.fits
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57531.7/1days/lightcurve_485369215_485455615/4fgl_j2232.6+1143_sed.fits
# 30 8
# 30 3
# 58119.7
# 14
# 30 17
# 30 13
# 30 17
# 30 14
# 30 14
# 30 14
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 14
# 30 11
# 30 12
# 30 14
# 30 14
# 30 14
# 57783.7
# 14
# 30 14
# 30 13
# 30 12
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57783.7/1days/lightcurve_507746815_507833215/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 10
# 30 17
# 30 13
# 30 12
# 30 15
# 30 13
# 30 13
# 57559.7
# 14
# 30 5
# 30 12
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 7
# 30 16
# 30 1
# 30 8
# 30 6
# 30 4
# 30 9
# 30 6
# 30 6
# 30 10
# 60023.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/60023.7/1days/lightcurve_700418815_700505215/4fgl_j2232.6+1143_sed.fits
# 30 10
# 30 2
# 30 10
# 30 1
# 30 11
# 30 5
# 30 6
# 30 6
# 30 6
# 30 9
# 30 7
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/60023.7/1days/lightcurve_701023615_701110015/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/60023.7/1days/lightcurve_701542015_701628415/4fgl_j2232.6+1143_sed.fits
# 30 1
# 55725.7
# 14
# 30 10
# 30 11
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/55725.7/1days/lightcurve_330022015_330108415/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 12
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/55725.7/1days/lightcurve_329935615_330022015/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/55725.7/1days/lightcurve_329676415_329762815/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/55725.7/1days/lightcurve_329503615_329590015/4fgl_j2232.6+1143_sed.fits
# 30 9
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/55725.7/1days/lightcurve_329849215_329935615/4fgl_j2232.6+1143_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/55725.7/1days/lightcurve_330108415_330194815/4fgl_j2232.6+1143_sed.fits
# 30 9
# 30 1
# 58217.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58217.7/1days/lightcurve_545071615_545158015/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58217.7/1days/lightcurve_544985215_545071615/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58217.7/1days/lightcurve_545417215_545503615/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58217.7/1days/lightcurve_544380415_544466815/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58217.7/1days/lightcurve_544812415_544898815/4fgl_j2232.6+1143_sed.fits
# 30 1
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58217.7/1days/lightcurve_545244415_545330815/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58217.7/1days/lightcurve_545330815_545417215/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58217.7/1days/lightcurve_545503615_545590015/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58217.7/1days/lightcurve_544726015_544812415/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58217.7/1days/lightcurve_544466815_544553215/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/58217.7/1days/lightcurve_545158015_545244415/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 4
# 57853.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57853.7/1days/lightcurve_513708415_513794815/4fgl_j2232.6+1143_sed.fits
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57853.7/1days/lightcurve_513449215_513535615/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 7
# 30 4
# 30 3
# 30 2
# 30 6
# 30 3
# 30 3
# 30 9
# 30 11
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/054_CTA102_1d/57853.7/1days/lightcurve_513794815_513881215/4fgl_j2232.6+1143_sed.fits
# 30 11
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]

# %%
print('Number of significant SEDs:',n_significant_sed)
# Out:
# Number of significant SEDs: 361

# %%
print(table_allSEDs.colnames)
# Out:
# ['e_min', 'e_ref', 'e_max', 'ref_dnde_e_min', 'ref_dnde_e_max', 'ref_dnde', 'ref_flux', 'ref_eflux', 'ref_npred', 'dnde', 'dnde_err', 'dnde_errp', 'dnde_errn', 'dnde_ul', 'e2dnde', 'e2dnde_err', 'e2dnde_errp', 'e2dnde_errn', 'e2dnde_ul', 'norm', 'norm_err', 'norm_errp', 'norm_errn', 'norm_ul', 'ts', 'loglike', 'norm_scan', 'dloglike_scan', 'ShowUL', 'tstart', 'tend']

# %%
table_allSEDs
# Out:
# <Table length=5007>
#       e_min              e_ref        ...       tstart              tend
#        MeV                MeV         ...
#      float64            float64       ...      float64            float64
# ------------------ ------------------ ... ------------------ ------------------
#              100.0 115.25240587974294 ... 57755.699990555186 57756.699990555186
# 132.83117061068992   153.091119887046 ... 57755.699990555186 57756.699990555186
#  176.4411988580621 203.35272664697808 ... 57755.699990555186 57756.699990555186
# 234.36890988269914  270.1158072739371 ... 57755.699990555186 57756.699990555186
#  311.3149665447022  358.7979888064861 ... 57755.699990555186 57756.699990555186
# 413.52331434760555  476.5900816815941 ... 57755.699990555186 57756.699990555186
#  549.2752115212968  633.0528961793416 ... 57755.699990555186 57756.699990555186
#  729.6086933380817  840.8915725798939 ... 57755.699990555186 57756.699990555186
#  969.1477682383326 1116.9661194245136 ... 57755.699990555186 57756.699990555186
#                ...                ... ...                ...                ...
# 132.83117061068992   153.091119887046 ... 57856.699990555186 57857.699990555186
#  176.4411988580621 203.35272664697808 ... 57856.699990555186 57857.699990555186
# 234.36890988269914  270.1158072739371 ... 57856.699990555186 57857.699990555186
#  311.3149665447022  358.7979888064861 ... 57856.699990555186 57857.699990555186
# 413.52331434760555  476.5900816815941 ... 57856.699990555186 57857.699990555186
#  549.2752115212968  633.0528961793416 ... 57856.699990555186 57857.699990555186
# 1709.9759409858673 1970.7884119509856 ... 57856.699990555186 57857.699990555186
# 2271.3810595726877  2617.821317854317 ... 57856.699990555186 57857.699990555186
#  5323.411028602609  6135.359285332078 ... 57856.699990555186 57857.699990555186
#  9392.473966813408  10825.05221838098 ... 57856.699990555186 57857.699990555186

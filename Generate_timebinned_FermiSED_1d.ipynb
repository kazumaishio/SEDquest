# %% [markdown]
# # 1day SEDs
# # Make an ecsv file which contains SEDs of all periods with significant number of data points
# Taking
# `/home/kazuma/Workspace/AGN_data/0XX_SOURCENAME_1d/MJD/1days/lightcurve_STARTMET_ENDMET/4fgl_jXXXXXXXXXX_sed.fits`

# %%
import os

# # 3C454.3 Number of significant SEDs: 871
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/051_3C454_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'


################ NO HIGH PERIOD ##################
# # Mrk421 = 4fgl_j1104.4+3812
# source_name='Mrk421'
# source_name_4fgl='4fgl_j1104.4+3812'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/032_Mrk421_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


# # BLLac = 4fgl_j2202.7+4216 Number of significant SEDs: 332
# source_name='BLLac'
# source_name_4fgl='4fgl_j2202.7+4216'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/053_BLLac_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'

# # # CTA102 = 4fgl_j2232.6+1143s Number of significant SEDs: 361
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/054_CTA102_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'

# # 3C279 = 4fgl_j1256.1-0547 Number of significant SEDs: 258
# source_name='3C279'
# source_name_4fgl='4fgl_j1256.1-0547'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/055_3C279_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'

################ NO HIGH PERIOD ##################
# # S50716+71 = 4fgl_j0721.9+7120
# source_name='S50716+71'
# source_name_4fgl='4fgl_j0721.9+7120'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/036_S50716+71_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# # PKS1424-41 = 4fgl_j1427.9-4206 Number of significant SEDs: 370
# source_name='PKS1424-41'
# source_name_4fgl='4fgl_j1427.9-4206'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/057_PKS1424-41_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'


################ NO HIGH PERIOD ##################
# # PKS0426-380 = 4fgl_j0428.6-3756
# source_name='PKS0426-380'
# source_name_4fgl='4fgl_j0428.6-3756'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/038_PKS0426-380_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


################ NO HIGH PERIOD ##################
# # PKS0537-441 = 4fgl_j0538.8-4405
# source_name='PKS0537-441'
# source_name_4fgl='4fgl_j0538.8-4405'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/039_PKS0537-441_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


################ NO HIGH PERIOD ##################
# # PKS2155-304 = 4fgl_j2158.8-3013
# source_name='PKS2155-304'
# source_name_4fgl='4fgl_j2158.8-3013'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/040_PKS2155-304_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'


################ NO HIGH PERIOD ##################
# # PKS0454-234 = 4fgl_j0457.0-2324
# source_name='PKS0454-234'
# source_name_4fgl='4fgl_j0457.0-2324'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/041_PKS0454-234_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# # # PKS1510-089 = 4fgl_j1512.8-0906 Number of significant SEDs: 263
# source_name='PKS1510-089'
# source_name_4fgl='4fgl_j1512.8-0906'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/062_PKS1510-089_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'


# # PKS1502+106 = 4fgl_j1504.4+1029 Number of significant SEDs: 81
# source_name='PKS1502+106'
# source_name_4fgl='4fgl_j1504.4+1029'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/063_PKS1502+106_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'


# # Ton599 = 4fgl_j1159.5+2914 Number of significant SEDs: 91
# source_name='Ton599'
# source_name_4fgl='4fgl_j1159.5+2914'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/064_Ton599_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'


# # -> PKS0346-27 = 4fgl_j0348.6-2749 Number of significant SEDs: 88
# source_name='PKS0346-27'
# source_name_4fgl='4fgl_j0348.6-2749'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/065_PKS0346-27_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'


# # 4C+01.02 = 4fgl_j0108.6+0134 Number of significant SEDs: 104
# source_name='4C+01.02'
# source_name_4fgl='4fgl_j0108.6+0134'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/066_4C+01.02_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'


################ NO HIGH PERIOD ##################
# # 4C+55.17 = 4fgl_j0957.6+5523
# source_name='4C+55.17'
# source_name_4fgl='4fgl_j0957.6+5523'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/047_4C+55.17_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# # 4C+21.35 = 4fgl_j1224.9+2122 Number of significant SEDs: 93
# source_name='4C+21.35'
# source_name_4fgl='4fgl_j1224.9+2122'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/068_4C+21.35_1d'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'


# PKS1830-211 = 4fgl_j1833.6-2103 Number of significant SEDs: 243
source_name='PKS1830-211'
source_name_4fgl='4fgl_j1833.6-2103'
input_directory_parent='/home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d'
sed_filename=f'{source_name_4fgl}_sed.fits'
outfilename=f'{source_name}_allsed_1d_min11.ecsv'

# # PKS0208-512 = 4fgl_j0210.7-5101
# source_name='PKS0208-512'
# source_name_4fgl='4fgl_j0210.7-5101'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/050_PKS0208-512_100MeV_14d/14days'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'

# %% [markdown]
# To exit GNU nano and save your merge message:
#
# 1. Press `Ctrl + O` (the letter O) to write/save the file.
# 2. Press `Enter` to confirm the filename.
# 3. Press `Ctrl + X` to exit nano.
#
# Your merge message will be saved and nano will close.

# %% [markdown]
# To synchronize your local branch with `origin/main`, follow these steps:
#
# 1. Make sure you are on the branch you want to update (e.g., `main`):

# %%
git checkout main

# %% [markdown]
# 2. Fetch the latest changes from the remote repository:

# %%
git fetch origin

# %% [markdown]
# 3. Merge the changes from `origin/main` into your local branch:

# %%
git merge origin/main

# %% [markdown]
# If you want your local branch to exactly match `origin/main` and discard local changes, you can use:

# %%
git reset --hard origin/main

# %% [markdown]
# Let me know if you want to synchronize a different branch or need help resolving merge conflicts.

# %%
####################################################################
# for Inline animations in Jupyter
# https://stackoverflow.com/questions/43445103/inline-animations-in-jupyter
####################################################################
# Enable interactive plot
# %matplotlib notebook

import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import os

####################################################################
# Functions
####################################################################
##################################
# 
##################################
def met_to_mjd(met) :
    mjd = 51910. + 7.4287e-4 + met/86400.
    return mjd
# print(mjd_start, mjd_end)
# print(met_to_mjd(mjd_start), met_to_mjd(mjd_end))

# %%
##################################
# Get Fermi SED
##################################

from astropy.table import Table, vstack
table_allSEDs=Table()
n_significant_sed=0

##################################
# Get subdirectories within time scope
ana_subdirectories=os.listdir(input_directory_parent)
print(len(ana_subdirectories))
# print(ana_subdirectories[0])

for ana_subdirectory in ana_subdirectories:
    print(ana_subdirectory)
    input_directory = os.path.join(input_directory_parent, ana_subdirectory,'1days')
    directories = os.listdir(input_directory)
    print(len(directories))
    for directoryname in directories:
        elements=directoryname.split('_')

        sed_path=os.path.join(input_directory_parent,ana_subdirectory,'1days',directoryname,sed_filename )
        try : 
            sed_tab= Table.read(sed_path)
            # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
            # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
        except:
            print('not found: ', sed_path)    
        if sed_tab is None:
            continue
        timebin_start=float(elements[1])
        timebin_end  =float(elements[2])
        # print(elements[1],elements[2]
        default_eref=sed_tab['e_ref']
        default_flux=np.ones(len(default_eref))*1e-4
        default_asymmerr=[np.ones(len(default_eref))*1e-5,np.ones(len(default_eref))*1e-5]

        default_errdiff=np.ones(len(default_eref))
        default_ts=np.ones(len(default_eref))*0.1
        high_significance_mask = (sed_tab['ts']>=9)
        low_significance_mask = (sed_tab['ts']<9)
        sed_tab['ShowUL']=low_significance_mask
        sed_tab_significant=sed_tab[high_significance_mask]
        sed_tab_nosignificant=sed_tab[low_significance_mask]
        print(len(sed_tab['e_ref']),len(sed_tab_significant['e_ref']))
        if len(sed_tab_significant['e_ref'])>=11:
            n_significant_sed+=1
            sed_tab_significant['tstart']=[met_to_mjd(timebin_start)]*len(sed_tab_significant['e_ref'])
            sed_tab_significant['tend']=[met_to_mjd(timebin_end)]*len(sed_tab_significant['e_ref'])
            table_allSEDs=vstack([table_allSEDs, sed_tab_significant])

        # print(len(sed_tab_nosignificant['e_ref']),len(sed_tab_nosignificant['e2dnde_ul']))
        # print(sed_tab_nosignificant['e_ref'],sed_tab_nosignificant['e2dnde_ul'])

table_allSEDs.write(outfilename)
# Out:
# 75
# 58637.7
# 14
# 30 2
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58637.7/1days/lightcurve_581705215_581791615/4fgl_j1833.6-2103_sed.fits
# 30 9
# 30 1
# 30 4
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58637.7/1days/lightcurve_581532415_581618815/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58637.7/1days/lightcurve_581791615_581878015/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58637.7/1days/lightcurve_581014015_581100415/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 1
# 30 9
# 30 3
# 58609.7
# 14
# 30 11
# 30 12
# 30 12
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 12
# 30 13
# 30 16
# 30 11
# 30 13
# 30 13
# 30 11
# 30 14
# 30 13
# 58595.7
# 14
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 15
# 30 16
# 30 15
# 30 16
# 30 15
# 30 12
# 30 14
# 30 14
# 30 16
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# 30 14
# 59855.7
# 14
# 30 6
# 30 13
# 30 10
# 30 9
# 30 11
# 30 9
# 30 10
# 30 9
# 30 9
# 30 11
# 30 8
# 30 7
# 30 9
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 59113.7
# 14
# 30 5
# 30 6
# 30 4
# 30 8
# 30 10
# 30 7
# 30 6
# 30 10
# 30 7
# 30 6
# 30 7
# 30 6
# 30 1
# 30 2
# 59883.7
# 14
# 30 9
# 30 8
# 30 5
# 30 4
# 30 10
# 30 2
# 30 9
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59883.7/1days/lightcurve_688754815_688841215/4fgl_j1833.6-2103_sed.fits
# 30 7
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59883.7/1days/lightcurve_688668415_688754815/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 7
# 30 6
# 30 11
# 58665.7
# 14
# 30 13
# 30 12
# 30 11
# 30 12
# 30 9
# 30 10
# 30 5
# 30 5
# 30 9
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 13
# 30 10
# 30 9
# 30 9
# 58679.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_584729215_584815615/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_585420415_585505954/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_585334015_585420415/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_584815615_584902015/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_585074815_585161215/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_584383615_584470015/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_584470015_584556415/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_584642815_584729215/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_584988415_585074815/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_585247615_585334015/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_584556415_584642815/4fgl_j1833.6-2103_sed.fits
# 30 9
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_584902015_584988415/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58679.7/1days/lightcurve_585161215_585247615/4fgl_j1833.6-2103_sed.fits
# 30 9
# 58539.7
# 14
# 30 10
# 30 13
# 30 11
# 30 8
# 30 11
# 30 11
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 12
# 30 8
# 30 11
# 30 12
# 30 9
# 30 12
# 59687.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59687.7/1days/lightcurve_671820415_671906815/4fgl_j1833.6-2103_sed.fits
# 30 12
# 30 13
# 30 5
# 30 1
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59687.7/1days/lightcurve_672079615_672166015/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59687.7/1days/lightcurve_671474815_671561215/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 9
# 30 3
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59687.7/1days/lightcurve_671734015_671820415/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 1
# 58889.7
# 14
# 30 4
# 30 4
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58889.7/1days/lightcurve_602441215_602527615/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 3
# 30 3
# 30 1
# 30 5
# 30 7
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58889.7/1days/lightcurve_602614015_602700415/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 3
# 30 3
# 30 4
# 59141.7
# 14
# 30 0
# 30 0
# 30 0
# 30 1
# 30 1
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59141.7/1days/lightcurve_625337215_625423615/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59141.7/1days/lightcurve_624473215_624559615/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 0
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59141.7/1days/lightcurve_624646015_624732415/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# 58483.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58483.7/1days/lightcurve_567449215_567535615/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58483.7/1days/lightcurve_568226815_568313215/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58483.7/1days/lightcurve_568486015_568571868/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 6
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58483.7/1days/lightcurve_567794815_567881215/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58483.7/1days/lightcurve_567535615_567622015/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 4
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58483.7/1days/lightcurve_567708415_567794815/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58483.7/1days/lightcurve_567362815_567449215/4fgl_j1833.6-2103_sed.fits
# 30 0
# 59827.7
# 14
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59827.7/1days/lightcurve_683830015_683916415/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 3
# 30 3
# 30 5
# 30 0
# 30 6
# 30 3
# 30 7
# 30 1
# 30 2
# 30 12
# 30 6
# 30 6
# 58861.7
# 14
# 30 4
# 30 4
# 30 5
# 30 2
# 30 6
# 30 0
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58861.7/1days/lightcurve_600972415_601058815/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 3
# 30 6
# 30 6
# 30 5
# 30 2
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58861.7/1days/lightcurve_600022015_600108415/4fgl_j1833.6-2103_sed.fits
# 30 4
# 58917.7
# 14
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58917.7/1days/lightcurve_605206015_605292415/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58917.7/1days/lightcurve_605465215_605551615/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 3
# 30 2
# 30 3
# 30 2
# 30 2
# 30 4
# 30 2
# 30 3
# 30 2
# 60765.7
# 14
# 30 4
# 30 2
# 30 6
# 30 2
# 30 3
# 30 7
# 30 2
# 30 1
# 30 0
# 30 2
# 30 2
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/60765.7/1days/lightcurve_765132415_765218815/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 1
# 58833.7
# 14
# 30 13
# 30 10
# 30 9
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58833.7/1days/lightcurve_598553215_598639615/4fgl_j1833.6-2103_sed.fits
# 30 13
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58833.7/1days/lightcurve_598466815_598553215/4fgl_j1833.6-2103_sed.fits
# 30 13
# 30 10
# 30 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58833.7/1days/lightcurve_598380415_598466815/4fgl_j1833.6-2103_sed.fits
# 30 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58833.7/1days/lightcurve_598726015_598812415/4fgl_j1833.6-2103_sed.fits
# 30 14
# 30 5
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58833.7/1days/lightcurve_598639615_598726015/4fgl_j1833.6-2103_sed.fits
# 30 11
# 58777.7
# 14
# 30 5
# 30 8
# 30 8
# 30 6
# 30 5
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58777.7/1days/lightcurve_593196415_593282815/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 3
# 30 5
# 30 11
# 30 3
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 2
# 30 8
# 30 9
# 58469.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_566239615_566326015/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_566930815_567017215/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_566585215_566671615/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_567103615_567190015/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_566412415_566498815/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_566671615_566758015/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_567190015_567276415/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_566758015_566844415/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_566844415_566930815/4fgl_j1833.6-2103_sed.fits
# 30 9
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_566498815_566585215/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_567017215_567103615/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_566153215_566239615/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58469.7/1days/lightcurve_567276415_567362815/4fgl_j1833.6-2103_sed.fits
# 30 0
# 58791.7
# 14
# 30 11
# 30 12
# 30 7
# 30 11
# 30 10
# 30 14
# 30 12
# 30 4
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 15
# 30 9
# 30 9
# 30 7
# 55557.7
# 14
# 30 6
# 30 12
# 30 2
# 30 10
# 30 7
# 30 14
# 30 3
# 30 5
# 30 10
# 30 10
# 30 5
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 10
# 60779.7
# 14
# 30 6
# 30 1
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/60779.7/1days/lightcurve_765910015_765996415/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 6
# 30 0
# 30 1
# 30 5
# 30 3
# 30 4
# 30 3
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/60779.7/1days/lightcurve_766082815_766169215/4fgl_j1833.6-2103_sed.fits
# 30 6
# 30 5
# 58385.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58385.7/1days/lightcurve_559068415_559154815/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58385.7/1days/lightcurve_558982015_559068415/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58385.7/1days/lightcurve_559327615_559414015/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58385.7/1days/lightcurve_559414015_559500415/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58385.7/1days/lightcurve_559500415_559586815/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58385.7/1days/lightcurve_559154815_559241215/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58385.7/1days/lightcurve_558895615_558982015/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58385.7/1days/lightcurve_559241215_559327615/4fgl_j1833.6-2103_sed.fits
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58385.7/1days/lightcurve_559846015_559932415/4fgl_j1833.6-2103_sed.fits
# 30 3
# 58693.7
# 14
# 30 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58693.7/1days/lightcurve_585679615_585766015/4fgl_j1833.6-2103_sed.fits
# 30 14
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58693.7/1days/lightcurve_586025215_586111615/4fgl_j1833.6-2103_sed.fits
# 30 10
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58693.7/1days/lightcurve_585852415_585938815/4fgl_j1833.6-2103_sed.fits
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58693.7/1days/lightcurve_585593215_585679615/4fgl_j1833.6-2103_sed.fits
# 30 11
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58693.7/1days/lightcurve_585938815_586025215/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58693.7/1days/lightcurve_585506815_585593215/4fgl_j1833.6-2103_sed.fits
# 30 13
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58693.7/1days/lightcurve_586370815_586457215/4fgl_j1833.6-2103_sed.fits
# 30 12
# 30 11
# 59925.7
# 14
# 30 4
# 30 11
# 30 9
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 13
# 30 4
# 30 7
# 30 4
# 30 1
# 30 7
# 30 14
# 30 6
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59925.7/1days/lightcurve_692902015_692988415/4fgl_j1833.6-2103_sed.fits
# 30 7
# 58763.7
# 14
# 30 14
# 30 6
# 30 10
# 30 14
# 30 10
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 7
# 30 10
# 30 9
# 30 11
# 30 11
# 30 11
# 30 9
# 55487.7
# 14
# 30 10
# 30 7
# 30 12
# 30 3
# 30 7
# 30 5
# 30 6
# 30 5
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 4
# 30 4
# 30 13
# 30 7
# 30 10
# 30 5
# 58497.7
# 14
# 30 4
# 30 11
# 30 13
# 30 10
# 30 12
# 30 13
# 30 13
# 30 10
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 11
# 30 8
# 30 13
# 30 10
# 58721.7
# 14
# 30 11
# 30 12
# 30 8
# 30 11
# 30 11
# 30 9
# 30 9
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 10
# 30 11
# 30 10
# 30 10
# 30 11
# 58623.7
# 14
# 30 8
# 30 16
# 30 10
# 30 10
# 30 13
# 30 13
# 30 14
# 30 0
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58623.7/1days/lightcurve_580495615_580582015/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 14
# 30 12
# 30 14
# 30 15
# 30 12
# 59869.7
# 14
# 30 4
# 30 9
# 30 4
# 30 8
# 30 2
# 30 7
# 30 2
# 30 7
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59869.7/1days/lightcurve_688150015_688236415/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 2
# 30 11
# 30 9
# 30 6
# 59841.7
# 14
# 30 11
# 30 11
# 30 8
# 30 12
# 30 13
# 30 11
# 30 8
# 30 13
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 6
# 30 12
# 30 8
# 30 9
# 58441.7
# 14
# 30 5
# 30 5
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58441.7/1days/lightcurve_563820415_563906815/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 0
# 30 5
# 30 0
# 30 8
# 30 3
# 30 0
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58441.7/1days/lightcurve_564166015_564252415/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 5
# 30 4
# 58735.7
# 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 17
# 30 9
# 30 13
# 30 12
# 30 11
# 30 15
# 30 10
# 30 16
# 30 10
# 30 15
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 13
# 58805.7
# 14
# 30 12
# 30 11
# 30 10
# 30 11
# 30 8
# 30 8
# 30 13
# 30 7
# 30 9
# 30 7
# 30 9
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 13
# 58427.7
# 14
# 30 2
# 30 10
# 30 4
# 30 2
# 30 1
# 30 5
# 30 5
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58427.7/1days/lightcurve_562610815_562697215/4fgl_j1833.6-2103_sed.fits
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58427.7/1days/lightcurve_563388415_563474815/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 5
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58427.7/1days/lightcurve_562524415_562610815/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 6
# 58903.7
# 14
# 30 8
# 30 5
# 30 3
# 30 6
# 30 6
# 30 9
# 30 4
# 30 11
# 30 8
# 30 3
# 30 8
# 30 5
# 30 5
# 30 7
# 59757.7
# 14
# 30 3
# 30 0
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59757.7/1days/lightcurve_677522815_677609215/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59757.7/1days/lightcurve_677695615_677782015/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 2
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59757.7/1days/lightcurve_677782015_677868415/4fgl_j1833.6-2103_sed.fits
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59757.7/1days/lightcurve_677436415_677522815/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 0
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59757.7/1days/lightcurve_678473215_678559615/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 1
# 58707.7
# 14
# 30 13
# 30 12
# 30 9
# 30 12
# 30 9
# 30 6
# 30 11
# 30 14
# 30 13
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58707.7/1days/lightcurve_587753215_587839615/4fgl_j1833.6-2103_sed.fits
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 14
# 30 11
# 59799.7
# 14
# 30 4
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59799.7/1days/lightcurve_681410815_681497215/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 5
# 30 5
# 30 1
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59799.7/1days/lightcurve_681670015_681756415/4fgl_j1833.6-2103_sed.fits
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59799.7/1days/lightcurve_681065215_681151615/4fgl_j1833.6-2103_sed.fits
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59799.7/1days/lightcurve_681324415_681410815/4fgl_j1833.6-2103_sed.fits
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59799.7/1days/lightcurve_681583615_681670015/4fgl_j1833.6-2103_sed.fits
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59799.7/1days/lightcurve_681151615_681238015/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59799.7/1days/lightcurve_681238015_681324415/4fgl_j1833.6-2103_sed.fits
# 30 7
# 59127.7
# 14
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59127.7/1days/lightcurve_623954815_624041215/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 1
# 30 4
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59127.7/1days/lightcurve_623263615_623350015/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 2
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59127.7/1days/lightcurve_623782015_623868415/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 2
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59127.7/1days/lightcurve_624041215_624127615/4fgl_j1833.6-2103_sed.fits
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59127.7/1days/lightcurve_623868415_623954815/4fgl_j1833.6-2103_sed.fits
# 30 4
# 58553.7
# 14
# 30 11
# 30 11
# 30 9
# 30 12
# 30 13
# 30 5
# 30 7
# 30 12
# 30 10
# 30 9
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 7
# 30 9
# 55529.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/55529.7/1days/lightcurve_312569215_312655615/4fgl_j1833.6-2103_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/55529.7/1days/lightcurve_312482815_312569215/4fgl_j1833.6-2103_sed.fits
# 30 9
# 30 1
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/55529.7/1days/lightcurve_313260415_313346655/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/55529.7/1days/lightcurve_312137215_312223615/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 2
# 30 1
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/55529.7/1days/lightcurve_312914815_313001215/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/55529.7/1days/lightcurve_312396415_312482815/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 4
# 59897.7
# 14
# 30 11
# 30 6
# 30 9
# 30 11
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 6
# 30 13
# 30 11
# 30 10
# 30 11
# 30 12
# 30 13
# 30 12
# 55473.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/55473.7/1days/lightcurve_307730815_307817215/4fgl_j1833.6-2103_sed.fits
# 30 12
# 30 3
# 30 4
# 30 6
# 30 0
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/55473.7/1days/lightcurve_307298815_307385215/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 4
# 30 3
# 30 4
# 30 6
# 30 1
# 30 0
# 30 4
# 59939.7
# 14
# 30 1
# 30 4
# 30 1
# 30 1
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59939.7/1days/lightcurve_694284415_694370815/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 3
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59939.7/1days/lightcurve_694025215_694111615/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59939.7/1days/lightcurve_693852415_693938815/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59939.7/1days/lightcurve_694198015_694284415/4fgl_j1833.6-2103_sed.fits
# 30 6
# 30 1
# 58749.7
# 14
# 30 11
# 30 12
# 30 12
# 30 14
# 30 15
# 30 13
# 30 13
# 30 12
# 30 10
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 13
# 30 11
# 30 12
# 58511.7
# 14
# 30 10
# 30 4
# 30 6
# 30 4
# 30 6
# 30 11
# 30 14
# 30 2
# 30 9
# 30 6
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 1
# 30 11
# 30 11
# 58875.7
# 14
# 30 7
# 30 1
# 30 3
# 30 5
# 30 3
# 30 5
# 30 2
# 30 5
# 30 2
# 30 4
# 30 6
# 30 1
# 30 5
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 2
# 58651.7
# 14
# 30 8
# 30 10
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58651.7/1days/lightcurve_581964415_582050815/4fgl_j1833.6-2103_sed.fits
# 30 10
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58651.7/1days/lightcurve_582050815_582137215/4fgl_j1833.6-2103_sed.fits
# 30 10
# 30 10
# 30 7
# 30 10
# 30 7
# 30 4
# 30 10
# 30 1
# 30 9
# 59911.7
# 14
# 30 13
# 30 6
# 30 4
# 30 3
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 3
# 30 6
# 30 6
# 30 12
# 30 4
# 30 4
# 30 8
# 30 9
# 30 4
# 58567.7
# 14
# 30 10
# 30 12
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 14
# 30 11
# 30 12
# 30 12
# 30 13
# 30 12
# 30 13
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 14
# 59099.7
# 14
# 30 3
# 30 5
# 30 3
# 30 0
# 30 1
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59099.7/1days/lightcurve_620585215_620671615/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59099.7/1days/lightcurve_621276415_621362815/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 2
# 30 4
# 30 6
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59099.7/1days/lightcurve_620671615_620758015/4fgl_j1833.6-2103_sed.fits
# 30 2
# 56075.7
# 14
# 30 6
# 30 5
# 30 2
# 30 2
# 30 5
# 30 2
# 30 9
# 30 7
# 30 3
# 30 6
# 30 4
# 30 5
# 30 3
# 30 9
# 55501.7
# 14
# 30 7
# 30 5
# 30 8
# 30 10
# 30 5
# 30 6
# 30 8
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 7
# 30 10
# 30 10
# 30 8
# 30 12
# 58399.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58399.7/1days/lightcurve_560278015_560364415/4fgl_j1833.6-2103_sed.fits
# 30 12
# 30 1
# 30 2
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58399.7/1days/lightcurve_560364415_560450815/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58399.7/1days/lightcurve_560191615_560278015/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 3
# 30 5
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58399.7/1days/lightcurve_560105215_560191615/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58399.7/1days/lightcurve_560710015_560796415/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 56089.7
# 14
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 13
# 30 11
# 30 6
# 30 12
# 30 11
# 30 12
# 30 12
# 30 9
# 30 11
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 8
# 56145.7
# 14
# 30 1
# 30 7
# 30 8
# 30 4
# 30 4
# 30 2
# 30 6
# 30 3
# 30 5
# 30 8
# 30 3
# 30 10
# 30 8
# 30 2
# 56061.7
# 14
# 30 7
# 30 1
# 30 9
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/56061.7/1days/lightcurve_359138815_359225215/4fgl_j1833.6-2103_sed.fits
# 30 7
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/56061.7/1days/lightcurve_358188415_358274815/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 5
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/56061.7/1days/lightcurve_359225215_359311615/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/56061.7/1days/lightcurve_358534015_358620415/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 1
# 58525.7
# 14
# 30 8
# 30 11
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 12
# 30 6
# 30 4
# 30 12
# 30 2
# 30 9
# 30 11
# 30 7
# 30 9
# 30 9
# 58581.7
# 14
# 30 14
# 30 15
# 30 17
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 17
# 30 19
# 30 14
# 30 15
# 30 14
# 30 16
# 30 14
# 30 15
# 30 15
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 56159.7
# 14
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/56159.7/1days/lightcurve_366569215_366655615/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 0
# 30 2
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/56159.7/1days/lightcurve_367433215_367519615/4fgl_j1833.6-2103_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/56159.7/1days/lightcurve_367087615_367174015/4fgl_j1833.6-2103_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/56159.7/1days/lightcurve_367692415_367778815/4fgl_j1833.6-2103_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/56159.7/1days/lightcurve_367001215_367087615/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 3
# 30 0
# 30 2
# 59085.7
# 14
# 30 2
# 30 0
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59085.7/1days/lightcurve_620326015_620412415/4fgl_j1833.6-2103_sed.fits
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59085.7/1days/lightcurve_620066815_620153215/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 0
# 30 1
# 30 2
# 30 1
# 30 3
# 30 1
# 30 1
# 30 2
# 30 1
# 60723.7
# 14
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/60723.7/1days/lightcurve_761071615_761158015/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 8
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/60723.7/1days/lightcurve_761158015_761244415/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 0
# 30 6
# 30 10
# 30 6
# 30 6
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/60723.7/1days/lightcurve_761935615_762022015/4fgl_j1833.6-2103_sed.fits
# 30 11
# 30 3
# 30 5
# 58413.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58413.7/1days/lightcurve_562438015_562524415/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 8
# 30 5
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58413.7/1days/lightcurve_562178815_562265215/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 11
# 30 9
# 30 7
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58413.7/1days/lightcurve_562351615_562438015/4fgl_j1833.6-2103_sed.fits
# 30 9
# 30 4
# 30 10
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58413.7/1days/lightcurve_562265215_562351615/4fgl_j1833.6-2103_sed.fits
# 30 10
# 30 5
# 30 11
# 59715.7
# 14
# 30 3
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59715.7/1days/lightcurve_674498815_674585215/4fgl_j1833.6-2103_sed.fits
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59715.7/1days/lightcurve_674930815_675017215/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 1
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59715.7/1days/lightcurve_674671615_674758015/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 1
# 30 2
# 30 0
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59715.7/1days/lightcurve_674326015_674412415/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 4
# 59701.7
# 14
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59701.7/1days/lightcurve_672857215_672943615/4fgl_j1833.6-2103_sed.fits
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59701.7/1days/lightcurve_673721215_673806634/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 0
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59701.7/1days/lightcurve_672770815_672857215/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 4
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59701.7/1days/lightcurve_673462015_673548415/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59701.7/1days/lightcurve_673289215_673375615/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59701.7/1days/lightcurve_673634815_673721215/4fgl_j1833.6-2103_sed.fits
# 30 0
# 59771.7
# 14
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59771.7/1days/lightcurve_679596415_679682815/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59771.7/1days/lightcurve_678646015_678732415/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 1
# 30 1
# 30 0
# 30 2
# 30 1
# 30 1
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59771.7/1days/lightcurve_679078015_679164415/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# 58819.7
# 14
# 30 2
# 30 9
# 30 9
# 30 2
# 30 5
# 30 10
# 30 3
# 30 7
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58819.7/1days/lightcurve_596393215_596479615/4fgl_j1833.6-2103_sed.fits
# 30 7
# 30 4
# 30 5
# 30 11
# 30 4
# 55571.7
# 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/55571.7/1days/lightcurve_316198015_316284415/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/55571.7/1days/lightcurve_316543615_316630015/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/55571.7/1days/lightcurve_316716415_316802815/4fgl_j1833.6-2103_sed.fits
# 30 8
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/55571.7/1days/lightcurve_316370815_316457215/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 1
# 30 3
# 30 2
# 30 2
# 30 0
# 59785.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59785.7/1days/lightcurve_680546815_680633215/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59785.7/1days/lightcurve_680287615_680374015/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59785.7/1days/lightcurve_680806015_680892415/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59785.7/1days/lightcurve_680719615_680806015/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59785.7/1days/lightcurve_680460415_680546815/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59785.7/1days/lightcurve_680374015_680460415/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59785.7/1days/lightcurve_680892415_680978815/4fgl_j1833.6-2103_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59785.7/1days/lightcurve_680978815_681065215/4fgl_j1833.6-2103_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59785.7/1days/lightcurve_680633215_680719615/4fgl_j1833.6-2103_sed.fits
# 30 2
# 58931.7
# 14
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58931.7/1days/lightcurve_606329215_606415615/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 4
# 30 2
# 30 3
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58931.7/1days/lightcurve_606502015_606588415/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 2
# 30 1
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58931.7/1days/lightcurve_607106815_607193215/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 1
# 30 1
# 30 3
# 59813.7
# 14
# 30 2
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59813.7/1days/lightcurve_683225215_683311615/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 1
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59813.7/1days/lightcurve_682966015_683052415/4fgl_j1833.6-2103_sed.fits
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/59813.7/1days/lightcurve_683398015_683484415/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 1
# 30 4
# 30 4
# 30 3
# 30 6
# 30 3
# 30 2
# 58455.7
# 14
# 30 8
# 30 8
# 30 7
# 30 5
# 30 6
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58455.7/1days/lightcurve_565894015_565980415/4fgl_j1833.6-2103_sed.fits
# 30 9
# 30 8
# 30 15
# 30 9
# 30 5
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/069_PKS1830-211_1d/58455.7/1days/lightcurve_566066815_566153215/4fgl_j1833.6-2103_sed.fits
# 30 12
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]

# %%
print('Number of significant SEDs:',n_significant_sed)
# Out:
# Number of significant SEDs: 243

# %%
print(table_allSEDs.colnames)
# Out:
# ['e_min', 'e_ref', 'e_max', 'ref_dnde_e_min', 'ref_dnde_e_max', 'ref_dnde', 'ref_flux', 'ref_eflux', 'ref_npred', 'dnde', 'dnde_err', 'dnde_errp', 'dnde_errn', 'dnde_ul', 'e2dnde', 'e2dnde_err', 'e2dnde_errp', 'e2dnde_errn', 'e2dnde_ul', 'norm', 'norm_err', 'norm_errp', 'norm_errn', 'norm_ul', 'ts', 'loglike', 'norm_scan', 'dloglike_scan', 'ShowUL', 'tstart', 'tend']

# %%
table_allSEDs
# Out:
# <Table length=3067>
#       e_min              e_ref        ...       tstart              tend
#        MeV                MeV         ...
#      float64            float64       ...      float64            float64
# ------------------ ------------------ ... ------------------ ------------------
#              100.0 115.25240587974294 ... 58612.699990555186 58613.699990555186
# 132.83117061068992   153.091119887046 ... 58612.699990555186 58613.699990555186
#  176.4411988580621 203.35272664697808 ... 58612.699990555186 58613.699990555186
# 234.36890988269914  270.1158072739371 ... 58612.699990555186 58613.699990555186
#  311.3149665447022  358.7979888064861 ... 58612.699990555186 58613.699990555186
# 413.52331434760555  476.5900816815941 ... 58612.699990555186 58613.699990555186
#  549.2752115212968  633.0528961793416 ... 58612.699990555186 58613.699990555186
#  729.6086933380817  840.8915725798939 ... 58612.699990555186 58613.699990555186
#  969.1477682383326 1116.9661194245136 ... 58612.699990555186 58613.699990555186
#                ...                ... ...                ...                ...
# 234.36890988269914  270.1158072739371 ... 58461.699990555186 58462.699990555186
#  311.3149665447022  358.7979888064861 ... 58461.699990555186 58462.699990555186
# 413.52331434760555  476.5900816815941 ... 58461.699990555186 58462.699990555186
#  549.2752115212968  633.0528961793416 ... 58461.699990555186 58462.699990555186
#  729.6086933380817  840.8915725798939 ... 58461.699990555186 58462.699990555186
#  969.1477682383326 1116.9661194245136 ... 58461.699990555186 58462.699990555186
# 2271.3810595726877  2617.821317854317 ... 58461.699990555186 58462.699990555186
# 3017.1020504598932 3477.2827010020824 ... 58461.699990555186 58462.699990555186
#  5323.411028602609  6135.359285332078 ... 58461.699990555186 58462.699990555186
#  9392.473966813408  10825.05221838098 ... 58461.699990555186 58462.699990555186

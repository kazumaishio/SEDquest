# %%
import gammapy
import math
from gammapy import maps
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
from astropy.io import ascii
data = ascii.read("collarea_magic.txt", delimiter=',')  
data
# Out:
# <Table length=29>
# lowedge  center content   error
# float64 float64 float64  float64
# ------- ------- -------- -------
# 31.6228 35.7167  46.1821 16.6172
# 39.8107 44.9647  895.357 75.5615
# 50.1187 56.6072  5182.16 183.965
# 63.0957 71.2643  14463.3 314.639
# 79.4328 89.7164  24011.9  415.15
#   100.0 112.946  30839.8  497.46
# 125.893 142.191  39008.1 593.806
# 158.489 179.008  45597.8 686.187
# 199.526 225.357  54720.1 792.559
# 251.189 283.708  68400.8 961.595
#     ...     ...      ...     ...
# 2511.89 2837.08 138532.0 2584.14
# 3162.28 3571.67 136425.0 2753.96
# 3981.07 4496.47 142475.0 3029.32
# 5011.87 5660.72 139143.0 3197.49
# 6309.57 7126.43 144148.0 3513.65
# 7943.28 8971.64 143264.0  3794.6
# 10000.0 11294.6 145579.0  4023.0
# 12589.3 14219.1 146763.0 4216.18
# 15848.9 17900.8 145941.0 4300.89
# 25118.9      --       --      --

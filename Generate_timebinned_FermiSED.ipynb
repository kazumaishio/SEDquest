# %% [markdown]
# # Make an ecsv file which contains SEDs of all periods with significant number of data points
#
# From
# `/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/Generate_timebinned_MWLSED.ipynb`
#
#
# `/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days`
# Number of significant SEDs: 264
#
# `home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days`
# Number of significant SEDs: 208

# %%
import os

# # 3C454.3
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# '/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days/{directoryname}/4fgl_j2253.9+1609_sed.fits'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # S20109+22 Number of significant SEDs: 58
# # S20109+22 = 4fgl_j0112.1+2245
# # Number of significant SEDs: 58
# source_name='S20109+22'
# source_name_4fgl='4fgl_j0112.1+2245'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/5_S20109+22_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 8_PKS1510-089_100MeV_14d Number of significant SEDs: 214
# # PKS1510-089 = 4fgl_j1512.8-0906
# # Number of significant SEDs: 40
# source_name='PKS1510-089'
# source_name_4fgl='4fgl_j1512.8-0906'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/8_PKS1510-089_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 9_4C+21.35_100MeV_14d Number of significant SEDs: 103
# # 4C+21.35 = 4fgl_j1224.9+2122
# source_name='4C+21.35'
# source_name_4fgl='4fgl_j1224.9+2122'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/9_4C+21.35_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 10_Mrk421_100MeV_14d Number of significant SEDs: 403
# # 4C+21.35 = 4fgl_j1224.9+2122
# source_name='Mrk421'
# source_name_4fgl='4fgl_j1104.4+3812'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 11_CTA102_100MeV_14d Number of significant SEDs: 180
# # CTA102 = 4fgl_j2232.6+1143s
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/11_CTA102_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# print(sed_path_test)

# # 13 3C454.3  Number of significant SEDs: 566
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/13_3C454_100MeV_1d_first1050days/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'
# '/home/kazuma/Workspace/AGN_data/13_3C454_100MeV_1d_first1050days/1days/{directoryname}/4fgl_j2253.9+1609_sed.fits'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 12_BLLac_100MeV_14d Number of significant SEDs: 298
# # BLLac = 4fgl_j2202.7+4216
# source_name='BLLac'
# source_name_4fgl='4fgl_j2202.7+4216'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/12_BLLac_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# print(sed_path_test)

# # 12_BLLac_100MeV_1d_1 Number of significant SEDs: 176
# # BLLac = 4fgl_j2202.7+4216
# source_name='BLLac'
# source_name_4fgl='4fgl_j2202.7+4216'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/12_BLLac_100MeV_1d_1/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_1_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# print(sed_path_test)

# # 12_BLLac_100MeV_1d_2 Number of significant SEDs: 115
# # BLLac = 4fgl_j2202.7+4216
# source_name='BLLac'
# source_name_4fgl='4fgl_j2202.7+4216'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/12_BLLac_100MeV_1d_2/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_2_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# print(sed_path_test)


# # 14_3C279_100MeV_14d Number of significant SEDs: 261
# # 3C279 = 4fgl_j1256.1-0547
# source_name='3C279'
# source_name_4fgl='4fgl_j1256.1-0547'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/14_3C279_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# print(sed_path_test)

# # 14_3C279_100MeV_1d_1 Number of significant SEDs: 46
# # 3C279 = 4fgl_j1256.1-0547
# source_name='3C279'
# source_name_4fgl='4fgl_j1256.1-0547'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_1/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_1_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# print(sed_path_test)

# 14_3C279_100MeV_1d_2 Number of significant SEDs: 184
# 3C279 = 4fgl_j1256.1-0547
source_name='3C279'
source_name_4fgl='4fgl_j1256.1-0547'
input_directory_parent='/home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days'
directoryname_test='lightcurve_xxx_xxx'
sed_filename=f'{source_name_4fgl}_sed.fits'
outfilename=f'{source_name}_allsed_1d_2_min11.ecsv'
sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
print(sed_path_test)

# # 15_3C454_100MeV_1d_second1150days Number of significant SEDs: 468
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/15_3C454_100MeV_1d_second1150days/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_2_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 16_S50716+71_100MeV_14d  Number of significant SEDs: 285
# # S50716+71 = 4fgl_j0721.9+7120
# source_name='S50716+71'
# source_name_4fgl='4fgl_j0721.9+7120'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/16_S50716+71_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 17_PKS1424-41_100MeV_14d Number of significant SEDs: 299
# # PKS1424-41 = 4fgl_j1427.9-4206
# source_name='PKS1424-41'
# source_name_4fgl='4fgl_j1427.9-4206'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/17_PKS1424-41_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 18_PKS0426-380_100MeV_14d Number of significant SEDs: 189
# # PKS0426-380 = 4fgl_j0428.6-3756
# source_name='PKS0426-380'
# source_name_4fgl='4fgl_j0428.6-3756'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/18_PKS0426-380_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 19_PKS0537-441_100MeV_14d Number of significant SEDs: 224
# # PKS0537-441 = 4fgl_j0538.8-4405
# source_name='PKS0537-441'
# source_name_4fgl='4fgl_j0538.8-4405'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/19_PKS0537-441_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 20_PKS2155-304_100MeV_14d Number of significant SEDs: 166
# # PKS2155-304 = 4fgl_j2158.8-3013
# source_name='PKS2155-304'
# source_name_4fgl='4fgl_j2158.8-3013'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/20_PKS2155-304_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 21_PKS0454-234_100MeV_14d Number of significant SEDs: 242
# # PKS0454-234 = 4fgl_j0457.0-2324
# source_name='PKS0454-234'
# source_name_4fgl='4fgl_j0457.0-2324'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/21_PKS0454-234_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 22_PKS1502+106_100MeV_14d Number of significant SEDs: 147
# # PKS1502+106 = 4fgl_j1504.4+1029
# source_name='PKS1502+106'
# source_name_4fgl='4fgl_j1504.4+1029'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/22_PKS1502+106_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 23_Ton599_100MeV_14d Number of significant SEDs: 186
# # Ton599 = 4fgl_j1159.5+2914
# source_name='Ton599'
# source_name_4fgl='4fgl_j1159.5+2914'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/23_Ton599_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 24_4C+55.17_100MeV_14d  Number of significant SEDs: 57
# # 4C+55.17 = 4fgl_j0957.6+5523
# source_name='4C+55.17'
# source_name_4fgl='4fgl_j0957.6+5523'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/24_4C+55.17_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 25_PKS0346-27_100MeV_14d Number of significant SEDs: 111
# # PKS0346-27 = 4fgl_j0348.5-2749
# source_name='PKS0346-27'
# source_name_4fgl='4fgl_j0348.5-2749'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/25_PKS0346-27_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 26_4C+01.02_100MeV_14d Number of significant SEDs: 158
# # 4C+01.02 = 4fgl_j0108.6+0134
# source_name='4C+01.02'
# source_name_4fgl='4fgl_j0108.6+0134'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/26_4C+01.02_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 27_PKS1830-211_100MeV_14d Number of significant SEDs: 117
# # PKS1830-211 = 4fgl_j1833.6-2103
# source_name='PKS1830-211'
# source_name_4fgl='4fgl_j1833.6-2103'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 27_PKS1830-211_100MeV_1d Number of significant SEDs: 170
# # PKS1830-211 = 4fgl_j1833.6-2103
# source_name='PKS1830-211'
# source_name_4fgl='4fgl_j1833.6-2103'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 27_PKS1830-211_100MeV_1d_1  Number of significant SEDs: 168
# # PKS1830-211 = 4fgl_j1833.6-2103
# source_name='PKS1830-211'
# source_name_4fgl='4fgl_j1833.6-2103'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_1_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 27_PKS1830-211_100MeV_1d_2  Number of significant SEDs: 27
# # PKS1830-211 = 4fgl_j1833.6-2103
# source_name='PKS1830-211'
# source_name_4fgl='4fgl_j1833.6-2103'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_2/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_2_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 28_PKS0208-512_100MeV_14d Number of significant SEDs: 94
# # PKS0208-512 = 4fgl_j0210.7-5101
# source_name='PKS0208-512'
# source_name_4fgl='4fgl_j0210.7-5101'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/28_PKS0208-512_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_1d Number of significant SEDs: 1
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_1d/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_1h Number of significant SEDs: 2
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_1h/0.041666666666666664days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1h_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_2h Number of significant SEDs: 2
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_2h/0.08333333333333333days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_2h_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_30min Number of significant SEDs: 2
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_30min/0.020833333333333332days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_30min_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_10min Number of significant SEDs: 2
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_10min/0.006944444444444444days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_10min_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_2min Number of significant SEDs: 2
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_2min/0.0013888888888888887days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_2min_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# 30_CTA102_100MeV_1d Number of significant SEDs: 0
# # CTA102 = 4fgl_j2232.6+1143
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_1_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 30_CTA102_100MeV_1d_2 Number of significant SEDs: 265
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_2_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 30_CTA102_100MeV_1d_3 Number of significant SEDs: 97
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_3/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_3_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 30_CTA102_100MeV_7d Number of significant SEDs: 226
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_7d/7days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_7d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# Out:
# /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_xxx_xxx/4fgl_j1256.1-0547_sed.fits

# %%
####################################################################
# for Inline animations in Jupyter
# https://stackoverflow.com/questions/43445103/inline-animations-in-jupyter
####################################################################
# Enable interactive plot
# %matplotlib notebook

import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import os

####################################################################
# Functions
####################################################################
##################################
# 
##################################
def met_to_mjd(met) :
    mjd = 51910. + 7.4287e-4 + met/86400.
    return mjd
# print(mjd_start, mjd_end)
# print(met_to_mjd(mjd_start), met_to_mjd(mjd_end))
##################################
#  GET fermi SED table from fits file
##################################
from astropy.table import Table
def getsed(timebin_start,timebin_end):
    # print(directories)
    directoryname=f'lightcurve_{timebin_start}_{timebin_end}'
    sed_path=os.path.join(input_directory_parent,directoryname,sed_filename )
    try : 
        sed_tab= Table.read(sed_path)
        # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
        # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
        return sed_tab
    except:
        print('not found: ', sed_path)    
        return None

from astropy import units as u
from astropy.io import ascii

# %%
mjd_min=45000#55000
mjd_max=65000#56000

##################################
# Get subdirectories within time scope
directories=os.listdir(input_directory_parent)
# directories=os.listdir('/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days')
timebins_start=[]
timebins_end=[]
for directoryname in directories:
    elements=directoryname.split('_')
    timebin_start=met_to_mjd(float(elements[1]))
    timebin_end=met_to_mjd(float(elements[2]))
#     print(elements[1],elements[2])
#     print(timebin_start, timebin_end)
    if timebin_end>mjd_max*1.0001 :
        continue        
    if timebin_start<mjd_min*0.9999 :
        continue
    timebins_start.append(int(elements[1]))
    timebins_end.append(int(elements[2]))

timebins_start.sort()
timebins_end.sort()
print(timebins_start[0], timebins_end[-1])
print('Which are {} and {}'.format(mjd_min,mjd_max))
print(met_to_mjd(timebins_start[0]), met_to_mjd(timebins_end[-1]))
# Out:
# 510451135 576979135
# Which are 45000 and 65000
# 57817.99999055518 58587.99999055518

# %%
##################################
# Get Fermi SED
##################################
n_significant_sed=0
for i in range(len(timebins_start)):
    timebin_start=timebins_start[i]
    timebin_end=timebins_end[i]
    sed_tab=getsed(timebin_start,timebin_end)
    if sed_tab is None:
        continue

    default_eref=sed_tab['e_ref']
    default_flux=np.ones(len(default_eref))*1e-4
    default_asymmerr=[np.ones(len(default_eref))*1e-5,np.ones(len(default_eref))*1e-5]

    default_errdiff=np.ones(len(default_eref))
    default_ts=np.ones(len(default_eref))*0.1
    high_significance_mask = (sed_tab['ts']>=9)
    low_significance_mask = (sed_tab['ts']<9)
    sed_tab['ShowUL']=low_significance_mask
    sed_tab_significant=sed_tab[high_significance_mask]
    sed_tab_nosignificant=sed_tab[low_significance_mask]
    print(len(sed_tab['e_ref']),len(sed_tab_significant['e_ref']))
    if len(sed_tab_significant['e_ref'])>=11:
        n_significant_sed+=1
    # print(len(sed_tab_nosignificant['e_ref']),len(sed_tab_nosignificant['e2dnde_ul']))
    # print(sed_tab_nosignificant['e_ref'],sed_tab_nosignificant['e2dnde_ul'])

print('Number of significant SEDs:',n_significant_sed)
# Out:
# 30 2
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_510623935_510710335/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 6
# 30 3
# 30 2
# 30 7
# 30 10
# 30 14
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 7
# 30 5
# 30 7
# 30 12
# 30 14
# 30 13
# 30 13
# 30 5
# 30 4
# 30 3
# 30 5
# 30 16
# 30 13
# 30 15
# 30 13
# 30 12
# 30 9
# 30 16
# 30 17
# 30 16
# 30 15
# 30 16
# 30 12
# 30 6
# 30 4
# 30 3
# 30 7
# 30 8
# 30 7
# 30 2
# 30 8
# 30 6
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_514339135_514425535/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_514598335_514684735/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 1
# 30 3
# 30 3
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_515116735_515203135/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 4
# 30 2
# 30 2
# 30 4
# 30 3
# 30 9
# 30 6
# 30 6
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_516067135_516153535/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 8
# 30 9
# 30 12
# 30 10
# 30 9
# 30 10
# 30 9
# 30 14
# 30 15
# 30 10
# 30 8
# 30 7
# 30 5
# 30 4
# 30 5
# 30 10
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_517708735_517795135/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 3
# 30 3
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_518140735_518227135/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 4
# 30 2
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_518572735_518659135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_518659135_518745535/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 3
# 30 2
# 30 0
# 30 1
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_519263935_519350335/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 2
# 30 3
# 30 6
# 30 1
# 30 8
# 30 11
# 30 15
# 30 9
# 30 9
# 30 3
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_520387135_520473535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_520473535_520559935/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 2
# 30 1
# 30 10
# 30 10
# 30 13
# 30 9
# 30 7
# 30 10
# 30 10
# 30 6
# 30 5
# 30 8
# 30 8
# 30 9
# 30 15
# 30 11
# 30 10
# 30 10
# 30 9
# 30 7
# 30 14
# 30 8
# 30 12
# 30 6
# 30 9
# 30 7
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_522979135_523065535/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 10
# 30 13
# 30 8
# 30 8
# 30 2
# 30 2
# 30 3
# 30 3
# 30 2
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_524015935_524102335/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 1
# 30 1
# 30 1
# 30 2
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_524620735_524707135/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 2
# 30 12
# 30 10
# 30 7
# 30 6
# 30 7
# 30 7
# 30 1
# 30 1
# 30 3
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_525743935_525830335/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 1
# 30 3
# 30 1
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_526262335_526348735/4fgl_j1256.1-0547_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_526435135_526521535/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 5
# 30 5
# 30 6
# 30 9
# 30 9
# 30 11
# 30 9
# 30 10
# 30 13
# 30 12
# 30 11
# 30 11
# 30 9
# 30 5
# 30 3
# 30 6
# 30 9
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_528163135_528249535/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_528508735_528595135/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 1
# 30 1
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_528940735_529027135/4fgl_j1256.1-0547_sed.fits
# 30 6
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_529199935_529286335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_529286335_529372735/4fgl_j1256.1-0547_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_529459135_529545535/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 2
# 30 3
# 30 10
# 30 9
# 30 8
# 30 8
# 30 6
# 30 4
# 30 3
# 30 4
# 30 5
# 30 3
# 30 5
# 30 8
# 30 6
# 30 8
# 30 10
# 30 10
# 30 8
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_531359935_531446335/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_531619135_531705535/4fgl_j1256.1-0547_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_531791935_531878335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_531878335_531964735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_531964735_532051135/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 0
# 30 1
# 30 0
# 30 0
# 30 2
# 30 1
# 30 0
# 30 3
# 30 2
# 30 10
# 30 6
# 30 9
# 30 3
# 30 7
# 30 1
# 30 14
# 30 14
# 30 13
# 30 8
# 30 8
# 30 6
# 30 4
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_534124735_534211135/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 3
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_534470335_534556735/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 5
# 30 9
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_534902335_534988735/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 2
# 30 3
# 30 3
# 30 9
# 30 6
# 30 9
# 30 6
# 30 6
# 30 3
# 30 3
# 30 2
# 30 3
# 30 3
# 30 9
# 30 16
# 30 18
# 30 14
# 30 12
# 30 11
# 30 5
# 30 11
# 30 12
# 30 14
# 30 11
# 30 11
# 30 10
# 30 12
# 30 13
# 30 16
# 30 15
# 30 16
# 30 17
# 30 21
# 30 18
# 30 17
# 30 16
# 30 17
# 30 18
# 30 14
# 30 14
# 30 16
# 30 10
# 30 14
# 30 16
# 30 13
# 30 11
# 30 6
# 30 15
# 30 17
# 30 13
# 30 14
# 30 13
# 30 10
# 30 9
# 30 8
# 30 7
# 30 11
# 30 14
# 30 14
# 30 12
# 30 12
# 30 12
# 30 11
# 30 13
# 30 11
# 30 14
# 30 13
# 30 16
# 30 16
# 30 17
# 30 14
# 30 14
# 30 11
# 30 13
# 30 12
# 30 10
# 30 14
# 30 13
# 30 13
# 30 10
# 30 9
# 30 7
# 30 8
# 30 7
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_542419135_542505535/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 0
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_542851135_542937535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_542937535_543023935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543023935_543110335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543110335_543196735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543196735_543283135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543283135_543369535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543369535_543455935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543455935_543542335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543542335_543628735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543628735_543715135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543715135_543801535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543801535_543887935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543887935_543974335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543974335_544060735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_544060735_544147135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_544147135_544233535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_544233535_544319935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_544319935_544406335/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 9
# 30 14
# 30 11
# 30 11
# 30 8
# 30 11
# 30 11
# 30 11
# 30 15
# 30 13
# 30 14
# 30 17
# 30 18
# 30 19
# 30 19
# 30 21
# 30 20
# 30 20
# 30 19
# 30 16
# 30 17
# 30 17
# 30 16
# 30 15
# 30 14
# 30 11
# 30 14
# 30 13
# 30 17
# 30 16
# 30 18
# 30 16
# 30 17
# 30 19
# 30 18
# 30 15
# 30 11
# 30 10
# 30 14
# 30 2
# 30 0
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_548207935_548294335/4fgl_j1256.1-0547_sed.fits
# 30 7
# 30 7
# 30 13
# 30 17
# 30 10
# 30 10
# 30 8
# 30 5
# 30 12
# 30 12
# 30 12
# 30 13
# 30 16
# 30 18
# 30 18
# 30 18
# 30 15
# 30 18
# 30 13
# 30 16
# 30 15
# 30 12
# 30 8
# 30 10
# 30 10
# 30 7
# 30 9
# 30 8
# 30 10
# 30 5
# 30 15
# 30 16
# 30 16
# 30 11
# 30 12
# 30 14
# 30 16
# 30 11
# 30 11
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_551750335_551836735/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_552009535_552095935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_552095935_552182335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_552182335_552268735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_552268735_552355135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_552355135_552441535/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 12
# 30 13
# 30 15
# 30 12
# 30 13
# 30 12
# 30 10
# 30 12
# 30 10
# 30 11
# 30 10
# 30 9
# 30 9
# 30 10
# 30 11
# 30 14
# 30 14
# 30 13
# 30 8
# 30 6
# 30 10
# 30 14
# 30 11
# 30 12
# 30 13
# 30 13
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_554860735_554947135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_554947135_555033535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_555033535_555119935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_555119935_555206335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_555206335_555292735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_555292735_555379135/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_555638335_555724735/4fgl_j1256.1-0547_sed.fits
# 30 14
# 30 10
# 30 8
# 30 4
# 30 2
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556329535_556415935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556415935_556502335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556502335_556588735/4fgl_j1256.1-0547_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556675135_556761535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556761535_556847935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556847935_556934335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556934335_557020735/4fgl_j1256.1-0547_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_557107135_557193535/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_557366335_557452735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_557452735_557539135/4fgl_j1256.1-0547_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_557625535_557711935/4fgl_j1256.1-0547_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_557798335_557884735/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_558057535_558143935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_558143935_558230335/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_558489535_558575935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_558575935_558662335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_558662335_558748735/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559007935_559094335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559094335_559180735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559180735_559267135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559267135_559353535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559353535_559439935/4fgl_j1256.1-0547_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559526335_559612735/4fgl_j1256.1-0547_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559699135_559785535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559785535_559871935/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_560044735_560131135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_560131135_560217535/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_560390335_560476735/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 0
# 30 2
# 30 3
# 30 0
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_560995135_561081535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561081535_561167935/4fgl_j1256.1-0547_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561254335_561340735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561340735_561427135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561427135_561513535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561513535_561599935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561599935_561686335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561686335_561772735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561772735_561859135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561859135_561945535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561945535_562031935/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 6
# 30 5
# 30 2
# 30 2
# 30 2
# 30 3
# 30 1
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_562809535_562895935/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 2
# 30 0
# 30 1
# 30 3
# 30 3
# 30 5
# 30 6
# 30 7
# 30 7
# 30 4
# 30 5
# 30 8
# 30 2
# 30 4
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_564278335_564364735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_564364735_564451135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_564451135_564537535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_564537535_564623935/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 2
# 30 7
# 30 5
# 30 8
# 30 9
# 30 12
# 30 14
# 30 13
# 30 9
# 30 4
# 30 3
# 30 4
# 30 3
# 30 3
# 30 7
# 30 8
# 30 11
# 30 11
# 30 8
# 30 14
# 30 9
# 30 12
# 30 5
# 30 6
# 30 6
# 30 11
# 30 9
# 30 11
# 30 11
# 30 9
# 30 4
# 30 3
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_567561535_567647935/4fgl_j1256.1-0547_sed.fits
# 30 8
# 30 7
# 30 7
# 30 4
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_568079935_568166335/4fgl_j1256.1-0547_sed.fits
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_568252735_568339135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_568339135_568425535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_568425535_568511935/4fgl_j1256.1-0547_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_568598335_568684735/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 1
# 30 1
# 30 4
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_569203135_569289535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_569289535_569375935/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_569635135_569721535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_569721535_569807935/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_570067135_570153535/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 7
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_570412735_570499135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_570499135_570585535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_570585535_570671935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_570671935_570758335/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 0
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_571103935_571190335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_571190335_571276735/4fgl_j1256.1-0547_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_571363135_571449535/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# 30 1
# 30 3
# 30 3
# 30 1
# 30 3
# 30 3
# 30 7
# 30 1
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_572486335_572572735/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_572831935_572918335/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_573177535_573263935/4fgl_j1256.1-0547_sed.fits
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_573350335_573436735/4fgl_j1256.1-0547_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_573523135_573609535/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_573782335_573868735/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 3
# 30 3
# 30 5
# 30 2
# 30 3
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_574559935_574646335/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 1
# 30 4
# 30 2
# 30 4
# 30 0
# 30 2
# 30 4
# 30 1
# 30 2
# 30 2
# 30 2
# 30 1
# 30 3
# 30 5
# 30 7
# 30 10
# 30 7
# 30 6
# 30 4
# 30 4
# 30 6
# 30 3
# 30 1
# 30 2
# 30 0
# 30 0
# Number of significant SEDs: 184

# %%
##################################
# Get Fermi SED
##################################

from astropy.table import Table, vstack
table_allSEDs=Table()
n_significant_sed=0
for i in range(len(timebins_start)):
    timebin_start=timebins_start[i]
    timebin_end=timebins_end[i]
    sed_tab=getsed(timebin_start,timebin_end)
    if sed_tab is None:
        continue

    default_eref=sed_tab['e_ref']
    default_flux=np.ones(len(default_eref))*1e-4
    default_asymmerr=[np.ones(len(default_eref))*1e-5,np.ones(len(default_eref))*1e-5]

    default_errdiff=np.ones(len(default_eref))
    default_ts=np.ones(len(default_eref))*0.1
    high_significance_mask = (sed_tab['ts']>=9)
    low_significance_mask = (sed_tab['ts']<9)
    sed_tab['ShowUL']=low_significance_mask
    sed_tab_significant=sed_tab[high_significance_mask]
    sed_tab_nosignificant=sed_tab[low_significance_mask]
    print(len(sed_tab['e_ref']),len(sed_tab_significant['e_ref']))
    if len(sed_tab_significant['e_ref'])>=11:
        n_significant_sed+=1
        sed_tab_significant['tstart']=[met_to_mjd(timebin_start)]*len(sed_tab_significant['e_ref'])
        sed_tab_significant['tend']=[met_to_mjd(timebin_end)]*len(sed_tab_significant['e_ref'])
        table_allSEDs=vstack([table_allSEDs, sed_tab_significant])

    # print(len(sed_tab_nosignificant['e_ref']),len(sed_tab_nosignificant['e2dnde_ul']))
    # print(sed_tab_nosignificant['e_ref'],sed_tab_nosignificant['e2dnde_ul'])


table_allSEDs.write(outfilename)
# print(t)

# print('Number of significant SEDs:',n_significant_sed)
# Out:
# 30 2
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_510623935_510710335/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 6
# 30 3
# 30 2
# 30 7
# 30 10
# 30 14
# 30 14
# 30 12
# 30 7
# 30 5
# 30 7
# 30 12
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 13
# 30 5
# 30 4
# 30 3
# 30 5
# 30 16
# 30 13
# 30 15
# 30 13
# 30 12
# 30 9
# 30 16
# 30 17
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# 30 15
# 30 16
# 30 12
# 30 6
# 30 4
# 30 3
# 30 7
# 30 8
# 30 7
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 2
# 30 8
# 30 6
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_514339135_514425535/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_514598335_514684735/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 1
# 30 3
# 30 3
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_515116735_515203135/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 4
# 30 2
# 30 2
# 30 4
# 30 3
# 30 9
# 30 6
# 30 6
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_516067135_516153535/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 8
# 30 9
# 30 12
# 30 10
# 30 9
# 30 10
# 30 9
# 30 14
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 8
# 30 7
# 30 5
# 30 4
# 30 5
# 30 10
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_517708735_517795135/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 3
# 30 3
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_518140735_518227135/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 4
# 30 2
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_518572735_518659135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_518659135_518745535/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 3
# 30 2
# 30 0
# 30 1
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_519263935_519350335/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 2
# 30 3
# 30 6
# 30 1
# 30 8
# 30 11
# 30 15
# 30 9
# 30 9
# 30 3
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_520387135_520473535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_520473535_520559935/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 2
# 30 1
# 30 10
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 9
# 30 7
# 30 10
# 30 10
# 30 6
# 30 5
# 30 8
# 30 8
# 30 9
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 10
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 7
# 30 14
# 30 8
# 30 12
# 30 6
# 30 9
# 30 7
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_522979135_523065535/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 10
# 30 13
# 30 8
# 30 8
# 30 2
# 30 2
# 30 3
# 30 3
# 30 2
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_524015935_524102335/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 1
# 30 1
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 1
# 30 2
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_524620735_524707135/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 2
# 30 12
# 30 10
# 30 7
# 30 6
# 30 7
# 30 7
# 30 1
# 30 1
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 3
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_525743935_525830335/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 1
# 30 3
# 30 1
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_526262335_526348735/4fgl_j1256.1-0547_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_526435135_526521535/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 5
# 30 5
# 30 6
# 30 9
# 30 9
# 30 11
# 30 9
# 30 10
# 30 13
# 30 12
# 30 11
# 30 11
# 30 9
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 5
# 30 3
# 30 6
# 30 9
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_528163135_528249535/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_528508735_528595135/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 1
# 30 1
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_528940735_529027135/4fgl_j1256.1-0547_sed.fits
# 30 6
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_529199935_529286335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_529286335_529372735/4fgl_j1256.1-0547_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_529459135_529545535/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 2
# 30 3
# 30 10
# 30 9
# 30 8
# 30 8
# 30 6
# 30 4
# 30 3
# 30 4
# 30 5
# 30 3
# 30 5
# 30 8
# 30 6
# 30 8
# 30 10
# 30 10
# 30 8
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_531359935_531446335/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_531619135_531705535/4fgl_j1256.1-0547_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_531791935_531878335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_531878335_531964735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_531964735_532051135/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 0
# 30 1
# 30 0
# 30 0
# 30 2
# 30 1
# 30 0
# 30 3
# 30 2
# 30 10
# 30 6
# 30 9
# 30 3
# 30 7
# 30 1
# 30 14
# 30 14
# 30 13
# 30 8
# 30 8
# 30 6
# 30 4
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_534124735_534211135/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 3
# 30 1
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_534470335_534556735/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 5
# 30 9
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_534902335_534988735/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 2
# 30 3
# 30 3
# 30 9
# 30 6
# 30 9
# 30 6
# 30 6
# 30 3
# 30 3
# 30 2
# 30 3
# 30 3
# 30 9
# 30 16
# 30 18
# 30 14
# 30 12
# 30 11
# 30 5
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 12
# 30 14
# 30 11
# 30 11
# 30 10
# 30 12
# 30 13
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 16
# 30 17
# 30 21
# 30 18
# 30 17
# 30 16
# 30 17
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 18
# 30 14
# 30 14
# 30 16
# 30 10
# 30 14
# 30 16
# 30 13
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 6
# 30 15
# 30 17
# 30 13
# 30 14
# 30 13
# 30 10
# 30 9
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 7
# 30 11
# 30 14
# 30 14
# 30 12
# 30 12
# 30 12
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 11
# 30 14
# 30 13
# 30 16
# 30 16
# 30 17
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 11
# 30 13
# 30 12
# 30 10
# 30 14
# 30 13
# 30 13
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 7
# 30 8
# 30 7
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_542419135_542505535/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 0
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_542851135_542937535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_542937535_543023935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543023935_543110335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543110335_543196735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543196735_543283135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543283135_543369535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543369535_543455935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543455935_543542335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543542335_543628735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543628735_543715135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543715135_543801535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543801535_543887935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543887935_543974335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_543974335_544060735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_544060735_544147135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_544147135_544233535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_544233535_544319935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_544319935_544406335/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 9
# 30 14
# 30 11
# 30 11
# 30 8
# 30 11
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 15
# 30 13
# 30 14
# 30 17
# 30 18
# 30 19
# 30 19
# 30 21
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 20
# 30 20
# 30 19
# 30 16
# 30 17
# 30 17
# 30 16
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 11
# 30 14
# 30 13
# 30 17
# 30 16
# 30 18
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# 30 19
# 30 18
# 30 15
# 30 11
# 30 10
# 30 14
# 30 2
# 30 0
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_548207935_548294335/4fgl_j1256.1-0547_sed.fits
# 30 7
# 30 7
# 30 13
# 30 17
# 30 10
# 30 10
# 30 8
# 30 5
# 30 12
# 30 12
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 16
# 30 18
# 30 18
# 30 18
# 30 15
# 30 18
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# 30 15
# 30 12
# 30 8
# 30 10
# 30 10
# 30 7
# 30 9
# 30 8
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 5
# 30 15
# 30 16
# 30 16
# 30 11
# 30 12
# 30 14
# 30 16
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_551750335_551836735/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_552009535_552095935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_552095935_552182335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_552182335_552268735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_552268735_552355135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_552355135_552441535/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 12
# 30 13
# 30 15
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 12
# 30 10
# 30 12
# 30 10
# 30 11
# 30 10
# 30 9
# 30 9
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 14
# 30 14
# 30 13
# 30 8
# 30 6
# 30 10
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 12
# 30 13
# 30 13
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_554860735_554947135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_554947135_555033535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_555033535_555119935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_555119935_555206335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_555206335_555292735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_555292735_555379135/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_555638335_555724735/4fgl_j1256.1-0547_sed.fits
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 8
# 30 4
# 30 2
# 30 3
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556329535_556415935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556415935_556502335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556502335_556588735/4fgl_j1256.1-0547_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556675135_556761535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556761535_556847935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556847935_556934335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_556934335_557020735/4fgl_j1256.1-0547_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_557107135_557193535/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_557366335_557452735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_557452735_557539135/4fgl_j1256.1-0547_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_557625535_557711935/4fgl_j1256.1-0547_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_557798335_557884735/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_558057535_558143935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_558143935_558230335/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_558489535_558575935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_558575935_558662335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_558662335_558748735/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559007935_559094335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559094335_559180735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559180735_559267135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559267135_559353535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559353535_559439935/4fgl_j1256.1-0547_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559526335_559612735/4fgl_j1256.1-0547_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559699135_559785535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_559785535_559871935/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_560044735_560131135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_560131135_560217535/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_560390335_560476735/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 0
# 30 2
# 30 3
# 30 0
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_560995135_561081535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561081535_561167935/4fgl_j1256.1-0547_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561254335_561340735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561340735_561427135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561427135_561513535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561513535_561599935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561599935_561686335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561686335_561772735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561772735_561859135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561859135_561945535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_561945535_562031935/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 6
# 30 5
# 30 2
# 30 2
# 30 2
# 30 3
# 30 1
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_562809535_562895935/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 2
# 30 0
# 30 1
# 30 3
# 30 3
# 30 5
# 30 6
# 30 7
# 30 7
# 30 4
# 30 5
# 30 8
# 30 2
# 30 4
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_564278335_564364735/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_564364735_564451135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_564451135_564537535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_564537535_564623935/4fgl_j1256.1-0547_sed.fits
# 30 2
# 30 2
# 30 7
# 30 5
# 30 8
# 30 9
# 30 12
# 30 14
# 30 13
# 30 9
# 30 4
# 30 3
# 30 4
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 3
# 30 3
# 30 7
# 30 8
# 30 11
# 30 11
# 30 8
# 30 14
# 30 9
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 5
# 30 6
# 30 6
# 30 11
# 30 9
# 30 11
# 30 11
# 30 9
# 30 4
# 30 3
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_567561535_567647935/4fgl_j1256.1-0547_sed.fits
# 30 8
# 30 7
# 30 7
# 30 4
# 30 5
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_568079935_568166335/4fgl_j1256.1-0547_sed.fits
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_568252735_568339135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_568339135_568425535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_568425535_568511935/4fgl_j1256.1-0547_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_568598335_568684735/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 1
# 30 1
# 30 4
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_569203135_569289535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_569289535_569375935/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_569635135_569721535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_569721535_569807935/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_570067135_570153535/4fgl_j1256.1-0547_sed.fits
# 30 4
# 30 7
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_570412735_570499135/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_570499135_570585535/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_570585535_570671935/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_570671935_570758335/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 0
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_571103935_571190335/4fgl_j1256.1-0547_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_571190335_571276735/4fgl_j1256.1-0547_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_571363135_571449535/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# 30 1
# 30 3
# 30 3
# 30 1
# 30 3
# 30 3
# 30 7
# 30 1
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_572486335_572572735/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_572831935_572918335/4fgl_j1256.1-0547_sed.fits
# 30 0
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_573177535_573263935/4fgl_j1256.1-0547_sed.fits
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_573350335_573436735/4fgl_j1256.1-0547_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_573523135_573609535/4fgl_j1256.1-0547_sed.fits
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_573782335_573868735/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 3
# 30 3
# 30 5
# 30 2
# 30 3
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/14_3C279_100MeV_1d_2/1days/lightcurve_574559935_574646335/4fgl_j1256.1-0547_sed.fits
# 30 3
# 30 1
# 30 4
# 30 2
# 30 4
# 30 0
# 30 2
# 30 4
# 30 1
# 30 2
# 30 2
# 30 2
# 30 1
# 30 3
# 30 5
# 30 7
# 30 10
# 30 7
# 30 6
# 30 4
# 30 4
# 30 6
# 30 3
# 30 1
# 30 2
# 30 0
# 30 0

# %%
print(table_allSEDs.colnames)
# Out:
# ['e_min', 'e_ref', 'e_max', 'ref_dnde_e_min', 'ref_dnde_e_max', 'ref_dnde', 'ref_flux', 'ref_eflux', 'ref_npred', 'dnde', 'dnde_err', 'dnde_errp', 'dnde_errn', 'dnde_ul', 'e2dnde', 'e2dnde_err', 'e2dnde_errp', 'e2dnde_errn', 'e2dnde_ul', 'norm', 'norm_err', 'norm_errp', 'norm_errn', 'norm_ul', 'ts', 'loglike', 'norm_scan', 'dloglike_scan', 'ShowUL', 'tstart', 'tend']

# %%
table_allSEDs
# Out:
# <Table length=2574>
#       e_min              e_ref        ...       tstart             tend
#        MeV                MeV         ...
#      float64            float64       ...      float64           float64
# ------------------ ------------------ ... ----------------- -----------------
#              100.0 115.25240587974294 ... 57826.99999055518 57827.99999055518
# 132.83117061068992   153.091119887046 ... 57826.99999055518 57827.99999055518
#  176.4411988580621 203.35272664697808 ... 57826.99999055518 57827.99999055518
# 234.36890988269914  270.1158072739371 ... 57826.99999055518 57827.99999055518
#  311.3149665447022  358.7979888064861 ... 57826.99999055518 57827.99999055518
# 413.52331434760555  476.5900816815941 ... 57826.99999055518 57827.99999055518
#  549.2752115212968  633.0528961793416 ... 57826.99999055518 57827.99999055518
#  729.6086933380817  840.8915725798939 ... 57826.99999055518 57827.99999055518
#  969.1477682383326 1116.9661194245136 ... 57826.99999055518 57827.99999055518
#                ...                ... ...               ...               ...
# 132.83117061068992   153.091119887046 ... 58473.99999055518 58474.99999055518
#  176.4411988580621 203.35272664697808 ... 58473.99999055518 58474.99999055518
# 234.36890988269914  270.1158072739371 ... 58473.99999055518 58474.99999055518
#  311.3149665447022  358.7979888064861 ... 58473.99999055518 58474.99999055518
# 413.52331434760555  476.5900816815941 ... 58473.99999055518 58474.99999055518
#  729.6086933380817  840.8915725798939 ... 58473.99999055518 58474.99999055518
# 1287.3303254983532 1483.6791717563765 ... 58473.99999055518 58474.99999055518
# 1709.9759409858673 1970.7884119509856 ... 58473.99999055518 58474.99999055518
# 2271.3810595726877  2617.821317854317 ... 58473.99999055518 58474.99999055518
#  7071.149185711414  8149.575733880153 ... 58473.99999055518 58474.99999055518

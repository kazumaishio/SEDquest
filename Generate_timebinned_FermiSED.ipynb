# %% [markdown]
# # Make an ecsv file which contains SEDs of all periods with significant number of data points
#
# From
# `/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/Generate_timebinned_MWLSED.ipynb`
#
#
# `/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days`
# Number of significant SEDs: 264
#
# `home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days`
# Number of significant SEDs: 208

# %%
import os

# # 3C454.3
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# '/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days/{directoryname}/4fgl_j2253.9+1609_sed.fits'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # S20109+22 Number of significant SEDs: 58
# # S20109+22 = 4fgl_j0112.1+2245
# # Number of significant SEDs: 58
# source_name='S20109+22'
# source_name_4fgl='4fgl_j0112.1+2245'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/5_S20109+22_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 8_PKS1510-089_100MeV_14d Number of significant SEDs: 214
# # PKS1510-089 = 4fgl_j1512.8-0906
# # Number of significant SEDs: 40
# source_name='PKS1510-089'
# source_name_4fgl='4fgl_j1512.8-0906'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/8_PKS1510-089_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 9_4C+21.35_100MeV_14d Number of significant SEDs: 103
# # 4C+21.35 = 4fgl_j1224.9+2122
# source_name='4C+21.35'
# source_name_4fgl='4fgl_j1224.9+2122'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/9_4C+21.35_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 10_Mrk421_100MeV_14d Number of significant SEDs: 403
# # 4C+21.35 = 4fgl_j1224.9+2122
# source_name='Mrk421'
# source_name_4fgl='4fgl_j1104.4+3812'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 11_CTA102_100MeV_14d Number of significant SEDs: 180
# # CTA102 = 4fgl_j2232.6+1143
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/11_CTA102_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# print(sed_path_test)

# # 13 3C454.3  Number of significant SEDs: 566
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/13_3C454_100MeV_1d_first1050days/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'
# '/home/kazuma/Workspace/AGN_data/13_3C454_100MeV_1d_first1050days/1days/{directoryname}/4fgl_j2253.9+1609_sed.fits'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 12_BLLac_100MeV_14d Number of significant SEDs: 298
# # BLLac = 4fgl_j2202.7+4216
# source_name='BLLac'
# source_name_4fgl='4fgl_j2202.7+4216'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/12_BLLac_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# print(sed_path_test)

# # 14_3C279_100MeV_14d Number of significant SEDs: 261
# # 3C279 = 4fgl_j1256.1-0547
# source_name='3C279'
# source_name_4fgl='4fgl_j1256.1-0547'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/14_3C279_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# print(sed_path_test)

# # 15_3C454_100MeV_1d_second1150days Number of significant SEDs: 468
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/15_3C454_100MeV_1d_second1150days/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_2_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 16_S50716+71_100MeV_14d  Number of significant SEDs: 285
# # S50716+71 = 4fgl_j0721.9+7120
# source_name='S50716+71'
# source_name_4fgl='4fgl_j0721.9+7120'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/16_S50716+71_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 17_PKS1424-41_100MeV_14d Number of significant SEDs: 299
# # PKS1424-41 = 4fgl_j1427.9-4206
# source_name='PKS1424-41'
# source_name_4fgl='4fgl_j1427.9-4206'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/17_PKS1424-41_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 18_PKS0426-380_100MeV_14d Number of significant SEDs: 189
# # PKS0426-380 = 4fgl_j0428.6-3756
# source_name='PKS0426-380'
# source_name_4fgl='4fgl_j0428.6-3756'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/18_PKS0426-380_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 19_PKS0537-441_100MeV_14d Number of significant SEDs: 224
# # PKS0537-441 = 4fgl_j0538.8-4405
# source_name='PKS0537-441'
# source_name_4fgl='4fgl_j0538.8-4405'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/19_PKS0537-441_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 20_PKS2155-304_100MeV_14d Number of significant SEDs: 166
# # PKS2155-304 = 4fgl_j2158.8-3013
# source_name='PKS2155-304'
# source_name_4fgl='4fgl_j2158.8-3013'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/20_PKS2155-304_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 21_PKS0454-234_100MeV_14d Number of significant SEDs: 242
# # PKS0454-234 = 4fgl_j0457.0-2324
# source_name='PKS0454-234'
# source_name_4fgl='4fgl_j0457.0-2324'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/21_PKS0454-234_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 22_PKS1502+106_100MeV_14d Number of significant SEDs: 147
# # PKS1502+106 = 4fgl_j1504.4+1029
# source_name='PKS1502+106'
# source_name_4fgl='4fgl_j1504.4+1029'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/22_PKS1502+106_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 23_Ton599_100MeV_14d Number of significant SEDs: 186
# # Ton599 = 4fgl_j1159.5+2914
# source_name='Ton599'
# source_name_4fgl='4fgl_j1159.5+2914'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/23_Ton599_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 24_4C+55.17_100MeV_14d  Number of significant SEDs: 57
# # 4C+55.17 = 4fgl_j0957.6+5523
# source_name='4C+55.17'
# source_name_4fgl='4fgl_j0957.6+5523'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/24_4C+55.17_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 25_PKS0346-27_100MeV_14d Number of significant SEDs: 111
# # PKS0346-27 = 4fgl_j0348.5-2749
# source_name='PKS0346-27'
# source_name_4fgl='4fgl_j0348.5-2749'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/25_PKS0346-27_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 26_4C+01.02_100MeV_14d Number of significant SEDs: 158
# # 4C+01.02 = 4fgl_j0108.6+0134
# source_name='4C+01.02'
# source_name_4fgl='4fgl_j0108.6+0134'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/26_4C+01.02_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 27_PKS1830-211_100MeV_14d Number of significant SEDs: 117
# # PKS1830-211 = 4fgl_j1833.6-2103
# source_name='PKS1830-211'
# source_name_4fgl='4fgl_j1833.6-2103'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 28_PKS0208-512_100MeV_14d Number of significant SEDs: 94
# # PKS0208-512 = 4fgl_j0210.7-5101
# source_name='PKS0208-512'
# source_name_4fgl='4fgl_j0210.7-5101'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/28_PKS0208-512_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_1d Number of significant SEDs: 1
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_1d/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# 30_CTA102_100MeV_1d Number of significant SEDs: 0
# # CTA102 = 4fgl_j2232.6+1143
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_1_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 30_CTA102_100MeV_1d_2 Number of significant SEDs: 265
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_2_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# 30_CTA102_100MeV_1d_3 Number of significant SEDs: 97
source_name='CTA102'
source_name_4fgl='4fgl_j2232.6+1143'
input_directory_parent='/home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_3/1days'
directoryname_test='lightcurve_xxx_xxx'
sed_filename=f'{source_name_4fgl}_sed.fits'
outfilename=f'{source_name}_allsed_1d_3_min11.ecsv'
sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# %%
####################################################################
# for Inline animations in Jupyter
# https://stackoverflow.com/questions/43445103/inline-animations-in-jupyter
####################################################################
# Enable interactive plot
# %matplotlib notebook

import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import os

####################################################################
# Functions
####################################################################
##################################
# 
##################################
def met_to_mjd(met) :
    mjd = 51910. + 7.4287e-4 + met/86400.
    return mjd
# print(mjd_start, mjd_end)
# print(met_to_mjd(mjd_start), met_to_mjd(mjd_end))
##################################
#  GET fermi SED table from fits file
##################################
from astropy.table import Table
def getsed(timebin_start,timebin_end):
    # print(directories)
    directoryname=f'lightcurve_{timebin_start}_{timebin_end}'
    sed_path=os.path.join(input_directory_parent,directoryname,sed_filename )
    try : 
        sed_tab= Table.read(sed_path)
        # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
        # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
        return sed_tab
    except:
        print('not found: ', sed_path)    
        return None

from astropy import units as u
from astropy.io import ascii

# %%
mjd_min=45000#55000
mjd_max=65000#56000

##################################
# Get subdirectories within time scope
directories=os.listdir(input_directory_parent)
# directories=os.listdir('/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days')
timebins_start=[]
timebins_end=[]
for directoryname in directories:
    elements=directoryname.split('_')
    timebin_start=met_to_mjd(float(elements[1]))
    timebin_end=met_to_mjd(float(elements[2]))
#     print(elements[1],elements[2])
#     print(timebin_start, timebin_end)
    if timebin_end>mjd_max*1.0001 :
        continue        
    if timebin_start<mjd_min*0.9999 :
        continue
    timebins_start.append(int(elements[1]))
    timebins_end.append(int(elements[2]))

timebins_start.sort()
timebins_end.sort()
print(timebins_start[0], timebins_end[-1])
print('Which are {} and {}'.format(mjd_min,mjd_max))
print(met_to_mjd(timebins_start[0]), met_to_mjd(timebins_end[-1]))
# Out:
# 421891136 518918336
# Which are 45000 and 65000
# 56793.00000212926 57916.00000212926

# %%
##################################
# Get Fermi SED
##################################
n_significant_sed=0
for i in range(len(timebins_start)):
    timebin_start=timebins_start[i]
    timebin_end=timebins_end[i]
    sed_tab=getsed(timebin_start,timebin_end)
    if sed_tab is None:
        continue

    default_eref=sed_tab['e_ref']
    default_flux=np.ones(len(default_eref))*1e-4
    default_asymmerr=[np.ones(len(default_eref))*1e-5,np.ones(len(default_eref))*1e-5]

    default_errdiff=np.ones(len(default_eref))
    default_ts=np.ones(len(default_eref))*0.1
    high_significance_mask = (sed_tab['ts']>=9)
    low_significance_mask = (sed_tab['ts']<9)
    sed_tab['ShowUL']=low_significance_mask
    sed_tab_significant=sed_tab[high_significance_mask]
    sed_tab_nosignificant=sed_tab[low_significance_mask]
    print(len(sed_tab['e_ref']),len(sed_tab_significant['e_ref']))
    if len(sed_tab_significant['e_ref'])>=10:
        n_significant_sed+=1
    # print(len(sed_tab_nosignificant['e_ref']),len(sed_tab_nosignificant['e2dnde_ul']))
    # print(sed_tab_nosignificant['e_ref'],sed_tab_nosignificant['e2dnde_ul'])

print('Number of significant SEDs:',n_significant_sed)
# Out:
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_421891136_421977536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422150336_422236736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422236736_422323136/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422409536_422495936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422495936_422582336/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422668736_422755136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422755136_422841536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422841536_422927936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422927936_423014336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423014336_423100736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423100736_423187136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423187136_423273536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423359936_423446336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423446336_423532736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423619136_423705536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423705536_423791936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423791936_423878336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423878336_423964736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423964736_424051136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_424051136_424137536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_424483136_424569536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_424569536_424655936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_424655936_424742336/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_424828736_424915136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_424915136_425001536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_425087936_425174336/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_425260736_425347136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_425347136_425433536/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_425519936_425606336/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_425692736_425779136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_425779136_425865536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426124736_426211136/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426383936_426470336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426470336_426556736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426556736_426643136/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426729536_426815936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426815936_426902336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426902336_426988736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426988736_427075136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427075136_427161536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427161536_427247936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427247936_427334336/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427420736_427507136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427507136_427593536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427593536_427679936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427679936_427766336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427766336_427852736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427939136_428025536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428111936_428198336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428198336_428284736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428284736_428371136/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428543936_428630336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428630336_428716736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428716736_428803136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428803136_428889536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428889536_428975936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429062336_429148736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429148736_429235136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429235136_429321536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429321536_429407936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429407936_429494336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429494336_429580736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429667136_429753536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429753536_429839936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429839936_429926336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429926336_430012736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430012736_430099136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430099136_430185536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430185536_430271936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430271936_430358336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430358336_430444736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430444736_430531136/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430617536_430703936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430703936_430790336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430790336_430876736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430876736_430963136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430963136_431049536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_431222336_431308736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_431308736_431395136/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_431567936_431654336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_431654336_431740736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_431740736_431827136/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_431913536_431999936/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_432086336_432172736/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_432345536_432431936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_432518336_432604736/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 2
# 30 0
# 30 1
# 30 0
# 30 2
# 30 0
# 30 0
# 30 1
# 30 0
# 30 1
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_433641536_433727936/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 2
# 30 4
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434073536_434159936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434246336_434332736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434332736_434419136/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434505536_434591936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434591936_434678336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434678336_434764736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434764736_434851136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434851136_434937536/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_435110336_435196736/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 10
# 30 3
# 30 7
# 30 3
# 30 7
# 30 11
# 30 11
# 30 10
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_436060736_436147136/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_436319936_436406336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_436406336_436492736/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 3
# 30 4
# 30 6
# 30 7
# 30 2
# 30 3
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_437183936_437270336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_437270336_437356736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_437356736_437443136/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_437529536_437615936/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_437875136_437961536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_437961536_438047936/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_438220736_438307136/4fgl_j2232.6+1143_sed.fits
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_438393536_438479936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_438479936_438566336/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 2
# 30 2
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_438998336_439084736/4fgl_j2232.6+1143_sed.fits
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_439171136_439257536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_439343936_439430336/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 6
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_439689536_439775936/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 1
# 30 3
# 30 3
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_440294336_440380736/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 2
# 30 1
# 30 1
# 30 0
# 30 1
# 30 4
# 30 0
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_441158336_441244736/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_441503936_441590336/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 1
# 30 4
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_441935936_442022336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_442022336_442108736/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 1
# 30 1
# 30 3
# 30 0
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_442627136_442713536/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_442799936_442886336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_442886336_442972736/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 0
# 30 12
# 30 5
# 30 6
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_443491136_443577536/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_443663936_443750336/4fgl_j2232.6+1143_sed.fits
# 30 7
# 30 6
# 30 8
# 30 3
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_444182336_444268736/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 6
# 30 8
# 30 12
# 30 9
# 30 11
# 30 9
# 30 5
# 30 8
# 30 10
# 30 7
# 30 6
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_445478336_445564736/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_445651136_445737536/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 1
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_445996736_446083136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446083136_446169536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446169536_446255936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446255936_446342336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446342336_446428736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446428736_446515136/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446687936_446774336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446774336_446860736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446860736_446947136/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 3
# 30 4
# 30 4
# 30 4
# 30 11
# 30 10
# 30 11
# 30 4
# 30 2
# 30 4
# 30 4
# 30 4
# 30 2
# 30 2
# 30 1
# 30 1
# 30 1
# 30 1
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_448675136_448761536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_448761536_448847936/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 0
# 30 3
# 30 4
# 30 0
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_449452736_449539136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_449539136_449625536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_449711936_449798336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_449798336_449884736/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450143936_450230336/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450316736_450403136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450403136_450489536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450489536_450575936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450575936_450662336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450662336_450748736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450835136_450921536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450921536_451007936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_451007936_451094336/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_451353536_451439936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_451439936_451526336/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 2
# 30 0
# 30 3
# 30 4
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452131136_452217536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452217536_452303936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452303936_452390336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452390336_452476736/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452649536_452735936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452735936_452822336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452822336_452908736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452908736_452995136/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453081536_453167936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453254336_453340736/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453427136_453513536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453599936_453686336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453686336_453772736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453772736_453859136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453859136_453945536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454118336_454204736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454204736_454291136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454291136_454377536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454377536_454463936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454463936_454550336/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454636736_454723136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454723136_454809536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454809536_454895936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454895936_454982336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454982336_455068736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455155136_455241536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455241536_455327936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455414336_455500736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455500736_455587136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455587136_455673536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455673536_455759936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455759936_455846336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455846336_455932736/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_456191936_456278336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_456278336_456364736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_456451136_456537536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_456623936_456710336/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 2
# 30 4
# 30 7
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_457142336_457228736/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_457487936_457574336/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_457660736_457747136/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 3
# 30 5
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_458179136_458265536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_458265536_458351936/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_458524736_458611136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_458611136_458697536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_458956736_459043136/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_459129536_459215936/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_459475136_459561536/4fgl_j2232.6+1143_sed.fits
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_459647936_459734336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_459734336_459820736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_459907136_459993536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460079936_460166336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460166336_460252736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460252736_460339136/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460425536_460511936/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460598336_460684736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460684736_460771136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460771136_460857536/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460943936_461030336/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 5
# 30 4
# 30 4
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_461462336_461548736/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 4
# 30 4
# 30 5
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462067136_462153536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462153536_462239936/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462326336_462412736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462412736_462499136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462499136_462585536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462585536_462671936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462671936_462758336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462758336_462844736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462844736_462931136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462931136_463017536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463017536_463103936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463103936_463190336/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463363136_463449536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463535936_463622336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463622336_463708736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463708736_463795136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463795136_463881536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_464054336_464140736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_464140736_464227136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_464227136_464313536/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 2
# 30 2
# 30 8
# 30 7
# 30 10
# 30 11
# 30 5
# 30 6
# 30 2
# 30 4
# 30 2
# 30 4
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_465523136_465609536/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 5
# 30 5
# 30 7
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_466041536_466127936/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 1
# 30 0
# 30 1
# 30 2
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_466732736_466819136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_466819136_466905536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_466991936_467078336/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_467251136_467337536/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_467423936_467510336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_467510336_467596736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_467596736_467683136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_467683136_467769536/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_467855936_467942336/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_468028736_468115136/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_468201536_468287936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_468374336_468460736/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 2
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_468719936_468806336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_468806336_468892736/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_468979136_469065536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_469065536_469151936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_469238336_469324736/4fgl_j2232.6+1143_sed.fits
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_469411136_469497536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_469583936_469670336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_469670336_469756736/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_469843136_469929536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_470015936_470102336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_470102336_470188736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_470188736_470275136/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_470361536_470447936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_470447936_470534336/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 3
# 30 2
# 30 12
# 30 9
# 30 11
# 30 1
# 30 5
# 30 0
# 30 4
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_471484736_471571136/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_471657536_471743936/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 0
# 30 3
# 30 2
# 30 6
# 30 2
# 30 6
# 30 14
# 30 5
# 30 2
# 30 2
# 30 13
# 30 9
# 30 11
# 30 15
# 30 15
# 30 7
# 30 6
# 30 6
# 30 2
# 30 3
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_473644736_473731136/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 2
# 30 3
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_474163136_474249536/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_474335936_474422336/4fgl_j2232.6+1143_sed.fits
# 30 14
# 30 6
# 30 2
# 30 6
# 30 10
# 30 8
# 30 9
# 30 11
# 30 8
# 30 13
# 30 16
# 30 18
# 30 10
# 30 12
# 30 15
# 30 12
# 30 10
# 30 15
# 30 7
# 30 8
# 30 14
# 30 9
# 30 9
# 30 16
# 30 12
# 30 14
# 30 17
# 30 12
# 30 14
# 30 15
# 30 17
# 30 14
# 30 10
# 30 14
# 30 16
# 30 17
# 30 14
# 30 17
# 30 17
# 30 12
# 30 11
# 30 16
# 30 16
# 30 14
# 30 10
# 30 15
# 30 12
# 30 10
# 30 11
# 30 14
# 30 7
# 30 8
# 30 7
# 30 10
# 30 10
# 30 7
# 30 5
# 30 2
# 30 6
# 30 3
# 30 9
# 30 6
# 30 8
# 30 7
# 30 10
# 30 10
# 30 8
# 30 13
# 30 7
# 30 11
# 30 12
# 30 11
# 30 12
# 30 15
# 30 9
# 30 12
# 30 9
# 30 12
# 30 12
# 30 10
# 30 7
# 30 9
# 30 7
# 30 3
# 30 6
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_481852736_481939136/4fgl_j2232.6+1143_sed.fits
# 30 8
# 30 6
# 30 8
# 30 10
# 30 14
# 30 6
# 30 5
# 30 3
# 30 4
# 30 7
# 30 4
# 30 3
# 30 5
# 30 6
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_483235136_483321536/4fgl_j2232.6+1143_sed.fits
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_483407936_483494336/4fgl_j2232.6+1143_sed.fits
# 30 7
# 30 5
# 30 4
# 30 8
# 30 4
# 30 2
# 30 3
# 30 4
# 30 3
# 30 10
# 30 9
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_484531136_484617536/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_484790336_484876736/4fgl_j2232.6+1143_sed.fits
# 30 6
# 30 1
# 30 3
# 30 5
# 30 2
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_485395136_485481536/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 2
# 30 9
# 30 9
# 30 8
# 30 8
# 30 8
# 30 2
# 30 2
# 30 2
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_486431936_486518336/4fgl_j2232.6+1143_sed.fits
# 30 7
# 30 11
# 30 13
# 30 11
# 30 9
# 30 13
# 30 15
# 30 10
# 30 3
# 30 8
# 30 12
# 30 14
# 30 12
# 30 11
# 30 3
# 30 7
# 30 5
# 30 11
# 30 10
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_488246336_488332736/4fgl_j2232.6+1143_sed.fits
# 30 10
# 30 7
# 30 11
# 30 16
# 30 14
# 30 11
# 30 10
# 30 9
# 30 7
# 30 12
# 30 9
# 30 7
# 30 7
# 30 6
# 30 4
# 30 5
# 30 7
# 30 2
# 30 7
# 30 5
# 30 4
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_490233536_490319936/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 10
# 30 9
# 30 1
# 30 6
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_490838336_490924736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_490924736_491011136/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 3
# 30 2
# 30 0
# 30 0
# 30 0
# 30 0
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_491788736_491875136/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_492047936_492134336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_492134336_492220736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_492220736_492307136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_492307136_492393536/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 3
# 30 3
# 30 1
# 30 2
# 30 3
# 30 9
# 30 7
# 30 7
# 30 6
# 30 8
# 30 10
# 30 13
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_493603136_493689536/4fgl_j2232.6+1143_sed.fits
# 30 13
# 30 15
# 30 13
# 30 12
# 30 13
# 30 15
# 30 12
# 30 12
# 30 11
# 30 11
# 30 11
# 30 11
# 30 6
# 30 5
# 30 6
# 30 6
# 30 4
# 30 12
# 30 9
# 30 6
# 30 4
# 30 5
# 30 6
# 30 4
# 30 5
# 30 7
# 30 9
# 30 9
# 30 11
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_496281536_496367936/4fgl_j2232.6+1143_sed.fits
# 30 8
# 30 12
# 30 12
# 30 10
# 30 11
# 30 5
# 30 6
# 30 1
# 30 1
# 30 4
# 30 3
# 30 3
# 30 9
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_497577536_497663936/4fgl_j2232.6+1143_sed.fits
# 30 8
# 30 9
# 30 5
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_498009536_498095936/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 1
# 30 0
# 30 1
# 30 7
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_498614336_498700736/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 11
# 30 3
# 30 5
# 30 2
# 30 4
# 30 15
# 30 10
# 30 6
# 30 2
# 30 6
# 30 11
# 30 6
# 30 3
# 30 7
# 30 2
# 30 6
# 30 6
# 30 9
# 30 11
# 30 6
# 30 7
# 30 12
# 30 8
# 30 10
# 30 5
# 30 6
# 30 10
# 30 13
# 30 9
# 30 8
# 30 11
# 30 19
# 30 17
# 30 13
# 30 12
# 30 11
# 30 12
# 30 14
# 30 15
# 30 19
# 30 14
# 30 15
# 30 15
# 30 17
# 30 14
# 30 16
# 30 16
# 30 15
# 30 17
# 30 15
# 30 17
# 30 14
# 30 15
# 30 19
# 30 18
# 30 21
# 30 16
# 30 17
# 30 18
# 30 19
# 30 17
# 30 20
# 30 20
# 30 20
# 30 17
# 30 19
# 30 19
# 30 19
# 30 19
# 30 21
# 30 21
# 30 19
# 30 16
# 30 17
# 30 15
# 30 19
# 30 19
# 30 21
# 30 20
# 30 17
# 30 16
# 30 15
# 30 15
# 30 14
# 30 16
# 30 18
# 30 13
# 30 16
# 30 16
# 30 15
# 30 15
# 30 16
# 30 13
# 30 14
# 30 12
# 30 18
# 30 14
# 30 15
# 30 13
# 30 12
# 30 13
# 30 13
# 30 13
# 30 4
# 30 8
# 30 9
# 30 12
# 30 11
# 30 17
# 30 14
# 30 17
# 30 18
# 30 19
# 30 19
# 30 16
# 30 20
# 30 14
# 30 13
# 30 14
# 30 14
# 30 8
# 30 10
# 30 9
# 30 5
# 30 8
# 30 8
# 30 6
# 30 6
# 30 13
# 30 10
# 30 8
# 30 9
# 30 8
# 30 12
# 30 13
# 30 7
# 30 10
# 30 8
# 30 11
# 30 5
# 30 8
# 30 4
# 30 10
# 30 5
# 30 4
# 30 7
# 30 8
# 30 7
# 30 13
# 30 8
# 30 11
# 30 11
# 30 8
# 30 11
# 30 10
# 30 12
# 30 11
# 30 12
# 30 12
# 30 13
# 30 15
# 30 17
# 30 17
# 30 13
# 30 7
# 30 7
# 30 5
# 30 3
# 30 3
# 30 0
# 30 7
# 30 7
# 30 8
# 30 6
# 30 9
# 30 11
# 30 9
# 30 8
# 30 15
# 30 20
# 30 18
# 30 9
# 30 11
# 30 11
# 30 9
# 30 9
# 30 9
# 30 8
# 30 8
# 30 9
# 30 13
# 30 11
# 30 17
# 30 7
# 30 9
# 30 8
# 30 6
# 30 9
# 30 11
# 30 9
# 30 15
# 30 17
# 30 13
# 30 14
# 30 17
# 30 17
# 30 15
# 30 16
# 30 13
# 30 11
# 30 6
# 30 8
# 30 7
# 30 4
# 30 4
# 30 5
# 30 5
# 30 10
# 30 10
# 30 8
# 30 8
# 30 12
# 30 11
# 30 11
# 30 10
# 30 4
# 30 10
# 30 4
# 30 10
# 30 5
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_518745536_518831936/4fgl_j2232.6+1143_sed.fits
# 30 3
# Number of significant SEDs: 265

# %%
##################################
# Get Fermi SED
##################################

from astropy.table import Table, vstack
table_allSEDs=Table()
n_significant_sed=0
for i in range(len(timebins_start)):
    timebin_start=timebins_start[i]
    timebin_end=timebins_end[i]
    sed_tab=getsed(timebin_start,timebin_end)
    if sed_tab is None:
        continue

    default_eref=sed_tab['e_ref']
    default_flux=np.ones(len(default_eref))*1e-4
    default_asymmerr=[np.ones(len(default_eref))*1e-5,np.ones(len(default_eref))*1e-5]

    default_errdiff=np.ones(len(default_eref))
    default_ts=np.ones(len(default_eref))*0.1
    high_significance_mask = (sed_tab['ts']>=9)
    low_significance_mask = (sed_tab['ts']<9)
    sed_tab['ShowUL']=low_significance_mask
    sed_tab_significant=sed_tab[high_significance_mask]
    sed_tab_nosignificant=sed_tab[low_significance_mask]
    print(len(sed_tab['e_ref']),len(sed_tab_significant['e_ref']))
    if len(sed_tab_significant['e_ref'])>=10:
        n_significant_sed+=1
        sed_tab_significant['tstart']=[met_to_mjd(timebin_start)]*len(sed_tab_significant['e_ref'])
        sed_tab_significant['tend']=[met_to_mjd(timebin_end)]*len(sed_tab_significant['e_ref'])
        table_allSEDs=vstack([table_allSEDs, sed_tab_significant])

    # print(len(sed_tab_nosignificant['e_ref']),len(sed_tab_nosignificant['e2dnde_ul']))
    # print(sed_tab_nosignificant['e_ref'],sed_tab_nosignificant['e2dnde_ul'])


table_allSEDs.write(outfilename)
# print(t)

# print('Number of significant SEDs:',n_significant_sed)
# Out:
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_421891136_421977536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422150336_422236736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422236736_422323136/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422409536_422495936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422495936_422582336/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422668736_422755136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422755136_422841536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422841536_422927936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_422927936_423014336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423014336_423100736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423100736_423187136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423187136_423273536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423359936_423446336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423446336_423532736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423619136_423705536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423705536_423791936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423791936_423878336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423878336_423964736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_423964736_424051136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_424051136_424137536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_424483136_424569536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_424569536_424655936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_424655936_424742336/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_424828736_424915136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_424915136_425001536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_425087936_425174336/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_425260736_425347136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_425347136_425433536/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_425519936_425606336/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_425692736_425779136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_425779136_425865536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426124736_426211136/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426383936_426470336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426470336_426556736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426556736_426643136/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426729536_426815936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426815936_426902336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426902336_426988736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_426988736_427075136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427075136_427161536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427161536_427247936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427247936_427334336/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427420736_427507136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427507136_427593536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427593536_427679936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427679936_427766336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427766336_427852736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_427939136_428025536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428111936_428198336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428198336_428284736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428284736_428371136/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428543936_428630336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428630336_428716736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428716736_428803136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428803136_428889536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_428889536_428975936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429062336_429148736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429148736_429235136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429235136_429321536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429321536_429407936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429407936_429494336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429494336_429580736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429667136_429753536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429753536_429839936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429839936_429926336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_429926336_430012736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430012736_430099136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430099136_430185536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430185536_430271936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430271936_430358336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430358336_430444736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430444736_430531136/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430617536_430703936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430703936_430790336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430790336_430876736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430876736_430963136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_430963136_431049536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_431222336_431308736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_431308736_431395136/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_431567936_431654336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_431654336_431740736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_431740736_431827136/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_431913536_431999936/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_432086336_432172736/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_432345536_432431936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_432518336_432604736/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 2
# 30 0
# 30 1
# 30 0
# 30 2
# 30 0
# 30 0
# 30 1
# 30 0
# 30 1
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_433641536_433727936/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 2
# 30 4
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434073536_434159936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434246336_434332736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434332736_434419136/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434505536_434591936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434591936_434678336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434678336_434764736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434764736_434851136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_434851136_434937536/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_435110336_435196736/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 10
# 30 3
# 30 7
# 30 3
# 30 7
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 10
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_436060736_436147136/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_436319936_436406336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_436406336_436492736/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 3
# 30 4
# 30 6
# 30 7
# 30 2
# 30 3
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_437183936_437270336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_437270336_437356736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_437356736_437443136/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_437529536_437615936/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_437875136_437961536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_437961536_438047936/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_438220736_438307136/4fgl_j2232.6+1143_sed.fits
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_438393536_438479936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_438479936_438566336/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 2
# 30 2
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_438998336_439084736/4fgl_j2232.6+1143_sed.fits
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_439171136_439257536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_439343936_439430336/4fgl_j2232.6+1143_sed.fits
# 30 5
# 30 6
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_439689536_439775936/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 1
# 30 3
# 30 3
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_440294336_440380736/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 2
# 30 1
# 30 1
# 30 0
# 30 1
# 30 4
# 30 0
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_441158336_441244736/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_441503936_441590336/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 1
# 30 4
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_441935936_442022336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_442022336_442108736/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 1
# 30 1
# 30 3
# 30 0
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_442627136_442713536/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_442799936_442886336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_442886336_442972736/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 0
# 30 12
# 30 5
# 30 6
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_443491136_443577536/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_443663936_443750336/4fgl_j2232.6+1143_sed.fits
# 30 7
# 30 6
# 30 8
# 30 3
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_444182336_444268736/4fgl_j2232.6+1143_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 4
# 30 6
# 30 8
# 30 12
# 30 9
# 30 11
# 30 9
# 30 5
# 30 8
# 30 10
# 30 7
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 6
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_445478336_445564736/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_445651136_445737536/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 1
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_445996736_446083136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446083136_446169536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446169536_446255936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446255936_446342336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446342336_446428736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446428736_446515136/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446687936_446774336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446774336_446860736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_446860736_446947136/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 3
# 30 4
# 30 4
# 30 4
# 30 11
# 30 10
# 30 11
# 30 4
# 30 2
# 30 4
# 30 4
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 4
# 30 2
# 30 2
# 30 1
# 30 1
# 30 1
# 30 1
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_448675136_448761536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_448761536_448847936/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 0
# 30 3
# 30 4
# 30 0
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_449452736_449539136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_449539136_449625536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_449711936_449798336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_449798336_449884736/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450143936_450230336/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450316736_450403136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450403136_450489536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450489536_450575936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450575936_450662336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450662336_450748736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450835136_450921536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_450921536_451007936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_451007936_451094336/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_451353536_451439936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_451439936_451526336/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 2
# 30 0
# 30 3
# 30 4
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452131136_452217536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452217536_452303936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452303936_452390336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452390336_452476736/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452649536_452735936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452735936_452822336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452822336_452908736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_452908736_452995136/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453081536_453167936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453254336_453340736/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453427136_453513536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453599936_453686336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453686336_453772736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453772736_453859136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_453859136_453945536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454118336_454204736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454204736_454291136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454291136_454377536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454377536_454463936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454463936_454550336/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454636736_454723136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454723136_454809536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454809536_454895936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454895936_454982336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_454982336_455068736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455155136_455241536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455241536_455327936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455414336_455500736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455500736_455587136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455587136_455673536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455673536_455759936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455759936_455846336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_455846336_455932736/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_456191936_456278336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_456278336_456364736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_456451136_456537536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_456623936_456710336/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 2
# 30 4
# 30 7
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_457142336_457228736/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_457487936_457574336/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_457660736_457747136/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 3
# 30 5
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_458179136_458265536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_458265536_458351936/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_458524736_458611136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_458611136_458697536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_458956736_459043136/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_459129536_459215936/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_459475136_459561536/4fgl_j2232.6+1143_sed.fits
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_459647936_459734336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_459734336_459820736/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_459907136_459993536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460079936_460166336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460166336_460252736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460252736_460339136/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460425536_460511936/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460598336_460684736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460684736_460771136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460771136_460857536/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_460943936_461030336/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 5
# 30 4
# 30 4
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_461462336_461548736/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 4
# 30 4
# 30 5
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462067136_462153536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462153536_462239936/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462326336_462412736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462412736_462499136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462499136_462585536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462585536_462671936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462671936_462758336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462758336_462844736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462844736_462931136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_462931136_463017536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463017536_463103936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463103936_463190336/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463363136_463449536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463535936_463622336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463622336_463708736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463708736_463795136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_463795136_463881536/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_464054336_464140736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_464140736_464227136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_464227136_464313536/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 2
# 30 2
# 30 8
# 30 7
# 30 10
# 30 11
# 30 5
# 30 6
# 30 2
# 30 4
# 30 2
# 30 4
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_465523136_465609536/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 5
# 30 5
# 30 7
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_466041536_466127936/4fgl_j2232.6+1143_sed.fits
# 30 2
# 30 1
# 30 0
# 30 1
# 30 2
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_466732736_466819136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_466819136_466905536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_466991936_467078336/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_467251136_467337536/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_467423936_467510336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_467510336_467596736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_467596736_467683136/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_467683136_467769536/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_467855936_467942336/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_468028736_468115136/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_468201536_468287936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_468374336_468460736/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 2
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_468719936_468806336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_468806336_468892736/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_468979136_469065536/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_469065536_469151936/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_469238336_469324736/4fgl_j2232.6+1143_sed.fits
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_469411136_469497536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_469583936_469670336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_469670336_469756736/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_469843136_469929536/4fgl_j2232.6+1143_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_470015936_470102336/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_470102336_470188736/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_470188736_470275136/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_470361536_470447936/4fgl_j2232.6+1143_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_470447936_470534336/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 3
# 30 2
# 30 12
# 30 9
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 1
# 30 5
# 30 0
# 30 4
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_471484736_471571136/4fgl_j2232.6+1143_sed.fits
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_471657536_471743936/4fgl_j2232.6+1143_sed.fits
# 30 1
# 30 0
# 30 3
# 30 2
# 30 6
# 30 2
# 30 6
# 30 14
# 30 5
# 30 2
# 30 2
# 30 13
# 30 9
# 30 11
# 30 15
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 7
# 30 6
# 30 6
# 30 2
# 30 3
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_473644736_473731136/4fgl_j2232.6+1143_sed.fits
# 30 0
# 30 2
# 30 3
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_474163136_474249536/4fgl_j2232.6+1143_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_474335936_474422336/4fgl_j2232.6+1143_sed.fits
# 30 14
# 30 6
# 30 2
# 30 6
# 30 10
# 30 8
# 30 9
# 30 11
# 30 8
# 30 13
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 18
# 30 10
# 30 12
# 30 15
# 30 12
# 30 10
# 30 15
# 30 7
# 30 8
# 30 14
# 30 9
# 30 9
# 30 16
# 30 12
# 30 14
# 30 17
# 30 12
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 17
# 30 14
# 30 10
# 30 14
# 30 16
# 30 17
# 30 14
# 30 17
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# 30 12
# 30 11
# 30 16
# 30 16
# 30 14
# 30 10
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 10
# 30 11
# 30 14
# 30 7
# 30 8
# 30 7
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 7
# 30 5
# 30 2
# 30 6
# 30 3
# 30 9
# 30 6
# 30 8
# 30 7
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 8
# 30 13
# 30 7
# 30 11
# 30 12
# 30 11
# 30 12
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 12
# 30 9
# 30 12
# 30 12
# 30 10
# 30 7
# 30 9
# 30 7
# 30 3
# 30 6
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_481852736_481939136/4fgl_j2232.6+1143_sed.fits
# 30 8
# 30 6
# 30 8
# 30 10
# 30 14
# 30 6
# 30 5
# 30 3
# 30 4
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 7
# 30 4
# 30 3
# 30 5
# 30 6
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_483235136_483321536/4fgl_j2232.6+1143_sed.fits
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_483407936_483494336/4fgl_j2232.6+1143_sed.fits
# 30 7
# 30 5
# 30 4
# 30 8
# 30 4
# 30 2
# 30 3
# 30 4
# 30 3
# 30 10
# 30 9
# 30 6
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_484531136_484617536/4fgl_j2232.6+1143_sed.fits
# 30 3
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_484790336_484876736/4fgl_j2232.6+1143_sed.fits
# 30 6
# 30 1
# 30 3
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 5
# 30 2
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_485395136_485481536/4fgl_j2232.6+1143_sed.fits
# 30 4
# 30 2
# 30 9
# 30 9
# 30 8
# 30 8
# 30 8
# 30 2
# 30 2
# 30 2
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_486431936_486518336/4fgl_j2232.6+1143_sed.fits
# 30 7
# 30 11
# 30 13
# 30 11
# 30 9
# 30 13
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# ...
# 30 14
# 30 15
# 30 19
# 30 18
# 30 21
# 30 16
# 30 17
# 30 18
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 19
# 30 17
# 30 20
# 30 20
# 30 20
# 30 17
# 30 19
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 19
# 30 19
# 30 19
# 30 21
# 30 21
# 30 19
# 30 16
# 30 17
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 19
# 30 19
# 30 21
# 30 20
# 30 17
# 30 16
# 30 15
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 16
# 30 18
# 30 13
# 30 16
# 30 16
# 30 15
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# 30 13
# 30 14
# 30 12
# 30 18
# 30 14
# 30 15
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 13
# 30 13
# 30 13
# 30 4
# 30 8
# 30 9
# 30 12
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# 30 14
# 30 17
# 30 18
# 30 19
# 30 19
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 20
# 30 14
# 30 13
# 30 14
# 30 14
# 30 8
# 30 10
# 30 9
# 30 5
# 30 8
# 30 8
# 30 6
# 30 6
# 30 13
# 30 10
# 30 8
# 30 9
# 30 8
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 7
# 30 10
# 30 8
# 30 11
# 30 5
# 30 8
# 30 4
# 30 10
# 30 5
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 4
# 30 7
# 30 8
# 30 7
# 30 13
# 30 8
# 30 11
# 30 11
# 30 8
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 12
# 30 11
# 30 12
# 30 12
# 30 13
# 30 15
# 30 17
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# 30 13
# 30 7
# 30 7
# 30 5
# 30 3
# 30 3
# 30 0
# 30 7
# 30 7
# 30 8
# 30 6
# 30 9
# 30 11
# 30 9
# 30 8
# 30 15
# 30 20
# 30 18
# 30 9
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 11
# 30 9
# 30 9
# 30 9
# 30 8
# 30 8
# 30 9
# 30 13
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# 30 7
# 30 9
# 30 8
# 30 6
# 30 9
# 30 11
# 30 9
# 30 15
# 30 17
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 14
# 30 17
# 30 17
# 30 15
# 30 16
# 30 13
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 6
# 30 8
# 30 7
# 30 4
# 30 4
# 30 5
# 30 5
# 30 10
# 30 10
# 30 8
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 11
# 30 11
# 30 10
# 30 4
# 30 10
# 30 4
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 5
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days/lightcurve_518745536_518831936/4fgl_j2232.6+1143_sed.fits
# 30 3

# %%
print(table_allSEDs.colnames)
# Out:
# ['e_min', 'e_ref', 'e_max', 'ref_dnde_e_min', 'ref_dnde_e_max', 'ref_dnde', 'ref_flux', 'ref_eflux', 'ref_npred', 'dnde', 'dnde_err', 'dnde_errp', 'dnde_errn', 'dnde_ul', 'e2dnde', 'e2dnde_err', 'e2dnde_errp', 'e2dnde_errn', 'e2dnde_ul', 'norm', 'norm_err', 'norm_errp', 'norm_errn', 'norm_ul', 'ts', 'loglike', 'norm_scan', 'dloglike_scan', 'ShowUL', 'tstart', 'tend']

# %%
table_allSEDs
# Out:
# <Table length=10>
#       e_min              e_ref        ...       tstart             tend
#        MeV                MeV         ...
#      float64            float64       ...      float64           float64
# ------------------ ------------------ ... ----------------- -----------------
#              100.0 115.25240587974294 ... 56901.00077759222 56902.00077759222
# 132.83117061068992   153.091119887046 ... 56901.00077759222 56902.00077759222
#  176.4411988580621 203.35272664697808 ... 56901.00077759222 56902.00077759222
# 234.36890988269914  270.1158072739371 ... 56901.00077759222 56902.00077759222
#  311.3149665447022  358.7979888064861 ... 56901.00077759222 56902.00077759222
# 413.52331434760555  476.5900816815941 ... 56901.00077759222 56902.00077759222
#  549.2752115212968  633.0528961793416 ... 56901.00077759222 56902.00077759222
#  729.6086933380817  840.8915725798939 ... 56901.00077759222 56902.00077759222
#  969.1477682383326 1116.9661194245136 ... 56901.00077759222 56902.00077759222
# 1287.3303254983532 1483.6791717563765 ... 56901.00077759222 56902.00077759222

# %% [markdown]
# # Make an ecsv file which contains SEDs of all periods with significant number of data points
#
# From
# `/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/Generate_timebinned_MWLSED.ipynb`
#
#
# `/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days`
# Number of significant SEDs: 264
#
# `home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days`
# Number of significant SEDs: 208

# %%
import os

# # 3C454.3
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# '/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days/{directoryname}/4fgl_j2253.9+1609_sed.fits'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # S20109+22 Number of significant SEDs: 58
# # S20109+22 = 4fgl_j0112.1+2245
# # Number of significant SEDs: 58
# source_name='S20109+22'
# source_name_4fgl='4fgl_j0112.1+2245'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/5_S20109+22_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 8_PKS1510-089_100MeV_14d Number of significant SEDs: 214
# # PKS1510-089 = 4fgl_j1512.8-0906
# # Number of significant SEDs: 40
# source_name='PKS1510-089'
# source_name_4fgl='4fgl_j1512.8-0906'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/8_PKS1510-089_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 9_4C+21.35_100MeV_14d Number of significant SEDs: 103
# # 4C+21.35 = 4fgl_j1224.9+2122
# source_name='4C+21.35'
# source_name_4fgl='4fgl_j1224.9+2122'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/9_4C+21.35_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 10_Mrk421_100MeV_14d Number of significant SEDs: 403
# # 4C+21.35 = 4fgl_j1224.9+2122
# source_name='Mrk421'
# source_name_4fgl='4fgl_j1104.4+3812'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 11_CTA102_100MeV_14d Number of significant SEDs: 180
# # CTA102 = 4fgl_j2232.6+1143s
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/11_CTA102_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# print(sed_path_test)

# # 13 3C454.3  Number of significant SEDs: 566
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/13_3C454_100MeV_1d_first1050days/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'
# '/home/kazuma/Workspace/AGN_data/13_3C454_100MeV_1d_first1050days/1days/{directoryname}/4fgl_j2253.9+1609_sed.fits'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 12_BLLac_100MeV_14d Number of significant SEDs: 298
# # BLLac = 4fgl_j2202.7+4216
# source_name='BLLac'
# source_name_4fgl='4fgl_j2202.7+4216'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/12_BLLac_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# print(sed_path_test)

# # 14_3C279_100MeV_14d Number of significant SEDs: 261
# # 3C279 = 4fgl_j1256.1-0547
# source_name='3C279'
# source_name_4fgl='4fgl_j1256.1-0547'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/14_3C279_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
# print(sed_path_test)

# # 15_3C454_100MeV_1d_second1150days Number of significant SEDs: 468
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/15_3C454_100MeV_1d_second1150days/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_2_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 16_S50716+71_100MeV_14d  Number of significant SEDs: 285
# # S50716+71 = 4fgl_j0721.9+7120
# source_name='S50716+71'
# source_name_4fgl='4fgl_j0721.9+7120'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/16_S50716+71_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 17_PKS1424-41_100MeV_14d Number of significant SEDs: 299
# # PKS1424-41 = 4fgl_j1427.9-4206
# source_name='PKS1424-41'
# source_name_4fgl='4fgl_j1427.9-4206'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/17_PKS1424-41_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 18_PKS0426-380_100MeV_14d Number of significant SEDs: 189
# # PKS0426-380 = 4fgl_j0428.6-3756
# source_name='PKS0426-380'
# source_name_4fgl='4fgl_j0428.6-3756'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/18_PKS0426-380_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 19_PKS0537-441_100MeV_14d Number of significant SEDs: 224
# # PKS0537-441 = 4fgl_j0538.8-4405
# source_name='PKS0537-441'
# source_name_4fgl='4fgl_j0538.8-4405'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/19_PKS0537-441_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 20_PKS2155-304_100MeV_14d Number of significant SEDs: 166
# # PKS2155-304 = 4fgl_j2158.8-3013
# source_name='PKS2155-304'
# source_name_4fgl='4fgl_j2158.8-3013'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/20_PKS2155-304_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 21_PKS0454-234_100MeV_14d Number of significant SEDs: 242
# # PKS0454-234 = 4fgl_j0457.0-2324
# source_name='PKS0454-234'
# source_name_4fgl='4fgl_j0457.0-2324'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/21_PKS0454-234_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 22_PKS1502+106_100MeV_14d Number of significant SEDs: 147
# # PKS1502+106 = 4fgl_j1504.4+1029
# source_name='PKS1502+106'
# source_name_4fgl='4fgl_j1504.4+1029'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/22_PKS1502+106_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 23_Ton599_100MeV_14d Number of significant SEDs: 186
# # Ton599 = 4fgl_j1159.5+2914
# source_name='Ton599'
# source_name_4fgl='4fgl_j1159.5+2914'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/23_Ton599_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 24_4C+55.17_100MeV_14d  Number of significant SEDs: 57
# # 4C+55.17 = 4fgl_j0957.6+5523
# source_name='4C+55.17'
# source_name_4fgl='4fgl_j0957.6+5523'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/24_4C+55.17_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 25_PKS0346-27_100MeV_14d Number of significant SEDs: 111
# # PKS0346-27 = 4fgl_j0348.5-2749
# source_name='PKS0346-27'
# source_name_4fgl='4fgl_j0348.5-2749'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/25_PKS0346-27_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 26_4C+01.02_100MeV_14d Number of significant SEDs: 158
# # 4C+01.02 = 4fgl_j0108.6+0134
# source_name='4C+01.02'
# source_name_4fgl='4fgl_j0108.6+0134'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/26_4C+01.02_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 27_PKS1830-211_100MeV_14d Number of significant SEDs: 117
# # PKS1830-211 = 4fgl_j1833.6-2103
# source_name='PKS1830-211'
# source_name_4fgl='4fgl_j1833.6-2103'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 27_PKS1830-211_100MeV_1d Number of significant SEDs: 170
# # PKS1830-211 = 4fgl_j1833.6-2103
# source_name='PKS1830-211'
# source_name_4fgl='4fgl_j1833.6-2103'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# 27_PKS1830-211_100MeV_1d_1  Number of significant SEDs: 168
# PKS1830-211 = 4fgl_j1833.6-2103
source_name='PKS1830-211'
source_name_4fgl='4fgl_j1833.6-2103'
input_directory_parent='/home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days'
directoryname_test='lightcurve_xxx_xxx'
sed_filename=f'{source_name_4fgl}_sed.fits'
outfilename=f'{source_name}_allsed_1d_1_min11.ecsv'
sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 27_PKS1830-211_100MeV_1d_2  Number of significant SEDs: 27
# # PKS1830-211 = 4fgl_j1833.6-2103
# source_name='PKS1830-211'
# source_name_4fgl='4fgl_j1833.6-2103'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_2/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_2_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 28_PKS0208-512_100MeV_14d Number of significant SEDs: 94
# # PKS0208-512 = 4fgl_j0210.7-5101
# source_name='PKS0208-512'
# source_name_4fgl='4fgl_j0210.7-5101'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/28_PKS0208-512_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_1d Number of significant SEDs: 1
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_1d/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_1h Number of significant SEDs: 2
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_1h/0.041666666666666664days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1h_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_2h Number of significant SEDs: 2
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_2h/0.08333333333333333days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_2h_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_30min Number of significant SEDs: 2
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_30min/0.020833333333333332days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_30min_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_10min Number of significant SEDs: 2
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_10min/0.006944444444444444days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_10min_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 29_GB6J1040+0617_100MeV_2min Number of significant SEDs: 2
# # GB6J1040+0617 = 4fgl_j1040.5+0617
# source_name='GB6J1040+0617'
# source_name_4fgl='4fgl_j1040.5+0617'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/29_GB6J1040+0617_100MeV_2min/0.0013888888888888887days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_2min_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# 30_CTA102_100MeV_1d Number of significant SEDs: 0
# # CTA102 = 4fgl_j2232.6+1143
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_1_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 30_CTA102_100MeV_1d_2 Number of significant SEDs: 265
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_2/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_2_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 30_CTA102_100MeV_1d_3 Number of significant SEDs: 97
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_1d_3/1days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_1d_3_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 30_CTA102_100MeV_7d Number of significant SEDs: 226
# source_name='CTA102'
# source_name_4fgl='4fgl_j2232.6+1143'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/30_CTA102_100MeV_7d/7days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_7d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# %%
####################################################################
# for Inline animations in Jupyter
# https://stackoverflow.com/questions/43445103/inline-animations-in-jupyter
####################################################################
# Enable interactive plot
# %matplotlib notebook

import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import os

####################################################################
# Functions
####################################################################
##################################
# 
##################################
def met_to_mjd(met) :
    mjd = 51910. + 7.4287e-4 + met/86400.
    return mjd
# print(mjd_start, mjd_end)
# print(met_to_mjd(mjd_start), met_to_mjd(mjd_end))
##################################
#  GET fermi SED table from fits file
##################################
from astropy.table import Table
def getsed(timebin_start,timebin_end):
    # print(directories)
    directoryname=f'lightcurve_{timebin_start}_{timebin_end}'
    sed_path=os.path.join(input_directory_parent,directoryname,sed_filename )
    try : 
        sed_tab= Table.read(sed_path)
        # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
        # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
        return sed_tab
    except:
        print('not found: ', sed_path)    
        return None

from astropy import units as u
from astropy.io import ascii

# %%
mjd_min=45000#55000
mjd_max=65000#56000

##################################
# Get subdirectories within time scope
directories=os.listdir(input_directory_parent)
# directories=os.listdir('/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days')
timebins_start=[]
timebins_end=[]
for directoryname in directories:
    elements=directoryname.split('_')
    timebin_start=met_to_mjd(float(elements[1]))
    timebin_end=met_to_mjd(float(elements[2]))
#     print(elements[1],elements[2])
#     print(timebin_start, timebin_end)
    if timebin_end>mjd_max*1.0001 :
        continue        
    if timebin_start<mjd_min*0.9999 :
        continue
    timebins_start.append(int(elements[1]))
    timebins_end.append(int(elements[2]))

timebins_start.sort()
timebins_end.sort()
print(timebins_start[0], timebins_end[-1])
print('Which are {} and {}'.format(mjd_min,mjd_max))
print(met_to_mjd(timebins_start[0]), met_to_mjd(timebins_end[-1]))
# Out:
# 559526336 624844735
# Which are 45000 and 65000
# 58386.00000212926 59141.99999055518

# %%
##################################
# Get Fermi SED
##################################
n_significant_sed=0
for i in range(len(timebins_start)):
    timebin_start=timebins_start[i]
    timebin_end=timebins_end[i]
    sed_tab=getsed(timebin_start,timebin_end)
    if sed_tab is None:
        continue

    default_eref=sed_tab['e_ref']
    default_flux=np.ones(len(default_eref))*1e-4
    default_asymmerr=[np.ones(len(default_eref))*1e-5,np.ones(len(default_eref))*1e-5]

    default_errdiff=np.ones(len(default_eref))
    default_ts=np.ones(len(default_eref))*0.1
    high_significance_mask = (sed_tab['ts']>=9)
    low_significance_mask = (sed_tab['ts']<9)
    sed_tab['ShowUL']=low_significance_mask
    sed_tab_significant=sed_tab[high_significance_mask]
    sed_tab_nosignificant=sed_tab[low_significance_mask]
    print(len(sed_tab['e_ref']),len(sed_tab_significant['e_ref']))
    if len(sed_tab_significant['e_ref'])>=11:
        n_significant_sed+=1
    # print(len(sed_tab_nosignificant['e_ref']),len(sed_tab_nosignificant['e2dnde_ul']))
    # print(sed_tab_nosignificant['e_ref'],sed_tab_nosignificant['e2dnde_ul'])

print('Number of significant SEDs:',n_significant_sed)
# Out:
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_559526336_559612736/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_559699136_559785536/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# 30 3
# 30 2
# 30 2
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_560390336_560476736/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 1
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 0
# 30 1
# 30 1
# 30 1
# 30 1
# 30 1
# 30 3
# 30 2
# 30 4
# 30 5
# 30 11
# 30 7
# 30 7
# 30 10
# 30 12
# 30 9
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562118336_562204736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562204736_562291136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562291136_562377536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562377536_562463936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562463936_562550336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562550336_562636736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562636736_562723136/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 1
# 30 4
# 30 5
# 30 4
# 30 2
# 30 4
# 30 8
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_563500736_563587136/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_563846336_563932736/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_564191936_564278336/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 3
# 30 3
# 30 4
# 30 4
# 30 3
# 30 5
# 30 7
# 30 5
# 30 9
# 30 9
# 30 14
# 30 14
# 30 10
# 30 5
# 30 5
# 30 6
# 30 12
# 30 7
# 30 5
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566092736_566179136/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566265536_566351936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566351936_566438336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566438336_566524736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566524736_566611136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566611136_566697536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566697536_566783936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566783936_566870336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566870336_566956736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566956736_567043136/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567215936_567302336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567302336_567388736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567388736_567475136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567475136_567561536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567561536_567647936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567647936_567734336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567734336_567820736/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567907136_567993536/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 6
# 30 3
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_568425536_568511936/4fgl_j1833.6-2103_sed.fits
# 30 6
# 30 12
# 30 12
# 30 11
# 30 7
# 30 9
# 30 9
# 30 9
# 30 12
# 30 12
# 30 11
# 30 11
# 30 13
# 30 11
# 30 12
# 30 12
# 30 13
# 30 11
# 30 9
# 30 12
# 30 2
# 30 2
# 30 2
# 30 2
# 30 4
# 30 4
# 30 6
# 30 11
# 30 8
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_571103936_571190336/4fgl_j1833.6-2103_sed.fits
# 30 8
# 30 12
# 30 7
# 30 16
# 30 12
# 30 10
# 30 9
# 30 9
# 30 7
# 30 9
# 30 3
# 30 4
# 30 10
# 30 10
# 30 8
# 30 7
# 30 9
# 30 9
# 30 8
# 30 11
# 30 12
# 30 13
# 30 10
# 30 10
# 30 12
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_573436736_573523136/4fgl_j1833.6-2103_sed.fits
# 30 9
# 30 9
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_573782336_573868736/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 8
# 30 11
# 30 13
# 30 9
# 30 9
# 30 11
# 30 11
# 30 12
# 30 12
# 30 12
# 30 12
# 30 13
# 30 12
# 30 14
# 30 13
# 30 12
# 30 11
# 30 11
# 30 10
# 30 10
# 30 16
# 30 14
# 30 17
# 30 18
# 30 14
# 30 15
# 30 14
# 30 15
# 30 17
# 30 16
# 30 14
# 30 15
# 30 13
# 30 14
# 30 15
# 30 16
# 30 15
# 30 14
# 30 11
# 30 12
# 30 14
# 30 16
# 30 15
# 30 16
# 30 15
# 30 16
# 30 14
# 30 17
# 30 13
# 30 16
# 30 14
# 30 11
# 30 13
# 30 13
# 30 11
# 30 12
# 30 12
# 30 15
# 30 14
# 30 11
# 30 10
# 30 12
# 30 10
# 30 15
# 30 14
# 30 15
# 30 13
# 30 14
# 30 13
# 30 15
# 30 15
# 30 12
# 30 10
# 30 10
# 30 10
# 30 10
# 30 3
# 30 3
# 30 7
# 30 6
# 30 5
# 30 1
# 30 0
# 30 3
# 30 5
# 30 5
# 30 5
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_581558336_581644736/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_581817536_581903936/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_581990336_582076736/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 7
# 30 6
# 30 13
# 30 8
# 30 8
# 30 11
# 30 8
# 30 8
# 30 14
# 30 8
# 30 10
# 30 12
# 30 15
# 30 10
# 30 11
# 30 11
# 30 5
# 30 6
# 30 10
# 30 7
# 30 8
# 30 10
# 30 9
# 30 10
# 30 12
# 30 10
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_584495936_584582336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_584582336_584668736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_584668736_584755136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_584755136_584841536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_584841536_584927936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_584927936_585014336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585014336_585100736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585100736_585187136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585187136_585273536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585273536_585359936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585359936_585446336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585446336_585532736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585532736_585619136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585619136_585705536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585705536_585791936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585791936_585878336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585878336_585964736/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_586051136_586137536/4fgl_j1833.6-2103_sed.fits
# 30 9
# 30 12
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_586396736_586483136/4fgl_j1833.6-2103_sed.fits
# 30 11
# 30 14
# 30 11
# 30 11
# 30 11
# 30 12
# 30 12
# 30 14
# 30 12
# 30 12
# 30 11
# 30 12
# 30 12
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_587692736_587779136/4fgl_j1833.6-2103_sed.fits
# 30 6
# 30 8
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_588038336_588124736/4fgl_j1833.6-2103_sed.fits
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_588211136_588297536/4fgl_j1833.6-2103_sed.fits
# 30 8
# 30 8
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_588556736_588643136/4fgl_j1833.6-2103_sed.fits
# 30 13
# 30 10
# 30 13
# 30 10
# 30 11
# 30 8
# 30 9
# 30 11
# 30 14
# 30 10
# 30 10
# 30 9
# 30 10
# 30 14
# 30 13
# 30 15
# 30 16
# 30 13
# 30 16
# 30 14
# 30 15
# 30 12
# 30 13
# 30 11
# 30 10
# 30 11
# 30 12
# 30 9
# 30 14
# 30 12
# 30 12
# 30 13
# 30 11
# 30 12
# 30 10
# 30 11
# 30 13
# 30 13
# 30 11
# 30 13
# 30 12
# 30 11
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_592358336_592444736/4fgl_j1833.6-2103_sed.fits
# 30 9
# 30 6
# 30 5
# 30 6
# 30 4
# 30 8
# 30 3
# 30 6
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_593222336_593308736/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 5
# 30 6
# 30 8
# 30 10
# 30 4
# 30 10
# 30 12
# 30 11
# 30 14
# 30 14
# 30 13
# 30 10
# 30 11
# 30 10
# 30 6
# 30 3
# 30 5
# 30 8
# 30 3
# 30 8
# 30 8
# 30 11
# 30 10
# 30 11
# 30 7
# 30 12
# 30 9
# 30 10
# 30 11
# 30 11
# 30 12
# 30 9
# 30 8
# 30 6
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_596419136_596505536/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 2
# 30 4
# 30 3
# 30 8
# 30 8
# 30 9
# 30 10
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_597283136_597369536/4fgl_j1833.6-2103_sed.fits
# 30 7
# 30 6
# 30 9
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_597715136_597801536/4fgl_j1833.6-2103_sed.fits
# 30 11
# 30 13
# 30 14
# 30 14
# 30 11
# 30 11
# 30 10
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_598492736_598579136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_598579136_598665536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_598665536_598751936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_598751936_598838336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_598838336_598924736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_598924736_599011136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599011136_599097536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599097536_599183936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599183936_599270336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599270336_599356736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599356736_599443136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599443136_599529536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599529536_599615936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599615936_599702336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599702336_599788736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599788736_599875136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599875136_599961536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599961536_600047936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_600047936_600134336/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 5
# 30 7
# 30 6
# 30 4
# 30 5
# 30 4
# 30 5
# 30 4
# 30 3
# 30 3
# 30 3
# 30 3
# 30 2
# 30 2
# 30 2
# 30 1
# 30 3
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_601775936_601862336/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 2
# 30 5
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_602207936_602294336/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 6
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_602553536_602639936/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_602812736_602899136/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 3
# 30 3
# 30 4
# 30 2
# 30 3
# 30 1
# 30 3
# 30 5
# 30 2
# 30 4
# 30 5
# 30 6
# 30 4
# 30 5
# 30 8
# 30 1
# 30 4
# 30 5
# 30 7
# 30 11
# 30 11
# 30 7
# 30 3
# 30 5
# 30 2
# 30 5
# 30 2
# 30 6
# 30 4
# 30 0
# 30 1
# 30 2
# 30 3
# 30 3
# 30 0
# 30 5
# 30 3
# 30 1
# 30 2
# 30 3
# 30 2
# 30 0
# 30 2
# 30 0
# 30 1
# 30 2
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_607132736_607219136/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 3
# 30 2
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_607564736_607651136/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_607737536_607823936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_607823936_607910336/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_607996736_608083136/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_608169536_608255936/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 0
# 30 3
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_608687936_608774336/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# 30 3
# 30 0
# 30 0
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_609379136_609465536/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_609551936_609638336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_609638336_609724736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_609724736_609811136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_609811136_609897536/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 1
# 30 0
# 30 0
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_610415936_610502336/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_610588736_610675136/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 0
# 30 2
# 30 0
# 30 0
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_611366336_611452736/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_611798336_611884736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_611884736_611971136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_611971136_612057536/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612143936_612230336/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612403136_612489536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612489536_612575936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612575936_612662336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612662336_612748736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612748736_612835136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612835136_612921536/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613180736_613267136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613267136_613353536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613353536_613439936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613439936_613526336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613526336_613612736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613612736_613699136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613699136_613785536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613785536_613871936/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613958336_614044736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_614044736_614131136/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_614303936_614390336/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_614649536_614735936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_614735936_614822336/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# 30 0
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_615254336_615340736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_615340736_615427136/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_615513536_615599936/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 2
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616031936_616118336/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 1
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616463936_616550336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616550336_616636736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616636736_616723136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616723136_616809536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616809536_616895936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616895936_616982336/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617068736_617155136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617155136_617241536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617241536_617327936/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617500736_617587136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617587136_617673536/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617759936_617846336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617846336_617932736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617932736_618019136/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 6
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_618278336_618364736/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 3
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_618623936_618710336/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_618796736_618883136/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 3
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_619228736_619315136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_619315136_619401536/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_619574336_619660736/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 2
# 30 2
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_620092736_620179136/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_620351936_620438336/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_620611136_620697536/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 3
# 30 4
# 30 1
# 30 1
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_621302336_621388736/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 0
# 30 2
# 30 2
# 30 2
# 30 3
# 30 6
# 30 2
# 30 4
# 30 7
# 30 7
# 30 9
# 30 5
# 30 8
# 30 5
# 30 8
# 30 5
# 30 9
# 30 7
# 30 5
# 30 2
# 30 2
# 30 3
# 30 3
# 30 4
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_623635136_623721536/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_623807936_623894336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_623894336_623980736/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_624067136_624153536/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 1
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_624499136_624585536/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 0
# Number of significant SEDs: 168

# %%
##################################
# Get Fermi SED
##################################

from astropy.table import Table, vstack
table_allSEDs=Table()
n_significant_sed=0
for i in range(len(timebins_start)):
    timebin_start=timebins_start[i]
    timebin_end=timebins_end[i]
    sed_tab=getsed(timebin_start,timebin_end)
    if sed_tab is None:
        continue

    default_eref=sed_tab['e_ref']
    default_flux=np.ones(len(default_eref))*1e-4
    default_asymmerr=[np.ones(len(default_eref))*1e-5,np.ones(len(default_eref))*1e-5]

    default_errdiff=np.ones(len(default_eref))
    default_ts=np.ones(len(default_eref))*0.1
    high_significance_mask = (sed_tab['ts']>=9)
    low_significance_mask = (sed_tab['ts']<9)
    sed_tab['ShowUL']=low_significance_mask
    sed_tab_significant=sed_tab[high_significance_mask]
    sed_tab_nosignificant=sed_tab[low_significance_mask]
    print(len(sed_tab['e_ref']),len(sed_tab_significant['e_ref']))
    if len(sed_tab_significant['e_ref'])>=11:
        n_significant_sed+=1
        sed_tab_significant['tstart']=[met_to_mjd(timebin_start)]*len(sed_tab_significant['e_ref'])
        sed_tab_significant['tend']=[met_to_mjd(timebin_end)]*len(sed_tab_significant['e_ref'])
        table_allSEDs=vstack([table_allSEDs, sed_tab_significant])

    # print(len(sed_tab_nosignificant['e_ref']),len(sed_tab_nosignificant['e2dnde_ul']))
    # print(sed_tab_nosignificant['e_ref'],sed_tab_nosignificant['e2dnde_ul'])


table_allSEDs.write(outfilename)
# print(t)

# print('Number of significant SEDs:',n_significant_sed)
# Out:
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_559526336_559612736/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_559699136_559785536/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# 30 3
# 30 2
# 30 2
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_560390336_560476736/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 1
# 30 0
# 30 1
# 30 1
# 30 1
# 30 1
# 30 1
# 30 3
# 30 2
# 30 4
# 30 5
# 30 11
# 30 7
# 30 7
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 12
# 30 9
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562118336_562204736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562204736_562291136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562291136_562377536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562377536_562463936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562463936_562550336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562550336_562636736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_562636736_562723136/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 1
# 30 4
# 30 5
# 30 4
# 30 2
# 30 4
# 30 8
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_563500736_563587136/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 2
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_563846336_563932736/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_564191936_564278336/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 3
# 30 3
# 30 4
# 30 4
# 30 3
# 30 5
# 30 7
# 30 5
# 30 9
# 30 9
# 30 14
# 30 14
# 30 10
# 30 5
# 30 5
# 30 6
# 30 12
# 30 7
# 30 5
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566092736_566179136/4fgl_j1833.6-2103_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566265536_566351936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566351936_566438336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566438336_566524736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566524736_566611136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566611136_566697536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566697536_566783936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566783936_566870336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566870336_566956736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_566956736_567043136/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567215936_567302336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567302336_567388736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567388736_567475136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567475136_567561536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567561536_567647936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567647936_567734336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567734336_567820736/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_567907136_567993536/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 6
# 30 3
# 30 1
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_568425536_568511936/4fgl_j1833.6-2103_sed.fits
# 30 6
# 30 12
# 30 12
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 7
# 30 9
# 30 9
# 30 9
# 30 12
# 30 12
# 30 11
# 30 11
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 12
# 30 12
# 30 13
# 30 11
# 30 9
# 30 12
# 30 2
# 30 2
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 2
# 30 2
# 30 4
# 30 4
# 30 6
# 30 11
# 30 8
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_571103936_571190336/4fgl_j1833.6-2103_sed.fits
# 30 8
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 7
# 30 16
# 30 12
# 30 10
# 30 9
# 30 9
# 30 7
# 30 9
# 30 3
# 30 4
# 30 10
# 30 10
# 30 8
# 30 7
# 30 9
# 30 9
# 30 8
# 30 11
# 30 12
# 30 13
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 12
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_573436736_573523136/4fgl_j1833.6-2103_sed.fits
# 30 9
# 30 9
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_573782336_573868736/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 8
# 30 11
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 9
# 30 9
# 30 11
# 30 11
# 30 12
# 30 12
# 30 12
# 30 12
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 14
# 30 13
# 30 12
# 30 11
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 10
# 30 10
# 30 16
# 30 14
# 30 17
# 30 18
# 30 14
# 30 15
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 17
# 30 16
# 30 14
# 30 15
# 30 13
# 30 14
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# 30 15
# 30 14
# 30 11
# 30 12
# 30 14
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 16
# 30 15
# 30 16
# 30 14
# 30 17
# 30 13
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 11
# 30 13
# 30 13
# 30 11
# 30 12
# 30 12
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 11
# 30 10
# 30 12
# 30 10
# 30 15
# 30 14
# 30 15
# 30 13
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 13
# 30 15
# 30 15
# 30 12
# 30 10
# 30 10
# 30 10
# 30 10
# 30 3
# 30 3
# 30 7
# 30 6
# 30 5
# 30 1
# 30 0
# 30 3
# 30 5
# 30 5
# 30 5
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_581558336_581644736/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_581817536_581903936/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_581990336_582076736/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 7
# 30 6
# 30 13
# 30 8
# 30 8
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 8
# 30 8
# 30 14
# 30 8
# 30 10
# 30 12
# 30 15
# 30 10
# 30 11
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 5
# 30 6
# 30 10
# 30 7
# 30 8
# 30 10
# 30 9
# 30 10
# 30 12
# 30 10
# 30 0
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_584495936_584582336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_584582336_584668736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_584668736_584755136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_584755136_584841536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_584841536_584927936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_584927936_585014336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585014336_585100736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585100736_585187136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585187136_585273536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585273536_585359936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585359936_585446336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585446336_585532736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585532736_585619136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585619136_585705536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585705536_585791936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585791936_585878336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_585878336_585964736/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_586051136_586137536/4fgl_j1833.6-2103_sed.fits
# 30 9
# 30 12
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_586396736_586483136/4fgl_j1833.6-2103_sed.fits
# 30 11
# 30 14
# 30 11
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 12
# 30 12
# 30 14
# 30 12
# 30 12
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 12
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_587692736_587779136/4fgl_j1833.6-2103_sed.fits
# 30 6
# 30 8
# 30 11
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_588038336_588124736/4fgl_j1833.6-2103_sed.fits
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_588211136_588297536/4fgl_j1833.6-2103_sed.fits
# 30 8
# 30 8
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_588556736_588643136/4fgl_j1833.6-2103_sed.fits
# 30 13
# 30 10
# 30 13
# 30 10
# 30 11
# 30 8
# 30 9
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 10
# 30 10
# 30 9
# 30 10
# 30 14
# 30 13
# 30 15
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 16
# 30 14
# 30 15
# 30 12
# 30 13
# 30 11
# 30 10
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 12
# 30 9
# 30 14
# 30 12
# 30 12
# 30 13
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 12
# 30 10
# 30 11
# 30 13
# 30 13
# 30 11
# 30 13
# 30 12
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_592358336_592444736/4fgl_j1833.6-2103_sed.fits
# 30 9
# 30 6
# 30 5
# 30 6
# 30 4
# 30 8
# 30 3
# 30 6
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_593222336_593308736/4fgl_j1833.6-2103_sed.fits
# 30 3
# 30 5
# 30 6
# 30 8
# 30 10
# 30 4
# 30 10
# 30 12
# 30 11
# 30 14
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 13
# 30 10
# 30 11
# 30 10
# 30 6
# 30 3
# 30 5
# 30 8
# 30 3
# 30 8
# 30 8
# 30 11
# 30 10
# 30 11
# 30 7
# 30 12
# 30 9
# 30 10
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 11
# 30 12
# 30 9
# 30 8
# 30 6
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_596419136_596505536/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 2
# 30 4
# 30 3
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 8
# 30 8
# 30 9
# 30 10
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_597283136_597369536/4fgl_j1833.6-2103_sed.fits
# 30 7
# 30 6
# 30 9
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_597715136_597801536/4fgl_j1833.6-2103_sed.fits
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# 30 14
# 30 14
# 30 11
# 30 11
# 30 10
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_598492736_598579136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_598579136_598665536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_598665536_598751936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_598751936_598838336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_598838336_598924736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_598924736_599011136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599011136_599097536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599097536_599183936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599183936_599270336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599270336_599356736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599356736_599443136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599443136_599529536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599529536_599615936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599615936_599702336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599702336_599788736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599788736_599875136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599875136_599961536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_599961536_600047936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_600047936_600134336/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 5
# 30 7
# 30 6
# 30 4
# 30 5
# 30 4
# 30 5
# 30 4
# 30 3
# 30 3
# 30 3
# 30 3
# 30 2
# 30 2
# 30 2
# 30 1
# 30 3
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_601775936_601862336/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 2
# 30 5
# 30 7
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_602207936_602294336/4fgl_j1833.6-2103_sed.fits
# 30 4
# 30 6
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_602553536_602639936/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 5
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_602812736_602899136/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 3
# 30 3
# 30 4
# 30 2
# 30 3
# 30 1
# 30 3
# 30 5
# 30 2
# 30 4
# 30 5
# 30 6
# 30 4
# 30 5
# 30 8
# 30 1
# 30 4
# 30 5
# 30 7
# 30 11
# 30 11
# 30 7
# 30 3
# 30 5
# 30 2
# 30 5
# 30 2
# 30 6
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 4
# 30 0
# 30 1
# 30 2
# 30 3
# 30 3
# 30 0
# 30 5
# 30 3
# 30 1
# 30 2
# 30 3
# 30 2
# 30 0
# 30 2
# 30 0
# 30 1
# 30 2
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_607132736_607219136/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 3
# 30 2
# 30 4
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_607564736_607651136/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_607737536_607823936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_607823936_607910336/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_607996736_608083136/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_608169536_608255936/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 0
# 30 3
# 30 0
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_608687936_608774336/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# 30 3
# 30 0
# 30 0
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_609379136_609465536/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_609551936_609638336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_609638336_609724736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_609724736_609811136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_609811136_609897536/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 1
# 30 0
# 30 0
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_610415936_610502336/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_610588736_610675136/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 0
# 30 2
# 30 0
# 30 0
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_611366336_611452736/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_611798336_611884736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_611884736_611971136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_611971136_612057536/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612143936_612230336/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612403136_612489536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612489536_612575936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612575936_612662336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612662336_612748736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612748736_612835136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_612835136_612921536/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613180736_613267136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613267136_613353536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613353536_613439936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613439936_613526336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613526336_613612736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613612736_613699136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613699136_613785536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613785536_613871936/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_613958336_614044736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_614044736_614131136/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_614303936_614390336/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 2
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_614649536_614735936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_614735936_614822336/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# 30 0
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_615254336_615340736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_615340736_615427136/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_615513536_615599936/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 2
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616031936_616118336/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 1
# 30 1
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616463936_616550336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616550336_616636736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616636736_616723136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616723136_616809536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616809536_616895936/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_616895936_616982336/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617068736_617155136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617155136_617241536/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617241536_617327936/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617500736_617587136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617587136_617673536/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617759936_617846336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617846336_617932736/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_617932736_618019136/4fgl_j1833.6-2103_sed.fits
# 30 5
# 30 6
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_618278336_618364736/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 3
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_618623936_618710336/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_618796736_618883136/4fgl_j1833.6-2103_sed.fits
# 30 1
# 30 3
# 30 0
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_619228736_619315136/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_619315136_619401536/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_619574336_619660736/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 2
# 30 2
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_620092736_620179136/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_620351936_620438336/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_620611136_620697536/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 3
# 30 4
# 30 1
# 30 1
# 30 3
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_621302336_621388736/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 0
# 30 2
# 30 2
# 30 2
# 30 3
# 30 6
# 30 2
# 30 4
# 30 7
# 30 7
# 30 9
# 30 5
# 30 8
# 30 5
# 30 8
# 30 5
# 30 9
# 30 7
# 30 5
# 30 2
# 30 2
# 30 3
# 30 3
# 30 4
# 30 2
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_623635136_623721536/4fgl_j1833.6-2103_sed.fits
# 30 0
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_623807936_623894336/4fgl_j1833.6-2103_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_623894336_623980736/4fgl_j1833.6-2103_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_624067136_624153536/4fgl_j1833.6-2103_sed.fits
# 30 2
# 30 1
# 30 0
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/27_PKS1830-211_100MeV_1d_1/1days/lightcurve_624499136_624585536/4fgl_j1833.6-2103_sed.fits
# 30 0
# 30 2
# 30 0

# %%
print(table_allSEDs.colnames)
# Out:
# ['e_min', 'e_ref', 'e_max', 'ref_dnde_e_min', 'ref_dnde_e_max', 'ref_dnde', 'ref_flux', 'ref_eflux', 'ref_npred', 'dnde', 'dnde_err', 'dnde_errp', 'dnde_errn', 'dnde_ul', 'e2dnde', 'e2dnde_err', 'e2dnde_errp', 'e2dnde_errn', 'e2dnde_ul', 'norm', 'norm_err', 'norm_errp', 'norm_errn', 'norm_ul', 'ts', 'loglike', 'norm_scan', 'dloglike_scan', 'ShowUL', 'tstart', 'tend']

# %%
table_allSEDs
# Out:
# <Table length=2152>
#       e_min              e_ref        ...       tstart             tend
#        MeV                MeV         ...
#      float64            float64       ...      float64           float64
# ------------------ ------------------ ... ----------------- -----------------
#              100.0 115.25240587974294 ... 58409.00000212926 58410.00000212926
# 132.83117061068992   153.091119887046 ... 58409.00000212926 58410.00000212926
#  176.4411988580621 203.35272664697808 ... 58409.00000212926 58410.00000212926
# 234.36890988269914  270.1158072739371 ... 58409.00000212926 58410.00000212926
#  311.3149665447022  358.7979888064861 ... 58409.00000212926 58410.00000212926
# 413.52331434760555  476.5900816815941 ... 58409.00000212926 58410.00000212926
#  549.2752115212968  633.0528961793416 ... 58409.00000212926 58410.00000212926
#  729.6086933380817  840.8915725798939 ... 58409.00000212926 58410.00000212926
#  969.1477682383326 1116.9661194245136 ... 58409.00000212926 58410.00000212926
#                ...                ... ...               ...               ...
# 132.83117061068992   153.091119887046 ... 58909.00000212926 58910.00000212926
#  176.4411988580621 203.35272664697808 ... 58909.00000212926 58910.00000212926
# 234.36890988269914  270.1158072739371 ... 58909.00000212926 58910.00000212926
#  311.3149665447022  358.7979888064861 ... 58909.00000212926 58910.00000212926
# 413.52331434760555  476.5900816815941 ... 58909.00000212926 58910.00000212926
#  549.2752115212968  633.0528961793416 ... 58909.00000212926 58910.00000212926
#  729.6086933380817  840.8915725798939 ... 58909.00000212926 58910.00000212926
#  969.1477682383326 1116.9661194245136 ... 58909.00000212926 58910.00000212926
# 2271.3810595726877  2617.821317854317 ... 58909.00000212926 58910.00000212926
# 4007.6519721450045  4618.915317184078 ... 58909.00000212926 58910.00000212926

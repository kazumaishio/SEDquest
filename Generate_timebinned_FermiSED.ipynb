# %% [markdown]
# # Make an ecsv file which contains SEDs of all periods with significant number of data points
#
# From
# `/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/Generate_timebinned_MWLSED.ipynb`
#
#
# `/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days`
# Number of significant SEDs: 264
#
# `home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days`
# Number of significant SEDs: 208

# %%
import os

# # 3C454.3
# source_name='3C454.3'
# source_name_4fgl='4fgl_j2253.9+1609'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# '/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days/{directoryname}/4fgl_j2253.9+1609_sed.fits'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # S20109+22
# # S20109+22 = 4fgl_j0112.1+2245
# # Number of significant SEDs: 58
# source_name='S20109+22'
# source_name_4fgl='4fgl_j0112.1+2245'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/5_S20109+22_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 8_PKS1510-089_100MeV_14d
# # PKS1510-089 = 4fgl_j1512.8-0906
# # Number of significant SEDs: 40
# source_name='PKS1510-089'
# source_name_4fgl='4fgl_j1512.8-0906'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/8_PKS1510-089_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# # 9_4C+21.35_100MeV_14d
# # 4C+21.35 = 4fgl_j1224.9+2122
# source_name='4C+21.35'
# source_name_4fgl='4fgl_j1224.9+2122'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/9_4C+21.35_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )


# # 10_Mrk421_100MeV_14d
# # 4C+21.35 = 4fgl_j1224.9+2122
# source_name='Mrk421'
# source_name_4fgl='4fgl_j1104.4+3812'
# input_directory_parent='/home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days'
# directoryname_test='lightcurve_xxx_xxx'
# sed_filename=f'{source_name_4fgl}_sed.fits'
# outfilename=f'{source_name}_allsed_14d_min11.ecsv'
# sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )

# 11_CTA102_100MeV_14d
# CTA102 = 4fgl_j2232.6+1143
source_name='CTA102'
source_name_4fgl='4fgl_j2232.6+1143'
input_directory_parent='/home/kazuma/Workspace/AGN_data/11_CTA102_100MeV_14d/14days'
directoryname_test='lightcurve_xxx_xxx'
sed_filename=f'{source_name_4fgl}_sed.fits'
outfilename=f'{source_name}_allsed_14d_min11.ecsv'
sed_path_test=os.path.join(input_directory_parent,directoryname_test,sed_filename )
print(sed_path_test)
# Out:
# /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_xxx_xxx/4fgl_j1104.4+3812_sed.fits

# %%
####################################################################
# for Inline animations in Jupyter
# https://stackoverflow.com/questions/43445103/inline-animations-in-jupyter
####################################################################
# Enable interactive plot
# %matplotlib notebook

import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import os

####################################################################
# Functions
####################################################################
##################################
# 
##################################
def met_to_mjd(met) :
    mjd = 51910. + 7.4287e-4 + met/86400.
    return mjd
# print(mjd_start, mjd_end)
# print(met_to_mjd(mjd_start), met_to_mjd(mjd_end))
##################################
#  GET fermi SED table from fits file
##################################
from astropy.table import Table
def getsed(timebin_start,timebin_end):
    # print(directories)
    directoryname=f'lightcurve_{timebin_start}_{timebin_end}'
    sed_path=os.path.join(input_directory_parent,directoryname,sed_filename )
    try : 
        sed_tab= Table.read(sed_path)
        # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_14d/14days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
        # sed_tab= Table.read(f'/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days/{directoryname}/4fgl_j2253.9+1609_sed.fits')
        return sed_tab
    except:
        print('not found: ', sed_path)    
        return None

from astropy import units as u
from astropy.io import ascii

# %%
mjd_min=45000#55000
mjd_max=65000#56000

##################################
# Get subdirectories within time scope
directories=os.listdir(input_directory_parent)
# directories=os.listdir('/home/kazuma/Workspace/AGN_data/3_3C454_100MeV_7d/7days')
timebins_start=[]
timebins_end=[]
for directoryname in directories:
    elements=directoryname.split('_')
    timebin_start=met_to_mjd(float(elements[1]))
    timebin_end=met_to_mjd(float(elements[2]))
#     print(elements[1],elements[2])
#     print(timebin_start, timebin_end)
    if timebin_end>mjd_max*1.0001 :
        continue        
    if timebin_start<mjd_min*0.9999 :
        continue
    timebins_start.append(int(elements[1]))
    timebins_end.append(int(elements[2]))

timebins_start.sort()
timebins_end.sort()
print(timebins_start[0], timebins_end[-1])
print('Which are {} and {}'.format(mjd_min,mjd_max))
print(met_to_mjd(timebins_start[0]), met_to_mjd(timebins_end[-1]))
# Out:
# 239557417 767620442
# Which are 45000 and 65000
# 54682.65603222185 60794.49659935148

# %%
##################################
# Get Fermi SED
##################################
n_significant_sed=0
for i in range(len(timebins_start)):
    timebin_start=timebins_start[i]
    timebin_end=timebins_end[i]
    sed_tab=getsed(timebin_start,timebin_end)
    if sed_tab is None:
        continue

    default_eref=sed_tab['e_ref']
    default_flux=np.ones(len(default_eref))*1e-4
    default_asymmerr=[np.ones(len(default_eref))*1e-5,np.ones(len(default_eref))*1e-5]

    default_errdiff=np.ones(len(default_eref))
    default_ts=np.ones(len(default_eref))*0.1
    high_significance_mask = (sed_tab['ts']>=9)
    low_significance_mask = (sed_tab['ts']<9)
    sed_tab['ShowUL']=low_significance_mask
    sed_tab_significant=sed_tab[high_significance_mask]
    sed_tab_nosignificant=sed_tab[low_significance_mask]
    print(len(sed_tab['e_ref']),len(sed_tab_significant['e_ref']))
    if len(sed_tab_significant['e_ref'])>=10:
        n_significant_sed+=1
    # print(len(sed_tab_nosignificant['e_ref']),len(sed_tab_nosignificant['e2dnde_ul']))
    # print(sed_tab_nosignificant['e_ref'],sed_tab_nosignificant['e2dnde_ul'])

print('Number of significant SEDs:',n_significant_sed)
# Out:
# 30 18
# 30 25
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_241976617_243186217/4fgl_j1104.4+3812_sed.fits
# 30 19
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_244395817_245605417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_245605417_246815017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_246815017_248024617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_248024617_249234217/4fgl_j1104.4+3812_sed.fits
# 30 18
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_250443817_251653417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_251653417_252863017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_252863017_254072617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_254072617_255282217/4fgl_j1104.4+3812_sed.fits
# 30 16
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_256491817_257701417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_257701417_258911017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_258911017_260120617/4fgl_j1104.4+3812_sed.fits
# 30 20
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_261330217_262539817/4fgl_j1104.4+3812_sed.fits
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_263749417_264959017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_264959017_266168617/4fgl_j1104.4+3812_sed.fits
# 30 19
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_267378217_268587817/4fgl_j1104.4+3812_sed.fits
# 30 18
# 30 17
# 30 19
# 30 14
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_273426217_274635817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_274635817_275845417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_275845417_277055017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_277055017_278264617/4fgl_j1104.4+3812_sed.fits
# 30 19
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_279474217_280683817/4fgl_j1104.4+3812_sed.fits
# 30 21
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_281893417_283103017/4fgl_j1104.4+3812_sed.fits
# 30 24
# 30 21
# 30 15
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_286731817_287941417/4fgl_j1104.4+3812_sed.fits
# 30 22
# 30 18
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_290360617_291570217/4fgl_j1104.4+3812_sed.fits
# 30 15
# 30 18
# 30 23
# 30 18
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_296408617_297618217/4fgl_j1104.4+3812_sed.fits
# 30 20
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_298827817_300037417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_300037417_301247017/4fgl_j1104.4+3812_sed.fits
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_302456617_303666217/4fgl_j1104.4+3812_sed.fits
# 30 18
# 30 16
# 30 16
# 30 19
# 30 20
# 30 15
# 30 16
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_312133417_313343017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_632677417_633887017/4fgl_j1104.4+3812_sed.fits
# 30 3
# 30 11
# 30 15
# 30 20
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_638725417_639935017/4fgl_j1104.4+3812_sed.fits
# 30 20
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_641144617_642354217/4fgl_j1104.4+3812_sed.fits
# 30 17
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_643563817_644773417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_644773417_645983017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_645983017_647192617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_647192617_648402217/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_648402217_649611817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_649611817_650821417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_650821417_652031017/4fgl_j1104.4+3812_sed.fits
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_653240617_654450217/4fgl_j1104.4+3812_sed.fits
# 30 16
# 30 16
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_658079017_659288617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_659288617_660498217/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_660498217_661707817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_661707817_662917417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_662917417_664127017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_664127017_665336617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_665336617_666546217/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_666546217_667755817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_667755817_668965417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_668965417_670175017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_670175017_671384617/4fgl_j1104.4+3812_sed.fits
# 30 7
# 30 23
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_673803817_675013417/4fgl_j1104.4+3812_sed.fits
# 30 19
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_676223017_677432617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_677432617_678642217/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_678642217_679851817/4fgl_j1104.4+3812_sed.fits
# 30 15
# 30 19
# 30 18
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_684690217_685899817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_685899817_687109417/4fgl_j1104.4+3812_sed.fits
# 30 25
# 30 23
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_689528617_690738217/4fgl_j1104.4+3812_sed.fits
# 30 22
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_691947817_693157417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_693157417_694367017/4fgl_j1104.4+3812_sed.fits
# 30 26
# 30 18
# 30 21
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_697995817_699205417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_699205417_700415017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_700415017_701624617/4fgl_j1104.4+3812_sed.fits
# 30 21
# 30 21
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_704043817_705253417/4fgl_j1104.4+3812_sed.fits
# 30 21
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_706463017_707672617/4fgl_j1104.4+3812_sed.fits
# 30 17
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_708882217_710091817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_710091817_711301417/4fgl_j1104.4+3812_sed.fits
# 30 21
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_712511017_713720617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_713720617_714930217/4fgl_j1104.4+3812_sed.fits
# 30 23
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_716139817_717349417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_717349417_718559017/4fgl_j1104.4+3812_sed.fits
# 30 24
# 30 24
# 30 19
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_722187817_723397417/4fgl_j1104.4+3812_sed.fits
# 30 23
# 30 26
# 30 15
# 30 18
# 30 23
# 30 12
# 30 15
# 30 20
# 30 20
# 30 7
# 30 13
# 30 21
# 30 18
# 30 19
# 30 24
# 30 18
# 30 18
# 30 8
# 30 14
# 30 16
# 30 5
# 30 16
# 30 15
# 30 16
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_752427817_753637417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_753637417_754847017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_754847017_756056617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_756056617_757266217/4fgl_j1104.4+3812_sed.fits
# 30 15
# 30 15
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_759685417_760895017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_760895017_762104617/4fgl_j1104.4+3812_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_763314217_764523817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_764523817_765733417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_765733417_766943017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_766943017_767620442/4fgl_j1104.4+3812_sed.fits
# Number of significant SEDs: 207

# %%
##################################
# Get Fermi SED
##################################

from astropy.table import Table, vstack
table_allSEDs=Table()
n_significant_sed=0
for i in range(len(timebins_start)):
    timebin_start=timebins_start[i]
    timebin_end=timebins_end[i]
    sed_tab=getsed(timebin_start,timebin_end)
    if sed_tab is None:
        continue

    default_eref=sed_tab['e_ref']
    default_flux=np.ones(len(default_eref))*1e-4
    default_asymmerr=[np.ones(len(default_eref))*1e-5,np.ones(len(default_eref))*1e-5]

    default_errdiff=np.ones(len(default_eref))
    default_ts=np.ones(len(default_eref))*0.1
    high_significance_mask = (sed_tab['ts']>=9)
    low_significance_mask = (sed_tab['ts']<9)
    sed_tab['ShowUL']=low_significance_mask
    sed_tab_significant=sed_tab[high_significance_mask]
    sed_tab_nosignificant=sed_tab[low_significance_mask]
    print(len(sed_tab['e_ref']),len(sed_tab_significant['e_ref']))
    if len(sed_tab_significant['e_ref'])>=10:
        n_significant_sed+=1
        sed_tab_significant['tstart']=[met_to_mjd(timebin_start)]*len(sed_tab_significant['e_ref'])
        sed_tab_significant['tend']=[met_to_mjd(timebin_end)]*len(sed_tab_significant['e_ref'])
        table_allSEDs=vstack([table_allSEDs, sed_tab_significant])

    # print(len(sed_tab_nosignificant['e_ref']),len(sed_tab_nosignificant['e2dnde_ul']))
    # print(sed_tab_nosignificant['e_ref'],sed_tab_nosignificant['e2dnde_ul'])


table_allSEDs.write(outfilename)
# print(t)

# print('Number of significant SEDs:',n_significant_sed)
# Out:
# 30 18
# 30 25
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_241976617_243186217/4fgl_j1104.4+3812_sed.fits
# 30 19
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_244395817_245605417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_245605417_246815017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_246815017_248024617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_248024617_249234217/4fgl_j1104.4+3812_sed.fits
# 30 18
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_250443817_251653417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_251653417_252863017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_252863017_254072617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_254072617_255282217/4fgl_j1104.4+3812_sed.fits
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_256491817_257701417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_257701417_258911017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_258911017_260120617/4fgl_j1104.4+3812_sed.fits
# 30 20
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_261330217_262539817/4fgl_j1104.4+3812_sed.fits
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_263749417_264959017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_264959017_266168617/4fgl_j1104.4+3812_sed.fits
# 30 19
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_267378217_268587817/4fgl_j1104.4+3812_sed.fits
# 30 18
# 30 17
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 19
# 30 14
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_273426217_274635817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_274635817_275845417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_275845417_277055017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_277055017_278264617/4fgl_j1104.4+3812_sed.fits
# 30 19
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_279474217_280683817/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 21
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_281893417_283103017/4fgl_j1104.4+3812_sed.fits
# 30 24
# 30 21
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_286731817_287941417/4fgl_j1104.4+3812_sed.fits
# 30 22
# 30 18
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_290360617_291570217/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 18
# 30 23
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 18
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_296408617_297618217/4fgl_j1104.4+3812_sed.fits
# 30 20
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_298827817_300037417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_300037417_301247017/4fgl_j1104.4+3812_sed.fits
# 30 8
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_302456617_303666217/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 18
# 30 16
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 19
# 30 20
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_312133417_313343017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_313343017_314552617/4fgl_j1104.4+3812_sed.fits
# 30 16
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_315762217_316971817/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_318181417_319391017/4fgl_j1104.4+3812_sed.fits
# 30 14
# 30 18
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 21
# 30 17
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_324229417_325439017/4fgl_j1104.4+3812_sed.fits
# 30 18
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# 30 9
# 30 9
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_331487017_332696617/4fgl_j1104.4+3812_sed.fits
# 30 14
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_333906217_335115817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_335115817_336325417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_336325417_337535017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_337535017_338744617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_338744617_339954217/4fgl_j1104.4+3812_sed.fits
# 30 18
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 22
# 30 19
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_344792617_346002217/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_346002217_347211817/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_348421417_349631017/4fgl_j1104.4+3812_sed.fits
# 30 13
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_353259817_354469417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_354469417_355679017/4fgl_j1104.4+3812_sed.fits
# 30 19
# 30 19
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_359307817_360517417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_360517417_361727017/4fgl_j1104.4+3812_sed.fits
# 30 23
# 30 25
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_364146217_365355817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_365355817_366565417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_366565417_367775017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_367775017_368984617/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 21
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_578245417_579455017/4fgl_j1104.4+3812_sed.fits
# 30 13
# 30 19
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_581874217_583083817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_583083817_584293417/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 12
# 30 20
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_587922217_589131817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_589131817_590341417/4fgl_j1104.4+3812_sed.fits
# 30 24
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_591551017_592760617/4fgl_j1104.4+3812_sed.fits
# 30 23
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_593970217_595179817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_595179817_596389417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_596389417_597599017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_597599017_598808617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_598808617_600018217/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 18
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_601227817_602437417/4fgl_j1104.4+3812_sed.fits
# 30 3
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_603647017_604856617/4fgl_j1104.4+3812_sed.fits
# 30 16
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_606066217_607275817/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 21
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_612114217_613323817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_613323817_614533417/4fgl_j1104.4+3812_sed.fits
# 30 18
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_615743017_616952617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_616952617_618162217/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_618162217_619371817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_619371817_620581417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_620581417_621791017/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 20
# 30 25
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_624210217_625419817/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 22
# 30 20
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_627839017_629048617/4fgl_j1104.4+3812_sed.fits
# 30 21
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_630258217_631467817/4fgl_j1104.4+3812_sed.fits
# 30 9
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_632677417_633887017/4fgl_j1104.4+3812_sed.fits
# 30 3
# 30 11
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 20
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_638725417_639935017/4fgl_j1104.4+3812_sed.fits
# 30 20
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_641144617_642354217/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 17
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_643563817_644773417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_644773417_645983017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_645983017_647192617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_647192617_648402217/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_648402217_649611817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_649611817_650821417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_650821417_652031017/4fgl_j1104.4+3812_sed.fits
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_653240617_654450217/4fgl_j1104.4+3812_sed.fits
# 30 16
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# 30 12
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_658079017_659288617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_659288617_660498217/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_660498217_661707817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_661707817_662917417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_662917417_664127017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_664127017_665336617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_665336617_666546217/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_666546217_667755817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_667755817_668965417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_668965417_670175017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_670175017_671384617/4fgl_j1104.4+3812_sed.fits
# 30 7
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 23
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_673803817_675013417/4fgl_j1104.4+3812_sed.fits
# 30 19
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_676223017_677432617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_677432617_678642217/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_678642217_679851817/4fgl_j1104.4+3812_sed.fits
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 19
# 30 18
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 13
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_684690217_685899817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_685899817_687109417/4fgl_j1104.4+3812_sed.fits
# 30 25
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 23
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_689528617_690738217/4fgl_j1104.4+3812_sed.fits
# 30 22
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_691947817_693157417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_693157417_694367017/4fgl_j1104.4+3812_sed.fits
# 30 26
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 18
# 30 21
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_697995817_699205417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_699205417_700415017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_700415017_701624617/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 21
# 30 21
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_704043817_705253417/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 21
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_706463017_707672617/4fgl_j1104.4+3812_sed.fits
# 30 17
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_708882217_710091817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_710091817_711301417/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 21
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_712511017_713720617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_713720617_714930217/4fgl_j1104.4+3812_sed.fits
# 30 23
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_716139817_717349417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_717349417_718559017/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 24
# 30 24
# 30 19
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_722187817_723397417/4fgl_j1104.4+3812_sed.fits
# 30 23
# 30 26
# 30 15
# 30 18
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 23
# 30 12
# 30 15
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 20
# 30 20
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 7
# 30 13
# 30 21
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 18
# 30 19
# 30 24
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 18
# 30 18
# 30 8
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 14
# 30 16
# 30 5
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 16
# 30 15
# 30 16
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_752427817_753637417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_753637417_754847017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_754847017_756056617/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_756056617_757266217/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# 30 15
# 30 15
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_759685417_760895017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_760895017_762104617/4fgl_j1104.4+3812_sed.fits
# 30 1
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_763314217_764523817/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_764523817_765733417/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_765733417_766943017/4fgl_j1104.4+3812_sed.fits
# not found:  /home/kazuma/Workspace/AGN_data/10_Mrk421_100MeV_14d/14days/lightcurve_766943017_767620442/4fgl_j1104.4+3812_sed.fits
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]

# %%
print(table_allSEDs.colnames)
# Out:
# []

# %%
table_allSEDs
# Out:
# <Table length=0>
# <No columns>

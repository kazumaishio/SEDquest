# %% [markdown]
# /Users/kazuma/Workspace/MAGICana/Analysis_Mrk501_2014/20241025_Mrk501_ST0303_SED_dark/20140721/4_flute/eff99_ThSq75_Az6_Ebin28/
# に、
# ```
# Status_flute.root
# Status_fold.root
# ```
# がある。これをもとに
# `eff99_ThSq75_Az6_Ebin28_LPfit`
# でEBL抜きにしてfit再実施。
#
#
# `fold --inputfile=./Output_flute.root --function=SEPWL`の結果：
# ```
# Function expression: dF/dE = [p0]*pow(x/409.00,[p1])*exp(-pow(x/[p2]/[p2],[p3]))
# Intrinsic spectral parameters:    4.6194e-10, -2.20794, 85.7847, 2.31068
# Intr. spec. param. uncertainties (default ones from Migrad): 2.76873e-11, 0.0694718, 11.0029, 1.80669
#
# Intrinsic spec. parameters (with MINOS uncertainties):
# parameter #0= 4.6194e-10   +2.86978e-09   -2.86978e-09
# parameter #1= -2.20794   +0.161931   -0.161931
# parameter #2= 85.7847   +0   0
# parameter #3= 2.31068   +0   0
#
# Final Chi2: 10.921 / 12
# Prob = 0.535698
# ```
